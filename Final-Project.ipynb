# %% [markdown]
# # Downloading and Peparing the data

# %%
#Importing the packaged

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import csv
from multiprocessing import Pool
import time
import sys
import urllib.request
import json

# %%
import networkx as nx
from networkx.algorithms import bipartite

# %%
# Creating a function that uses mapbox api to get NYC neighborhood name given our crime GPS coordinate
# Code adapted from Javascrip code obtained from Stack Overflow: 
# https://stackoverflow.com/questions/42583857/api-to-convert-lat-lon-to-nyc-neighborhood

access_token = '?access_token=pk.eyJ1IjoibWFwYm94IiwiYSI6ImNpejY4NXVycTA2emYycXBndHRqcmZ3N3gifQ.rJcFIG214AriISLbB6B5aw'
urlInit = 'https://api.mapbox.com/geocoding/v5/'
mode = 'mapbox.places/'
var_type = '&types=neighborhood'

def getNeighborhood(lat,lon):
    lonlat = str(lon) + '%2C' + str(lat) + '.json'
    url = urlInit + mode + lonlat + access_token + var_type
    with urllib.request.urlopen(url) as response:
        html = response.read().decode('utf-8')
    json_obj = json.loads(html)
    return json_obj['features'][0]['text']

# %%
# Loading NYC complaints from January 1st 2018 to November 1st 2018

data2018 = np.array(list(csv.reader(open("C://Users//Rebecca//Desktop//nsa//final_project//Project-Network//Project Network//NYPD_Complaint_Data_Current__Year_To_Date_.csv", "r"), delimiter=",")))

# %%
# Obtain the neighborhood information on all our crime data and saving it
# !! Careful !! Takes 2 hours to run

F = open("Longitude_Latitude_Neighborhood.csv", 'w')
F.write("Longitude,Latitude,Neighborhood\n")
for i in data2018[1:]:
    lon = i[-2]
    lat = i[-3]
    try:
        nei = getNeighborhood(lat,lon)
        line = str(lon) +','+ str(lat) +','+ str(nei) +'\n'
        F.write(line)
    except:
        line = str(lon) +','+ str(lat) +','+ "no neihborhood" +'\n'
        F.write(line)
F.close()

# %%
# Loading the data obtained and saved in the previous cell.

neihborhood = np.array(list(csv.reader(open("C://Users//Rebecca//Desktop//nsa//final_project//Project-Network//Project Network//Longitude_Latitude_Neighborhood.csv", "r"), delimiter=",")))

# %%
# Loading the data merged in excel of the neighborhoods of each crime, with the type of crime.

dataGraph = np.array(list(csv.reader(open("C://Users//Rebecca//Desktop//nsa//final_project//Project-Network//Project Network//Data-for-graph.csv", "r"), delimiter=",")))

# %%
# Same as dataGraph, but with the neighborhoods ordred by borough, and the crime ordered by crime types.

dataGraph2 = np.array(list(csv.reader(open("C://Users//Rebecca//Desktop//nsa//final_project//Project-Network//Project Network//Data-for-graph2.csv", "r"), delimiter=",")))

# %%
dataGraph3 = np.array(list(csv.reader(open("C://Users//Rebecca//Desktop//nsa//final_project//Project-Network//Project Network//Data-for-graph3.csv", "r"), delimiter=",")))

# %% [markdown]
# ### Creating the Bipartite Graph

# %% [markdown]
# This part was a trial, it holds some insights in our data but in the end was not used for our final results.
# It can be skipped.

# %%
# Creating a bipartite graph with the type of crimes as one type of nodes, and neighborhood as the other type.

G = nx.Graph()
# Adding attribute "bipartite" to differentiate two different classes in the bipartite garph
G.add_nodes_from(dataGraph[1:,2], bipartite=0)
G.add_nodes_from(dataGraph[1:,3], bipartite=1)

# %%
# Same as previous graph, but with the nodes ordered for easier visualisation.

G2 = nx.Graph()
G2.add_nodes_from(dataGraph2[1:,2], bipartite=0)
G2.add_nodes_from(dataGraph3[1:,3], bipartite=1)

# %%
G2.nodes
# Out:
# NodeView(('Longwood', 'Soundview', 'South Bronx', 'High Bridge', 'University Heights', 'Williamsbridge', 'Tremont', 'Parkchester', 'Morris Heights', 'Morris Park', 'Concourse', 'Fordham', 'Van Nest', 'Norwood', 'Bedford Park', 'Wakefield', 'East Tremont', 'Melrose', 'Mott Haven', 'West Farms', 'Eastchester', 'Co-op City', 'Pelham Bay', 'Throggs Neck', 'Kingsbridge', 'Hunts Point', 'City Island', 'Pelham Gardens', 'Unionport', 'Belmont', 'Port Morris', 'Baychester', 'Marble Hill', 'Castle Hill', 'Fieldston', 'Clason Point', 'Country Club', 'Rikers Island', 'North Riverdale', 'Westchester Heights', 'Woodlawn', 'Riverdale', 'no neihborhood BRONX', 'Spuyten Duyvil', 'Washington Heights', 'Van Cortlandt Park', 'Pelham Bay Park', 'Bronx Park', 'East New York', 'Brownsville', 'Bedford Stuyvesant', 'East Harlem', 'Crown Heights', 'Canarsie', 'Greenpoint', 'Flatbush', 'Williamsburg', 'Sheepshead Bay', 'Bath Beach', 'Flatlands', 'Bushwick', 'East Flatbush', 'Greenwood', 'Fort Greene', 'Kensington', 'Prospect Heights', 'Mill Basin', 'Downtown', 'Coney Island', 'Park Slope', 'Wingate', 'Prospect Lefferts Gardens', 'Ridgewood', 'Carroll Gardens', 'Windsor Terrace', 'Brighton Beach', 'Clinton Hill', 'Bay Ridge', 'Ocean Hill', 'Midwood', 'Sunset Park', 'Bensonhurst', 'Red Hook', 'Bergen Beach', 'Dyker Heights', 'Borough Park', 'Gowanus', 'Gravesend', 'Marine Park', 'Brooklyn Heights', 'DUMBO', 'Ocean Parkway', 'Boerum Hill', 'Homecrest', 'Fort Hamilton', 'Prospect Park', 'Gerritsen Beach', 'Columbia Street Waterfront District', 'New Utrecht', 'Ozone Park', 'Floyd Bennett Field', 'Georgetown', 'Cobble Hill', 'no neihborhood BROOKLYN', 'Manhattan Beach', 'Prospect Park South', 'Woodhaven', 'Chelsea', 'Vinegar Hill', 'Navy Yard', 'Upper West Side', 'Harlem', 'Midtown', 'Upper East Side', 'Manhattanville', 'Chinatown', 'Tribeca', 'Financial District', 'Gramercy', 'Flatiron District', 'Clinton', 'Greenwich Village', 'Garment District', 'Lower East Side', 'Central Park', 'West Village', 'Hamilton Heights', 'East Village', 'SoHo', 'Sutton Place', 'Morningside Heights', 'Murray Hill', 'Inwood', 'Turtle Bay', 'NoHo', 'Columbus Circle', 'no neihborhood MANHATTAN', 'Little Italy', 'Stuyvesant Town', 'Carnegie Hill', 'Tudor City', 'Roosevelt Island', 'Randals-Wards Island', 'Battery Park', 'Astoria', 'St. Albans', 'no neihborhood QUEENS', 'Maspeth', 'Bayside', 'Corona', 'Hunters Point', 'Elmhurst', 'Far Rockaway', 'South Ozone Park', 'Rochdale', 'Richmond Hill', 'Jackson Heights', 'Fresh Meadows', 'Forest Hills', 'Arverne', 'East Elmhurst', 'Flushing', 'Hollis', 'Pomonok', 'Sunnyside', 'Oakland Gardens', 'Jamaica', 'Woodside', 'Glendale', 'Briarwood', 'Rego Park', 'Rockaway Beach', 'Bellerose', 'Whitestone', 'Cambria Heights', 'Rosedale', 'Broad Channel', 'Laurelton', 'Springfield Gardens', 'Astoria Heights', 'Queens Village', 'Floral park', 'Kew Gardens Hills', 'Hillcrest', 'Neponsit', 'Kew Gardens', 'Douglaston-Little Neck', 'Rockaway Park', 'College Point', 'Jamaica Estates', 'Bay Terrace', 'Jamaica Hills', 'Auburndale', 'Howard Beach', 'Middle Village', 'Glen Oaks', 'Utopia', 'Flushing Meadows Corona Park', 'Malba', 'Belle Harbor', 'Holliswood', 'Blissville', 'Forest Hills Gardens', 'John F. Kennedy International Airport', 'Breezy Point', 'Jacob Riis Park', 'Graniteville', 'La Guardia Airport', 'Roxbury', "Mariner's Harbor", 'Park Hill', 'Port Ivory', 'St. George', 'Huguenot', 'Charleston', 'Port Richmond', 'Tottenville', 'South Beach', 'West Brighton', 'Stapleton', 'Arrochar', 'Westerleigh', 'Heartland Village', 'Tompkinsville', 'New Dorp', 'Great Kills', 'Dongan Hills', 'Oakwood', 'New Brighton', 'Midland Beach', 'Grant City', 'Woodrow', 'New Springville', 'Willowbrook', 'Elm Park', 'Richmond Town', 'Grasmere - Concord', 'Bulls Head', 'Todt Hill', 'Rossville', 'Eltingville', 'Grymes Hill', 'Chelsea-Travis', 'Richmond Valley', 'Castleton Corners', 'Emerson Hill', 'Rosebank', 'Arden Heights', 'Bloomfield', 'New Dorp Beach', "Prince's Bay", 'Meiers C ...

# %%
edgelist = [ (i[2],i[3]) for i in dataGraph2[1:]]

# %%
edgelist
# Out:
# [('Longwood', '567'),
#  ('Soundview', '114'),
#  ('South Bronx', '404'),
#  ('High Bridge', '638'),
#  ('Longwood', '567'),
#  ('University Heights', '729'),
#  ('Soundview', '101'),
#  ('Williamsbridge', '101'),
#  ('Williamsbridge', '254'),
#  ('High Bridge', '115'),
#  ('Longwood', '567'),
#  ('Tremont', '101'),
#  ('Parkchester', '267'),
#  ('Morris Heights', '187'),
#  ('Tremont', '637'),
#  ('Williamsbridge', '101'),
#  ('Morris Park', '922'),
#  ('Williamsbridge', '389'),
#  ('Concourse', '638'),
#  ('South Bronx', '637'),
#  ('Fordham', '269'),
#  ('Van Nest', '567'),
#  ('Norwood', '198'),
#  ('Bedford Park', '567'),
#  ('Wakefield', '343'),
#  ('Wakefield', '793'),
#  ('Morris Park', '333'),
#  ('Wakefield', '782'),
#  ('Fordham', '101'),
#  ('Van Nest', '916'),
#  ('Concourse', '637'),
#  ('Fordham', '101'),
#  ('Concourse', '638'),
#  ('East Tremont', '503'),
#  ('Melrose', '637'),
#  ('South Bronx', '109'),
#  ('Concourse', '101'),
#  ('Van Nest', '109'),
#  ('South Bronx', '321'),
#  ('Mott Haven', '114'),
#  ('West Farms', '922'),
#  ('Concourse', '705'),
#  ('Fordham', '503'),
#  ('West Farms', '397'),
#  ('Mott Haven', '637'),
#  ('Norwood', '157'),
#  ('Eastchester', '441'),
#  ('Morris Park', '101'),
#  ('Longwood', '101'),
#  ('Concourse', '637'),
#  ('Fordham', '638'),
#  ('University Heights', '511'),
#  ('Co-op City', '333'),
#  ('Melrose', '114'),
#  ('Pelham Bay', '782'),
#  ('Williamsbridge', '649'),
#  ('Fordham', '333'),
#  ('Morris Park', '333'),
#  ('South Bronx', '101'),
#  ('Concourse', '333'),
#  ('Melrose', '198'),
#  ('Throggs Neck', '333'),
#  ('Throggs Neck', '637'),
#  ('Tremont', '638'),
#  ('Tremont', '503'),
#  ('South Bronx', '101'),
#  ('Williamsbridge', '793'),
#  ('Parkchester', '637'),
#  ('Longwood', '637'),
#  ('Melrose', '113'),
#  ('Soundview', '639'),
#  ('Morris Park', '333'),
#  ('Williamsbridge', '638'),
#  ('Kingsbridge', '377'),
#  ('Throggs Neck', '338'),
#  ('Hunts Point', '198'),
#  ('Williamsbridge', '209'),
#  ('Soundview', '638'),
#  ('South Bronx', '101'),
#  ('South Bronx', '221'),
#  ('Pelham Bay', '254'),
#  ('Pelham Bay', '101'),
#  ('West Farms', '113'),
#  ('Norwood', '479'),
#  ('University Heights', '259'),
#  ('South Bronx', '916'),
#  ('South Bronx', '259'),
#  ('Fordham', '639'),
#  ('City Island', '338'),
#  ('Morris Heights', '637'),
#  ('Throggs Neck', '333'),
#  ('Co-op City', '637'),
#  ('Morris Park', '333'),
#  ('Pelham Gardens', '637'),
#  ('Unionport', '113'),
#  ('Tremont', '638'),
#  ('Belmont', '333'),
#  ('Port Morris', '254'),
#  ('South Bronx', '338'),
#  ('Parkchester', '333'),
#  ('High Bridge', '109'),
#  ('Melrose', '415'),
#  ('Concourse', '637'),
#  ('Kingsbridge', '637'),
#  ('Williamsbridge', '639'),
#  ('Concourse', '638'),
#  ('Concourse', '321'),
#  ('Concourse', '567'),
#  ('University Heights', '567'),
#  ('Kingsbridge', '638'),
#  ('Tremont', '390'),
#  ('Throggs Neck', '638'),
#  ('Melrose', '638'),
#  ('Concourse', '113'),
#  ('South Bronx', '638'),
#  ('Melrose', '638'),
#  ('Tremont', '386'),
#  ('East Tremont', '343'),
#  ('Tremont', '101'),
#  ('Kingsbridge', '333'),
#  ('Parkchester', '748'),
#  ('University Heights', '101'),
#  ('Mott Haven', '438'),
#  ('Melrose', '109'),
#  ('Unionport', '101'),
#  ('Unionport', '101'),
#  ('Soundview', '321'),
#  ('Williamsbridge', '109'),
#  ('Soundview', '384'),
#  ('Fordham', '749'),
#  ('South Bronx', '638'),
#  ('Soundview', '259'),
#  ('Longwood', '321'),
#  ('Concourse', '113'),
#  ('Melrose', '338'),
#  ('Longwood', '388'),
#  ('Williamsbridge', '321'),
#  ('Concourse', '637'),
#  ('Kingsbridge', '401'),
#  ('Morris Park', '108'),
#  ('High Bridge', '101'),
#  ('South Bronx', '639'),
#  ('Mott Haven', '397'),
#  ('South Bronx', '101'),
#  ('Concourse', '101'),
#  ('Williamsbridge', '109'),
#  ('Wakefield', '905'),
#  ('High Bridge', '109'),
#  ('Morris Park', '157'),
#  ('Concourse', '109'),
#  ('Williamsbridge', '905'),
#  ('Concourse', '343'),
#  ('Morris Heights', '916'),
#  ('Concourse', '101'),
#  ('Williamsbridge', '367'),
#  ('Longwood', '269'),
#  ('Wakefield', '905'),
#  ('Concourse', '386'),
#  ('Tremont', '259'),
#  ('East Tremont', '639'),
#  ('Williamsbridge', '638'),
#  ('Norwood', '905'),
#  ('Belmont', '305'),
#  ('South Bronx', '269'),
#  ('East Tremont', '259'),
#  ('South Bronx', '386'),
#  ('Hunts Point', '905'),
#  ('East Tremont', '638'),
#  ('Longwood', '905'),
#  ('Bedford Park', '109'),
#  ('Fordham', '101'),
#  ('Belmont', '503'),
#  ('Belmont', '109'),
#  ('Soundview', '457'),
#  ('South Bronx', '637'),
#  ('Baychester', '114'),
#  ('South Bronx', '254'),
#  ('Williamsbridge', '113'),
#  ('Tremont', '916'),
#  ('Longwood', '569'),
#  ('Mott Haven', '105'),
#  ('Kingsbridge', '637'),
#  ('Port Morris', '916'),
#  ('South Bronx', '357'),
#  ('Eastchester', '389'),
#  ('Melrose', '259'),
#  ('South Bronx', '916'),
#  ('Eastchester', '638'),
#  ('Morris Heights', '114'),
#  ('Kingsbridge', '638'),
#  ('Morris Park', '638'),
#  ('Mott Haven', '213'),
#  ('Norwood', '321'),
#  ('Williamsbridge', '335'),
#  ('Pelham Gardens', '441'),
#  ('Soundview', '637'),
#  ('South Bronx', '441'),
#  ('Morris Heights', '259'),
#  ('Concourse', '109'),
#  ('South Bronx', '421'),
#  ('South Bronx', '749'),
#  ('Wakefield', '638'),
#  ('Concourse', '421'),
#  ('Melrose', '439'),
#  ('Williamsbridge', '638'),
#  ('East Tremont', '638'),
#  ('Concourse', '638'),
#  ('Concourse', '421'),
#  ('Norwood', '198'),
#  ('Concourse', '254'),
#  ('Williamsbridge', '338'),
#  ('Melrose', '321'),
#  ('Concourse', '389'),
#  ('Unionport', '349'),
#  ('Mott Haven', '357'),
#  ('Williamsbridge', '109'),
#  ('Unionport', '638'),
#  ('Soundview', '267'),
#  ('Wakefield', '254'),
#  ('Soundview', '101'),
#  ('South Bronx', '321'),
#  ('Soundview', '338'),
#  ('Concourse', '101'),
#  ('Concourse', '638'),
#  ('Throggs Neck', '109'),
#  ('East Tremont', '729'),
#  ('Unionport', '361'),
#  ('Fordham', '638'),
#  ('Williamsbridge', '321'),
#  ('Melrose', '425'),
#  ('Tremont', '269'),
#  ('West Farms', '420'),
#  ('Throggs Neck', '333'),
#  ('Williamsbridge', '254'),
#  ('Soundview', '338'),
#  ('Williamsbridge', '638'),
#  ('Concourse', '338'),
#  ('Kingsbridge', '420'),
#  ('University Heights', '750'),
#  ('Norwood', '567'),
#  ('Hunts Point', '567'),
#  ('Longwood', '113'),
#  ('Mott Haven', '269'),
#  ('East Tremont', '339'),
#  ('Williamsbridge', '113'),
#  ('Soundview', '638'),
#  ('Longwood', '567'),
#  ('Longwood', '101'),
#  ('Kingsbridge', '113'),
#  ('Norwood', '782'),
#  ('South Bronx', '339'),
#  ('Longwood', '782'),
#  ('Concourse', '339'),
#  ('Concourse', '793'),
#  ('Concourse', '343'),
#  ('South Bronx', '637'),
#  ('Longwood', '749'),
#  ('Morris Heights', '638'),
#  ('Marble Hill', '638'),
#  ('Norwood', '637'),
#  ('Morris Heights', '638'),
#  ('Bedford Park', '259'),
#  ('Concourse', '792'),
#  ('Williamsbridge', '101'),
#  ('Concourse', '198'),
#  ('Williamsbridge', '338'),
#  ('Williamsbridge', '101'),
#  ('Tremont', '638'),
#  ('South Bronx', '333'),
#  ('Pelham Gardens', '638'),
#  ('High Bridge', '569'),
#  ('Kingsbridge', '101'),
#  ('Tremont', '567'),
#  ('Bedford Park', '792'),
#  ('University Heights', '198'),
#  ('Wakefield', '114'),
#  ('Mott Haven', '254'),
#  ('South Bronx', '198'),
#  ('Melrose', '638'),
#  ('South Bronx', '101'),
#  ('Bedford Park', '568'),
#  ('Mott Haven', '511'),
#  ('Bedford Park', '725'),
#  ('Melrose', '333'),
#  ('Fordham', '333'),
#  ('Bedford Park', '511'),
#  ('West Farms', '384'),
#  ('Soundview', '638'),
#  ('Concourse', '321'),
#  ('Concourse', '333'),
#  ('Melrose', '916'),
#  ('Williamsbridge', '258'),
#  ('Bedford Park', '638'),
#  ('South Bronx', '638'),
#  ('University Heights', '511'),
#  ('South Bronx', '916'),
#  ('South Bronx', '254'),
#  ('Bedford Park', '639'),
#  ('Concourse', '321'),
#  ('Concourse', '384'),
#  ('Fordham', '101'),
#  ('Concourse', '511'),
#  ('Castle Hill', '638'),
#  ('Concourse', '106'),
#  ('Concourse', '106'),
#  ('Fordham', '426'),
#  ('Morris Heights', '259'),
#  ('Melrose', '793'),
#  ('High Bridge', '639'),
#  ('Wakefield', '638'),
#  ('Pelham Gardens', '637'),
#  ('Morris Heights', '637'),
#  ('Pelham Bay', '402'),
#  ('Co-op City', '339'),
#  ('South Bronx', '101'),
#  ('South Bronx', '175'),
#  ('Morris Heights', '638'),
#  ('South Bronx', '357'),
#  ('Fieldston', '380'),
#  ('Soundview', '916'),
#  ('Co-op City', '333'),
#  ('Tremont', '637'),
#  ('Throggs Neck', '254'),
#  ('University Heights', '338'),
#  ('East Tremont', '438'),
#  ('Soundview', '254'),
#  ('South Bronx', '639'),
#  ('Fordham', '386'),
#  ('Morris Heights', '113'),
#  ('South Bronx', '254'),
#  ('South Bronx', '254'),
#  ('Concourse', '638'),
#  ('South Bronx', '357'),
#  ('East Tremont', '338'),
#  ('High Bridge', '101'),
#  ('South Bronx', '357'),
#  ('Hunts Point', '101'),
#  ('High Bridge', '638'),
#  ('Fordham', '109'),
#  ('University Heights', '729'),
#  ('Williamsbridge', '638'),
#  ('Tremont', '637'),
#  ('Longwood', '638'),
#  ('University Heights', '205'),
#  ('Concourse', '198'),
#  ('Longwood', '254'),
#  ('Mott Haven', '339'),
#  ('Concourse', '397'),
#  ('Concourse', '638'),
#  ('Mott Haven', '637'),
#  ('Fordham', '109'),
#  ('Morris Park', '333'),
#  ('South Bronx', '258'),
#  ('South Bronx', '258'),
#  ('South Bronx', '258'),
#  ('South Bronx', '258'),
#  ('South Bronx', '258'),
#  ('Pelham Gardens', '922'),
#  ('Williamsbridge', '637'),
#  ('Concourse', '511'),
#  ('South Bronx', '258'),
#  ('Bedford Park', '639'),
#  ('Clason Point', '640'),
#  ('South Bronx', '175'),
#  ('South Bronx', '254'),
#  ('South Bronx', '254'),
#  ('Concourse', '198'),
#  ('Bedford Park', '639'),
#  ('Parkchester', '567'),
#  ('Morris Heights', '639'),
#  ('Pelham Gardens', '254'),
#  ('Van Nest', '254'),
#  ('Fieldston', '357'),
#  ('Concourse', '759'),
#  ('West Farms', '113'),
#  ('Longwood', '258'),
#  ('Longwood', '258'),
#  ('Longwood', '258'),
#  ('Longwood', '258'),
#  ('Bedford Park', '638'),
#  ('Longwood', '258'),
#  ('Soundview', '639'),
#  ('Longwood', '258'),
#  ('Mott Haven', '638'),
#  ('Co-op City', '254'),
#  ('Concourse', '259'),
#  ('Country Club', '113'),
#  ('Fordham', '267'),
#  ('Concourse', '109'),
#  ('Throggs Neck', '408'),
#  ('Concourse', '321'),
#  ('Soundview', '101'),
#  ('Pelham Bay', '391'),
#  ('East Tremont', '749'),
#  ('Longwood', '321'),
#  ('Pelham Bay', '511'),
#  ('East Tremont', '739'),
#  ('Castle Hill', '269'),
#  ('Williamsbridge', '638'),
#  ('South Bronx', '338'),
#  ('Concourse', '109'),
#  ('Belmont', '705'),
#  ('South Bronx', '113'),
#  ('Tremont', '338'),
#  ('High Bridge', '254'),
#  ('Tremont', '109'),
#  ('Williamsbridge', '321'),
#  ('South Bronx', '321'),
#  ('Throggs Neck', '638'),
#  ('Soundview', '705'),
#  ('Morris Park', '198'),
#  ('Williamsbridge', '638'),
#  ('Williamsbridge', '639'),
#  ('Pelham Gardens', '441'),
#  ('Tremont', '749'),
#  ('Mott Haven', '512'),
#  ('Mott Haven', '500'),
#  ('Mott Haven', '500'),
#  ('Mott Haven', '500'),
#  ('Morris Heights', '259'),
#  ('Concourse', '321'),
#  ('Williamsbridge', '419'),
#  ('Baychester', '213'),
#  ('Pelham Bay', '267'),
#  ('Morris Heights', '183'),
#  ('South Bronx', '321'),
#  ('Longwood', '333'),
#  ('Rikers Island', '289'),
#  ('Soundview', '101'),
#  ('Mott Haven', '338'),
#  ('Mott Haven', '500'),
#  ('Norwood', '638'),
#  ('Soundview', '339'),
#  ('Soundview', '640'),
#  ('Belmont', '410'),
#  ('Pelham Bay', '638'),
#  ('Williamsbridge', '905'),
#  ('Fordham', '254'),
#  ('Pelham Bay', '254'),
#  ('Longwood', '254'),
#  ('University Heights', '637'),
#  ('Norwood', '254'),
#  ('Parkchester', '101'),
#  ('South Bronx', '254'),
#  ('Concourse', '321'),
#  ('Van Nest', '321'),
#  ('Hunts Point', '339'),
#  ('Kingsbridge', '349'),
#  ('High Bridge', '254'),
#  ('Bedford Park', '254'),
#  ('Castle Hill', '638'),
#  ('Unionport', '441'),
#  ('Fordham', '438'),
#  ('Wakefield', '254'),
#  ('Mott Haven', '638'),
#  ('South Bronx', '269'),
#  ('Morris Heights', '638'),
#  ('Hunts Point', '357'),
#  ('Norwood', '254'),
#  ('South Bronx', '338'),
#  ('Longwood', '155'),
#  ('South Bronx', '243'),
#  ('Wakefield', '224'),
#  ('Fordham', '109'),
#  ('Melrose', '321'),
#  ('Kingsbridge', '639'),
#  ('Bedford Park', '321'),
#  ('Castle Hill', '101'),
#  ('Bedford Park', '321'),
#  ('South Bronx', '105'),
#  ('Norwood', '101'),
#  ('University Heights', '338'),
#  ('South Bronx', '109'),
#  ('North Riverdale', '338'),
#  ('Soundview', '338'),
#  ('Belmont', '191'),
#  ('Concourse', '638'),
#  ('Concourse', '338'),
#  ('Longwood', '321'),
#  ('Longwood', '638'),
#  ('Morris Heights', '637'),
#  ('Parkchester', '420'),
#  ('Wakefield', '748'),
#  ('High Bridge', '321'),
#  ('Fordham', '421'),
#  ('Throggs Neck', '420'),
#  ('Morris Heights', '639'),
#  ('Fordham', '339'),
#  ('Tremont', '177'),
#  ('Tremont', '181'),
#  ('High Bridge', '638'),
#  ('Rikers Island', '109'),
#  ('Melrose', '916'),
#  ('Tremont', '739'),
#  ('Mott Haven', '177'),
#  ('Williamsbridge', '113'),
#  ('Tremont', '259'),
#  ('Soundview', '567'),
#  ('Concourse', '101'),
#  ('South Bronx', '511'),
#  ('Morris Heights', '568'),
#  ('Mott Haven', '259'),
#  ('High Bridge', '637'),
#  ('Concourse', '638'),
#  ('North Riverdale', '267'),
#  ('Concourse', '333'),
#  ('Soundview', '637'),
#  ('Williamsbridge', '101'),
#  ('Hunts Point', '500'),
#  ('Soundview', '567'),
#  ('Soundview', '101'),
#  ('Morris Park', '637'),
#  ('Williamsbridge', '638'),
#  ('University Heights', '109'),
#  ('East Tremont', '637'),
#  ('Longwood', '404'),
#  ('Castle Hill', '113'),
#  ('Fordham', '438'),
#  ('Williamsbridge', '198'),
#  ('Fordham', '637'),
#  ('Kingsbridge', '500'),
#  ('Soundview', '638'),
#  ('Throggs Neck', '386'),
#  ('Mott Haven', '259'),
#  ('Longwood', '333'),
#  ('Unionport', '357'),
#  ('Soundview', '638'),
#  ('Throggs Neck', '343'),
#  ('Soundview', '101'),
#  ('Soundview', '259'),
#  ('Concourse', '729'),
#  ('University Heights', '638'),
#  ('Longwood', '782'),
#  ('Soundview', '101'),
#  ('Bedford Park', '101'),
#  ('Bedford Park', '101'),
#  ('Wakefield', '638'),
#  ('West Farms', '333'),
#  ('Soundview', '109'),
#  ('South Bronx', '101'),
#  ('Tremont', '109'),
#  ('Tremont', '101'),
#  ('Williamsbridge', '639'),
#  ('Throggs Neck', '637'),
#  ('University Heights', '638'),
#  ('Rikers Island', '759'),
#  ('Belmont', '503'),
#  ('Williamsbridge', '922'),
#  ('Melrose', '338'),
#  ('Williamsbridge', '637'),
#  ('Fordham', '333'),
#  ('Norwood', '638'),
#  ('Williamsbridge', '922'),
#  ('Williamsbridge', '782'),
#  ('High Bridge', '638'),
#  ('Tremont', '638'),
#  ('Concourse', '638'),
#  ('South Bronx', '175'),
#  ('Soundview', '638'),
#  ('Fordham', '638'),
#  ('Fordham', '569'),
#  ('Fordham', '333'),
#  ('Fordham', '333'),
#  ('Concourse', '782'),
#  ('Williamsbridge', '101'),
#  ('Fordham', '101'),
#  ('Morris Heights', '333'),
#  ('Melrose', '404'),
#  ('Morris Park', '922'),
#  ('Morris Park', '922'),
#  ('Bedford Park', '338'),
#  ('Soundview', '267'),
#  ('Throggs Neck', '259'),
#  ('University Heights', '782'),
#  ('Castle Hill', '333'),
#  ('Concourse', '333'),
#  ('Bedford Park', '259'),
#  ('Bedford Park', '782'),
#  ('Westchester Heights', '567'),
#  ('Westchester Heights', '782'),
#  ('Concourse', '101'),
#  ('Fordham', '339'),
#  ('East Tremont', '301'),
#  ('Concourse', '109'),
#  ('University Heights', '198'),
#  ('Concourse', '638'),
#  ('Fordham', '113'),
#  ('Morris Heights', '511'),
#  ('University Heights', '382'),
#  ('University Heights', '259'),
#  ('University Heights', '638'),
#  ('Concourse', '638'),
#  ('Melrose', '817'),
#  ('Bedford Park', '567'),
#  ('Mott Haven', '389'),
#  ('South Bronx', '511'),
#  ('Port Morris', '101'),
#  ('Parkchester', '433'),
#  ('Longwood', '382'),
#  ('Concourse', '109'),
#  ('Williamsbridge', '333'),
#  ('Concourse', '101'),
#  ('Longwood', '638'),
#  ('Tremont', '357'),
#  ('Fordham', '637'),
#  ('Concourse', '638'),
#  ('High Bridge', '729'),
#  ('Concourse', '259'),
#  ('Concourse', '409'),
#  ('Mott Haven', '339'),
#  ('South Bronx', '638'),
#  ('University Heights', '521'),
#  ('Concourse', '333'),
#  ('East Tremont', '231'),
#  ('University Heights', '521'),
#  ('Wakefield', '916'),
#  ('Concourse', '106'),
#  ('South Bronx', '109'),
#  ('Tremont', '638'),
#  ('Morris Park', '333'),
#  ('Fordham', '109'),
#  ('Fordham', '109'),
#  ('University Heights', '338'),
#  ('Morris Park', '101'),
#  ('Mott Haven', '500'),
#  ('Mott Haven', '333'),
#  ('South Bronx', '729'),
#  ('West Farms', '916'),
#  ('Fordham', '361'),
#  ('Fordham', '333'),
#  ('Mott Haven', '638'),
#  ('Concourse', '361'),
#  ('Williamsbridge', '462'),
#  ('Morris Park', '333'),
#  ('Fordham', '101'),
#  ('Mott Haven', '101'),
#  ('Morris Heights', '638'),
#  ('Fordham', '749'),
#  ('Longwood', '254'),
#  ('Soundview', '101'),
#  ('Soundview', '101'),
#  ('Pelham Gardens', '750'),
#  ('Soundview', '637'),
#  ('Morris Heights', '638'),
#  ('South Bronx', '638'),
#  ('Williamsbridge', '638'),
#  ('Melrose', '321'),
#  ('South Bronx', '338'),
#  ('Morris Park', '221'),
#  ('Parkchester', '878'),
#  ('Tremont', '638'),
#  ('Parkchester', '638'),
#  ('Mott Haven', '638'),
#  ('Melrose', '101'),
#  ('Hunts Point', '321'),
#  ('Pelham Gardens', '101'),
#  ('Williamsbridge', '707'),
#  ('University Heights', '511'),
#  ('South Bronx', '450'),
#  ('High Bridge', '905'),
#  ('Concourse', '209'),
#  ('Mott Haven', '254'),
#  ('Williamsbridge', '665'),
#  ('South Bronx', '213'),
#  ('Woodlawn', '321'),
#  ('Fordham', '905'),
#  ('Concourse', '209'),
#  ('Belmont', '638'),
#  ('South Bronx', '638'),
#  ('Bedford Park', '113'),
#  ('South Bronx', '388'),
#  ('Concourse', '117'),
#  ('Melrose', '209'),
#  ('Melrose', '494'),
#  ('Morris Heights', '793'),
#  ('Norwood', '101'),
#  ('Williamsbridge', '101'),
#  ('Concourse', '321'),
#  ('Williamsbridge', '254'),
#  ('Eastchester', '114'),
#  ('Williamsbridge', '421'),
#  ('Pelham Gardens', '792'),
#  ('Co-op City', '101'),
#  ('Williamsbridge', '101'),
#  ('Melrose', '109'),
#  ('University Heights', '101'),
#  ('Clason Point', '639'),
#  ('Westchester Heights', '338'),
#  ('Concourse', '254'),
#  ('Mott Haven', '254'),
#  ('Concourse', '254'),
#  ('Williamsbridge', '205'),
#  ('Baychester', '759'),
#  ('Williamsbridge', '113'),
#  ('South Bronx', '259'),
#  ('Norwood', '321'),
#  ('Williamsbridge', '339'),
#  ('Soundview', '321'),
#  ('Williamsbridge', '101'),
#  ('Concourse', '254'),
#  ('Riverdale', '421'),
#  ('Longwood', '338'),
#  ('Williamsbridge', '321'),
#  ('Mott Haven', '321'),
#  ('Fieldston', '267'),
#  ('Longwood', '338'),
#  ('Williamsbridge', '254'),
#  ('Mott Haven', '639'),
#  ('Bedford Park', '639'),
#  ('Melrose', '321'),
#  ('Melrose', '321'),
#  ('Mott Haven', '749'),
#  ('Tremont', '792'),
#  ('Morris Heights', '233'),
#  ('Fordham', '494'),
#  ('Country Club', '113'),
#  ('Soundview', '254'),
#  ('Soundview', '321'),
#  ('Morris Heights', '321'),
#  ('Morris Park', '438'),
#  ('Woodlawn', '254'),
#  ('Williamsbridge', '638'),
#  ('Longwood', '321'),
#  ('Concourse', '106'),
#  ('Wakefield', '637'),
#  ('Concourse', '264'),
#  ('Eastchester', '268'),
#  ('University Heights', '259'),
#  ('Kingsbridge', '333'),
#  ('Williamsbridge', '638'),
#  ('Parkchester', '638'),
#  ('Mott Haven', '639'),
#  ('West Farms', '339'),
#  ('Longwood', '638'),
#  ('Williamsbridge', '421'),
#  ('University Heights', '221'),
#  ('West Farms', '644'),
#  ('Fordham', '638'),
#  ('Kingsbridge', '343'),
#  ('Castle Hill', '259'),
#  ('Mott Haven', '221'),
#  ('Fordham', '338'),
#  ('Concourse', '254'),
#  ('Concourse', '339'),
#  ('South Bronx', '259'),
#  ('Riverdale', '441'),
#  ('Mott Haven', '321'),
#  ('Melrose', '438'),
#  ('Concourse', '739'),
#  ('Concourse', '254'),
#  ('West Farms', '338'),
#  ('Belmont', '749'),
#  ('East Tremont', '639'),
#  ('Clason Point', '349'),
#  ('Concourse', '321'),
#  ('Concourse', '793'),
#  ('Soundview', '424'),
#  ('Mott Haven', '639'),
#  ('Concourse', '109'),
#  ('North Riverdale', '114'),
#  ('Westchester Heights', '462'),
#  ('Melrose', '338'),
#  ('Fordham', '224'),
#  ('Morris Heights', '817'),
#  ('Williamsbridge', '637'),
#  ('South Bronx', '339'),
#  ('East Tremont', '264'),
#  ('Fordham', '748'),
#  ('Westchester Heights', '108'),
#  ('Parkchester', '638'),
#  ('Bedford Park', '638'),
#  ('North Riverdale', '303'),
#  ('Mott Haven', '639'),
#  ('Fordham', '223'),
#  ('Tremont', '175'),
#  ('Fordham', '101'),
#  ('South Bronx', '637'),
#  ('Longwood', '437'),
#  ('Fieldston', '115'),
#  ('South Bronx', '338'),
#  ('Mott Haven', '639'),
#  ('Concourse', '638'),
#  ('Tremont', '333'),
#  ('Fordham', '338'),
#  ('Mott Haven', '639'),
#  ('Concourse', '407'),
#  ('Longwood', '321'),
#  ('Kingsbridge', '254'),
#  ('Williamsbridge', '739'),
#  ('Concourse', '117'),
#  ('Williamsbridge', '233'),
#  ('Rikers Island', '759'),
#  ('Morris Park', '637'),
#  ('Rikers Island', '640'),
#  ('Concourse', '412'),
#  ('High Bridge', '718'),
#  ('East Tremont', '748'),
#  ('Longwood', '637'),
#  ('Williamsbridge', '101'),
#  ('Concourse', '333'),
#  ('Concourse', '333'),
#  ('University Heights', '639'),
#  ('Tremont', '101'),
#  ('Concourse', '441'),
#  ('Concourse', '638'),
#  ('Marble Hill', '638'),
#  ('South Bronx', '101'),
#  ('Unionport', '198'),
#  ('Mott Haven', '333'),
#  ('Tremont', '503'),
#  ('Melrose', '382'),
#  ('Morris Park', '922'),
#  ('Belmont', '638'),
#  ('Unionport', '338'),
#  ('Soundview', '567'),
#  ('South Bronx', '109'),
#  ('Belmont', '333'),
#  ('South Bronx', '175'),
#  ('University Heights', '567'),
#  ('Marble Hill', '639'),
#  ('Kingsbridge', '638'),
#  ('Soundview', '101'),
#  ('Castle Hill', '333'),
#  ('Concourse', '338'),
#  ('Throggs Neck', '101'),
#  ('Parkchester', '638'),
#  ('Norwood', '638'),
#  ('Woodlawn', '638'),
#  ('Bedford Park', '101'),
#  ('Norwood', '639'),
#  ('University Heights', '114'),
#  ('Pelham Bay', '748'),
#  ('Rikers Island', '759'),
#  ('East Tremont', '511'),
#  ('Concourse', '384'),
#  ('Concourse', '333'),
#  ('Concourse', '259'),
#  ('Williamsbridge', '638'),
#  ('Wakefield', '105'),
#  ('Morris Park', '339'),
#  ('Fordham', '905'),
#  ('Concourse', '259'),
#  ('Tremont', '175'),
#  ('Soundview', '566'),
#  ('Throggs Neck', '638'),
#  ('Mott Haven', '386'),
#  ('Concourse', '639'),
#  ('Concourse', '748'),
#  ('Tremont', '101'),
#  ('Tremont', '101'),
#  ('no neihborhood BRONX', '748'),
#  ('Westchester Heights', '729'),
#  ('West Farms', '259'),
#  ('Parkchester', '404'),
#  ('Soundview', '333'),
#  ('Mott Haven', '749'),
#  ('Concourse', '198'),
#  ('Fordham', '338'),
#  ('Melrose', '101'),
#  ('Soundview', '113'),
#  ('Rikers Island', '106'),
#  ('Concourse', '106'),
#  ('East Tremont', '793'),
#  ('Port Morris', '397'),
#  ('High Bridge', '109'),
#  ('Parkchester', '333'),
#  ('South Bronx', '113'),
#  ('Fordham', '339'),
#  ('Unionport', '383'),
#  ('Concourse', '264'),
#  ('Williamsbridge', '638'),
#  ('Concourse', '404'),
#  ('Co-op City', '101'),
#  ('Concourse', '333'),
#  ('Castle Hill', '333'),
#  ('Wakefield', '101'),
#  ('Tremont', '705'),
#  ('Mott Haven', '760'),
#  ('South Bronx', '101'),
#  ('Fieldston', '421'),
#  ('Wakefield', '101'),
#  ('Kingsbridge', '259'),
#  ('Morris Park', '113'),
#  ('North Riverdale', '321'),
#  ('Castle Hill', '333'),
#  ('Soundview', '109'),
#  ('South Bronx', '221'),
#  ('Morris Park', '638'),
#  ('Belmont', '101'),
#  ('Concourse', '333'),
#  ('Morris Heights', '521'),
#  ('Throggs Neck', '349'),
#  ('Morris Heights', '511'),
#  ('Soundview', '101'),
#  ('Tremont', '638'),
#  ('East Tremont', '339'),
#  ('Concourse', '101'),
#  ('East Tremont', '500'),
#  ('Bedford Park', '511'),
#  ('Mott Haven', '637'),
#  ('Norwood', '175'),
#  ('Soundview', '333'),
#  ('Concourse', '339'),
#  ('Concourse', '793'),
#  ('Concourse', '760'),
#  ('Fordham', '500'),
#  ('Port Morris', '638'),
#  ('Bedford Park', '109'),
#  ('Soundview', '638'),
#  ('Melrose', '490'),
#  ('Wakefield', '441'),
#  ('South Bronx', '259'),
#  ('Morris Park', '916'),
#  ('Hunts Point', '259'),
#  ('Concourse', '638'),
#  ('South Bronx', '221'),
#  ('Longwood', '258'),
#  ('South Bronx', '258'),
#  ('Eastchester', '782'),
#  ('East Tremont', '396'),
#  ('Pelham Gardens', '321'),
#  ('South Bronx', '101'),
#  ('Concourse', '638'),
#  ('Castle Hill', '101'),
#  ('Concourse', '101'),
#  ('Concourse', '117'),
#  ('Bedford Park', '338'),
#  ('Longwood', '922'),
#  ('Morris Park', '681'),
#  ('Parkchester', '397'),
#  ('Tremont', '221'),
#  ('Williamsbridge', '639'),
#  ('Concourse', '639'),
#  ('Soundview', '748'),
#  ('Soundview', '725'),
#  ('Throggs Neck', '638'),
#  ('Concourse', '170'),
#  ('South Bronx', '333'),
#  ('Soundview', '638'),
#  ('Parkchester', '749'),
#  ('Mott Haven', '638'),
#  ('Concourse', '638'),
#  ('South Bronx', '782'),
#  ('Tremont', '638'),
#  ('Williamsbridge', '639'),
#  ('Van Nest', '511'),
#  ('Kingsbridge', '254'),
#  ('Williamsbridge', '637'),
#  ('University Heights', '101'),
#  ('South Bronx', '792'),
#  ('Williamsbridge', '223'),
#  ('Williamsbridge', '157'),
#  ('High Bridge', '101'),
#  ('Morris Park', '922'),
#  ('Kingsbridge', '450'),
#  ('Melrose', '793'),
#  ('Concourse', '277'),
#  ('Melrose', '339'),
#  ('Morris Heights', '388'),
#  ('High Bridge', '259'),
#  ('Melrose', '321'),
#  ('Woodlawn', '223'),
#  ('Longwood', '321'),
#  ('Spuyten Duyvil', '350'),
#  ('Soundview', '267'),
#  ('South Bronx', '705'),
#  ('Tremont', '478'),
#  ('East Tremont', '113'),
#  ('Riverdale', '267'),
#  ('Williamsbridge', '490'),
#  ('Parkchester', '105'),
#  ('South Bronx', '254'),
#  ('Longwood', '213'),
#  ('Melrose', '254'),
#  ('Morris Park', '101'),
#  ('Williamsbridge', '101'),
#  ('Mott Haven', '101'),
#  ('Fordham', '101'),
#  ('East Tremont', '638'),
#  ('Soundview', '113'),
#  ('University Heights', '259'),
#  ('Melrose', '357'),
#  ('East Tremont', '748'),
#  ('Parkchester', '223'),
#  ('Baychester', '259'),
#  ('Morris Heights', '638'),
#  ('Unionport', '357'),
#  ('Norwood', '254'),
#  ('Melrose', '339'),
#  ('Norwood', '321'),
#  ('Morris Park', '637'),
#  ('Belmont', '259'),
#  ('South Bronx', '109'),
#  ('Longwood', '259'),
#  ('Longwood', '321'),
#  ('Port Morris', '638'),
#  ('High Bridge', '357'),
#  ('Fordham', '221'),
#  ('Soundview', '267'),
#  ('Kingsbridge', '258'),
#  ...]

# %%
G2.add_edges_from(edgelist)

# %%
# Premilinary visulaisation of bipartite graph.

nx.draw(G2, node_size=10, width=0.01)
plt.show()

# %%
print(nx.is_connected(G2))
# Out:
# True

# %%
nx.is_bipartite(G)
# Out:
# True

# %%
# Other visualisation of our Graph

from scipy.sparse import csc_matrix
import matplotlib.pyplot as plt
nx.draw_circular(G2, node_size=10, width=0.01)
#plt.savefig('network_all_intial_order_line_width_0.01_circular.PNG', dpi = 300)
plt.show()

# %%
# Better visualisation for our bipartite Graph.
# Are nodes are ordered by type of borough on the left, and type of crime on the right.
# However the nodes with the highest degree seems to be evenly distibuted in each category.

X, Y = bipartite.sets(G2)
pos = dict()
pos.update( (n, (1, i)) for i, n in enumerate(X) ) # put nodes from X at x=1
pos.update( (n, (2, i)) for i, n in enumerate(Y) ) # put nodes from Y at x=2
nx.draw(G2, pos=pos, node_size=10, width=0.001)
#plt.savefig("network_all_intial_order_line_width_0.001_paralell.PNG", dpi = 300)
plt.show()

# %% [markdown]
# ### Neighborhood proximity graph

# %% [markdown]
# Creating a graph where the nodes are the neighborhoods, and the edges are made with the 5 neareast neighborhoods.
# The five nearest neighborhood were choosen instead of the actual neighborhood touching a given neighborhood because we were not able to find a dataset providing this information. The only way would have been to create it manually from an online map, which would have lead to potential human errors.
#
# We choose the five closest neighborhood because when looking at a map, we noticed that on average a neighborhood in NYC touches 5 other neighborhoods.

# %%
# Uploading a file which is the dataGraph data which have been grouped by neighborhoods, 
# so that the GPS coordinate of a neighborhood are the average of the GPS coordinate of the crimes that
# occured in that neighborhood

data = np.array(list(csv.reader(open("C://Users//Rebecca//Desktop//nsa//final_project//Project-Network//Project Network//File for J2.csv", "r"), delimiter=",")))

# %%
# Creating the edge list of the 5 closest neighborhood of a given neighborhood

edges = []
data = data[1:]
for j in range(len(data)):
    distances = []
    for i in range(len(data)):
        distances.append(abs(float(data[j][0])-float(data[i][0])) + abs(float(data[j][1])-float(data[i][1])))
    sorted_indices = np.argsort(distances)
    edges.append((data[j][2],data[sorted_indices[1]][2]))
    edges.append((data[j][2],data[sorted_indices[2]][2]))
    edges.append((data[j][2],data[sorted_indices[3]][2]))
    edges.append((data[j][2],data[sorted_indices[4]][2]))
    edges.append((data[j][2],data[sorted_indices[5]][2]))

# %%
# Transforming our edge list in a panda dataframe

dfedges = pd.DataFrame(edges, columns=['N1', 'N2'])

# %%
# Loading the data for graph mentioned above, and transforming it into a panda dataframe

datapanda = pd.read_csv("C://Users//Rebecca//Desktop//nsa//final_project//Project-Network//Project Network//Data-for-graph.csv",delimiter =",")

# %%
# Getting rid of the crimes without GPS coordinates (negligeable: 0.001%)

datapanda= datapanda[datapanda.Neighborhood != 'no neihborhood QUEENS']
datapanda= datapanda[datapanda.Neighborhood !='no neihborhood MANHATTAN']
datapanda= datapanda[datapanda.Neighborhood !='no neihborhood BRONX']
datapanda= datapanda[datapanda.Neighborhood !='no neihborhood STATEN ISLAND']
datapanda= datapanda[datapanda.Neighborhood !='no neihborhood BROOKLYN']

# %%
datapanda.head()
# Out:
#    Longitude   Latitude Neighborhood  PD_CD                         PD_DESC  \
# 0 -73.769745  40.683786   St. Albans  637.0      HARASSMENT,SUBD 1,CIVILIAN
# 2 -73.953117  40.726965   Greenpoint  478.0  THEFT OF SERVICES, UNCLASSIFIE
# 3 -73.897849  40.824519     Longwood  567.0     MARIJUANA, POSSESSION 4 & 5
# 4 -73.867003  40.822552    Soundview  114.0             OBSTR BREATH/CIRCUL
# 5 -73.891225  40.712362      Maspeth  905.0     INTOXICATED DRIVING,ALCOHOL
#
#     BORO_NM
# 0    QUEENS
# 2  BROOKLYN
# 3     BRONX
# 4     BRONX
# 5    QUEENS

# %%
datapanda.count()
# Out:
# Longitude       228636
# Latitude        228636
# Neighborhood    228636
# PD_CD           228488
# PD_DESC         228488
# BORO_NM         228486
# dtype: int64

# %%
# Grouping our dataframe per neighborhood to obtain the number of crimes per neighborhood through our time period

nbcrimenei = datapanda.groupby('Neighborhood').count()

# %%
# Dropping unnecessary columns

nbcrimenei = nbcrimenei.drop(columns = ["Latitude", "PD_CD", "PD_DESC", "BORO_NM"])

# %%
# The column Longitude actually is now the number of crime per neighborhood

nbcrimenei.reset_index(level=0, inplace=True)
nbcrimenei.head()
# Out:
#     Neighborhood  Longitude
# 0       Annadale         78
# 1  Arden Heights        105
# 2       Arrochar        239
# 3        Arverne        320
# 4        Astoria       3550

# %%
# Sorting the neighborhood by order of crime rate for visualisation purpose.

m = nbcrimenei.sort_values(by = 'Longitude')
m.head()
# Out:
#            Neighborhood  Longitude
# 93          Fresh Kills          2
# 126     Jacob Riis Park          2
# 161           Navy Yard          2
# 211             Roxbury          3
# 135  La Guardia Airport          4

# %%
# Plotting an histogram

nbcrimenei.hist(bins = 30)
plt.show()

# %%
# Plotting the number of crimes per neighborhood
x = list(m['Neighborhood'])
y = list(m['Longitude'])
plt.scatter(x, y)
plt.show()

# We identify 5 different group from this graph

# %%
# Renaming our columns

nbcrimenei = nbcrimenei.rename(index=str, columns={"index": "index", "Neighborhood": "Neighborhood", "Longitude": "NB Crime"})

# %%
# Assigning the crime group to each neighborhood from 5(extremely dangerous) to 1(totally safe)

# Create a list to store the data
crime_sc = []

# For each row in the column,
for row in nbcrimenei['NB Crime']:
    # if more than a value,
    if row > 5000:
        # Append a crime score
        crime_sc.append(5)
    # else, if more than a value,
    elif row > 2500:
        # Append a crime score
        crime_sc.append(4)
    # else, if more than a value,
    elif row > 1000:
        # Append a crime score
        crime_sc.append(3)
    # else, if more than a value,
    elif row > 250:
        # Append a crime score
        crime_sc.append(2)
    # else, if more than a value,
    else:
        # Append a crime score
        crime_sc.append(1)
        
# Create a column from the list
nbcrimenei['Crime Score'] = crime_sc

# %%
nbcrimenei.head()
# Out:
#     Neighborhood  NB Crime  Crime Score
# 0       Annadale        78            1
# 1  Arden Heights       105            1
# 2       Arrochar       239            1
# 3        Arverne       320            2
# 4        Astoria      3550            4

# %%
#Saving the node list ordered in alphabetical order

F = open("nodes.csv", 'w')
for r in range(len(nbcrimenei["Neighborhood"])):
    line = str(nbcrimenei["Neighborhood"][r]) + "\n"
    F.write(line)
F.close()

# %%
# Creating a color maping of the crime levels of neighborhood (in alphabetical order) for visualisation

color_map = []
for node in nbcrimenei["Crime Score"] :
    if node == 5:
        color_map.append('red')
    elif node == 4:
        color_map.append('orange')
    elif node == 3:
        color_map.append('yellow')
    elif node == 2:
        color_map.append('green')
    else: color_map.append('blue')

# %%
# Saving our color_map

F = open("color_map.csv", 'w')
for r in color_map:
    line = str(r) + "\n"
    F.write(line)
F.close()

# %%
# Finding out how many neighborhood per crime levels

nbcrimenei.groupby('Crime Score').count()
# Out:
#              Neighborhood  NB Crime
# Crime Score
# 1                     102       102
# 2                      88        88
# 3                      48        48
# 4                      19        19
# 5                       4         4

# %%
#crime_sc = nbcrimenei.drop(columns = ["index"])
crime_sc = nbcrimenei

# %%
# Merging our edge list of close neighbors with our crime rate for edges selection later on

dfedges = dfedges.merge(crime_sc, left_on='N1', right_on='Neighborhood', how = 'left', suffixes=('', '_N1'), copy='True')

dfedges = dfedges.merge(crime_sc, left_on='N2', right_on='Neighborhood', how = 'left', suffixes=('', '_N2'),copy='True')

# %%
# The new dataframe

dfedges.head()
# Out:
#          N1            N2 Neighborhood  NB Crime  Crime Score Neighborhood_N2  \
# 0  Longwood   Hunts Point     Longwood    2166.0          3.0     Hunts Point
# 1  Longwood   South Bronx     Longwood    2166.0          3.0     South Bronx
# 2  Longwood       Melrose     Longwood    2166.0          3.0         Melrose
# 3  Longwood     Soundview     Longwood    2166.0          3.0       Soundview
# 4  Longwood  East Tremont     Longwood    2166.0          3.0    East Tremont
#
#    NB Crime_N2  Crime Score_N2
# 0        664.0             2.0
# 1       4450.0             4.0
# 2       2459.0             3.0
# 3       3010.0             4.0
# 4       1580.0             3.0

# %%
# Finding out the difference in crime level between two close neighborhood

dfedges["Edge score"] = dfedges["Crime Score"] - dfedges["Crime Score_N2"]

dfedges["Edge score"] = dfedges["Edge score"].abs()

# %%
dfedges.shape
# Out:
# (1310, 9)

# %%
len(edges)
# Out:
# 1310

# %%
dfedges.head()
# Out:
#          N1            N2 Neighborhood  NB Crime  Crime Score Neighborhood_N2  \
# 0  Longwood   Hunts Point     Longwood    2166.0          3.0     Hunts Point
# 1  Longwood   South Bronx     Longwood    2166.0          3.0     South Bronx
# 2  Longwood       Melrose     Longwood    2166.0          3.0         Melrose
# 3  Longwood     Soundview     Longwood    2166.0          3.0       Soundview
# 4  Longwood  East Tremont     Longwood    2166.0          3.0    East Tremont
#
#    NB Crime_N2  Crime Score_N2  Edge score
# 0        664.0             2.0         1.0
# 1       4450.0             4.0         1.0
# 2       2459.0             3.0         0.0
# 3       3010.0             4.0         1.0
# 4       1580.0             3.0         0.0

# %% [markdown]
# We now create different edges lists with the information put together

# %%
# Edges for close neighborhood if their crime level difference is 0 or 1

newedges = []
for i in range(dfedges.shape[0]):
    if dfedges.loc[i, "Edge score"] < 2:
        newedges.append((dfedges.loc[i, "N1"],dfedges.loc[i, "N2"]))

# %%
# Edges for close neighborhood if their crime level difference is 0 or 1
# And no edges with crime level 1 (safe) neighborhoods

newedges1no0 = []
for i in range(dfedges.shape[0]):
    if dfedges.loc[i, "Edge score"] < 2:
        if dfedges.loc[i, "Crime Score"] >1:
            if dfedges.loc[i, "Crime Score_N2"] >1:
                newedges1no0.append((dfedges.loc[i, "N1"],dfedges.loc[i, "N2"]))

# %%
# Edges for close neighborhood if their crime level difference is 0 or 1
# And no edges with crime level 1 and 2 (safe and low criminality) neighborhoods

newedges1no01 = []
for i in range(dfedges.shape[0]):
    if dfedges.loc[i, "Edge score"] < 2:
        if dfedges.loc[i, "Crime Score"] >2:
            if dfedges.loc[i, "Crime Score_N2"] >2:
                newedges1no01.append((dfedges.loc[i, "N1"],dfedges.loc[i, "N2"]))

# %%
# Edges for close neighborhood if their crime level difference is 0

newedges0 = []
for i in range(dfedges.shape[0]):
    if dfedges.loc[i, "Edge score"] == 0:
        newedges0.append((dfedges.loc[i, "N1"],dfedges.loc[i, "N2"]))

# %%
# Connection of all the safe neighborhoods with safe or low criminality neighborhoods (level 1 and 2)

newedgessafe = []
for i in range(dfedges.shape[0]):
    if dfedges.loc[i, "Edge score"] < 2:
        if dfedges.loc[i, "Crime Score"] ==1:
            newedgessafe.append((dfedges.loc[i, "N1"],dfedges.loc[i, "N2"]))
        elif dfedges.loc[i, "Crime Score_N2"] ==1:
            newedgessafe.append((dfedges.loc[i, "N1"],dfedges.loc[i, "N2"]))

# %%
# Connection of all the safe neighborhoods with all their neighbors

newedgessafeNR = []
for i in range(dfedges.shape[0]):
    if dfedges.loc[i, "Crime Score"] ==1:
        newedgessafeNR.append((dfedges.loc[i, "N1"],dfedges.loc[i, "N2"]))
    elif dfedges.loc[i, "Crime Score_N2"] ==1:
        newedgessafeNR.append((dfedges.loc[i, "N1"],dfedges.loc[i, "N2"]))

# %%
# Saving our newedges list

F = open("newedges.csv", 'w')
for r in newedges:
    line = str(r[0]) + "," + str(r[1]) + "\n"
    F.write(line)
F.close()

# %%
#Selecting nodes

nodes = list(nbcrimenei["Neighborhood"])
nodes
# Out:
# ['Annadale',
#  'Arden Heights',
#  'Arrochar',
#  'Arverne',
#  'Astoria',
#  'Astoria Heights',
#  'Auburndale',
#  'Bath Beach',
#  'Battery Park',
#  'Bay Ridge',
#  'Bay Terrace',
#  'Baychester',
#  'Bayside',
#  'Bedford Park',
#  'Bedford Stuyvesant',
#  'Belle Harbor',
#  'Bellerose',
#  'Belmont',
#  'Bensonhurst',
#  'Bergen Beach',
#  'Blissville',
#  'Bloomfield',
#  'Boerum Hill',
#  'Borough Park',
#  'Breezy Point',
#  'Briarwood',
#  'Brighton Beach',
#  'Broad Channel',
#  'Bronx Park',
#  'Brooklyn Heights',
#  'Brownsville',
#  'Bulls Head',
#  'Bushwick',
#  'Butler Manor',
#  'Cambria Heights',
#  'Canarsie',
#  'Carnegie Hill',
#  'Carroll Gardens',
#  'Castle Hill',
#  'Castleton Corners',
#  'Central Park',
#  'Charleston',
#  'Chelsea',
#  'Chelsea-Travis',
#  'Chinatown',
#  'City Island',
#  'Clason Point',
#  'Clifton',
#  'Clinton',
#  'Clinton Hill',
#  'Clove Lake',
#  'Co-op City',
#  'Cobble Hill',
#  'College Point',
#  'Columbia Street Waterfront District',
#  'Columbus Circle',
#  'Concourse',
#  'Coney Island',
#  'Corona',
#  'Country Club',
#  'Crown Heights',
#  'DUMBO',
#  'Dongan Hills',
#  'Douglaston-Little Neck',
#  'Downtown',
#  'Dyker Heights',
#  'East Elmhurst',
#  'East Flatbush',
#  'East Harlem',
#  'East New York',
#  'East Tremont',
#  'East Village',
#  'Eastchester',
#  'Elm Park',
#  'Elmhurst',
#  'Eltingville',
#  'Emerson Hill',
#  'Far Rockaway',
#  'Fieldston',
#  'Financial District',
#  'Flatbush',
#  'Flatiron District',
#  'Flatlands',
#  'Floral park',
#  'Floyd Bennett Field',
#  'Flushing',
#  'Flushing Meadows Corona Park',
#  'Fordham',
#  'Forest Hills',
#  'Forest Hills Gardens',
#  'Fort Greene',
#  'Fort Hamilton',
#  'Fort Wadsworth',
#  'Fresh Kills',
#  'Fresh Meadows',
#  'Garment District',
#  'Georgetown',
#  'Gerritsen Beach',
#  'Glen Oaks',
#  'Glendale',
#  'Gowanus',
#  'Gramercy',
#  'Graniteville',
#  'Grant City',
#  'Grasmere - Concord',
#  'Gravesend',
#  'Great Kills',
#  'Greenpoint',
#  'Greenridge',
#  'Greenwich Village',
#  'Greenwood',
#  'Grymes Hill',
#  'Hamilton Heights',
#  'Harlem',
#  'Heartland Village',
#  'High Bridge',
#  'Hillcrest',
#  'Hollis',
#  'Holliswood',
#  'Homecrest',
#  'Howard Beach',
#  'Huguenot',
#  'Hunters Point',
#  'Hunts Point',
#  'Inwood',
#  'Jackson Heights',
#  'Jacob Riis Park',
#  'Jamaica',
#  'Jamaica Estates',
#  'Jamaica Hills',
#  'John F. Kennedy International Airport',
#  'Kensington',
#  'Kew Gardens',
#  'Kew Gardens Hills',
#  'Kingsbridge',
#  'La Guardia Airport',
#  'La Tourette Park',
#  'Laurelton',
#  'Lighthouse Hill',
#  'Little Italy',
#  'Longwood',
#  'Lower East Side',
#  'Malba',
#  'Manhattan Beach',
#  'Manhattanville',
#  'Marble Hill',
#  'Marine Park',
#  "Mariner's Harbor",
#  'Maspeth',
#  'Meiers Corners',
#  'Melrose',
#  'Middle Village',
#  'Midland Beach',
#  'Midtown',
#  'Midwood',
#  'Mill Basin',
#  'Morningside Heights',
#  'Morris Heights',
#  'Morris Park',
#  'Mott Haven',
#  'Murray Hill',
#  'Navy Yard',
#  'Neponsit',
#  'New Brighton',
#  'New Dorp',
#  'New Dorp Beach',
#  'New Springville',
#  'New Utrecht',
#  'NoHo',
#  'North Riverdale',
#  'Norwood',
#  'Oakland Gardens',
#  'Oakwood',
#  'Ocean Hill',
#  'Ocean Parkway',
#  'Old Town',
#  'Ozone Park',
#  'Park Hill',
#  'Park Slope',
#  'Parkchester',
#  'Pelham Bay',
#  'Pelham Bay Park',
#  'Pelham Gardens',
#  'Pleasant Plains',
#  'Pomonok',
#  'Port Ivory',
#  'Port Morris',
#  'Port Richmond',
#  "Prince's Bay",
#  'Prospect Heights',
#  'Prospect Lefferts Gardens',
#  'Prospect Park',
#  'Prospect Park South',
#  'Queens Village',
#  'Randall Manor',
#  'Randals-Wards Island',
#  'Red Hook',
#  'Rego Park',
#  'Richmond Hill',
#  'Richmond Town',
#  'Richmond Valley',
#  'Ridgewood',
#  'Rikers Island',
#  'Riverdale',
#  'Rochdale',
#  'Rockaway Beach',
#  'Rockaway Park',
#  'Roosevelt Island',
#  'Rosebank',
#  'Rosedale',
#  'Rossville',
#  'Roxbury',
#  'Sheepshead Bay',
#  'Silver Lake',
#  'SoHo',
#  'Soundview',
#  'South Beach',
#  'South Bronx',
#  'South Ozone Park',
#  'Springfield Gardens',
#  'Spuyten Duyvil',
#  'St. Albans',
#  'St. George',
#  'Stapleton',
#  'Stuyvesant Town',
#  'Sunnyside',
#  'Sunset Park',
#  'Sutton Place',
#  'Throggs Neck',
#  'Todt Hill',
#  'Tompkinsville',
#  'Tottenville',
#  'Tremont',
#  'Tribeca',
#  'Tudor City',
#  'Turtle Bay',
#  'Unionport',
#  'University Heights',
#  'Upper East Side',
#  'Upper West Side',
#  'Utopia',
#  'Van Cortlandt Park',
#  'Van Nest',
#  'Vinegar Hill',
#  'Wakefield',
#  'Washington Heights',
#  'West Brighton',
#  'West Farms',
#  'West Village',
#  'Westchester Heights',
#  'Westerleigh',
#  'Whitestone',
#  'Williamsbridge',
#  'Williamsburg',
#  'Willowbrook',
#  'Windsor Terrace',
#  'Wingate',
#  'Woodhaven',
#  'Woodlawn',
#  'Woodrow',
#  'Woodside']

# %%
# Creating G1, our graph with edges depending on closeness and crime level similarities

G1 = nx.Graph()
G1.add_nodes_from(nodes)
G1.add_edges_from(newedges)

# %%
nx.draw(G1,node_size=20,font_size=8, node_color = color_map)
#plt.savefig("plotsafeNR.PNG",dpi=300)

# %%
cc=nx.number_connected_components(G1) #1
gcc=nx.connected_components(G1)
cc, gcc
# Out:
# (3, <generator object connected_components at 0x000001F884037DB0>)

# %%
newedges
# Out:
# [('Longwood', 'Hunts Point'),
#  ('Longwood', 'South Bronx'),
#  ('Longwood', 'Melrose'),
#  ('Longwood', 'Soundview'),
#  ('Longwood', 'East Tremont'),
#  ('South Bronx', 'Longwood'),
#  ('South Bronx', 'Concourse'),
#  ('South Bronx', 'Tremont'),
#  ('South Bronx', 'East Tremont'),
#  ('South Bronx', 'Melrose'),
#  ('High Bridge', 'Concourse'),
#  ('High Bridge', 'Morris Heights'),
#  ('High Bridge', 'Washington Heights'),
#  ('High Bridge', 'South Bronx'),
#  ('High Bridge', 'Melrose'),
#  ('University Heights', 'Fordham'),
#  ('University Heights', 'Tremont'),
#  ('University Heights', 'Marble Hill'),
#  ('University Heights', 'Inwood'),
#  ('University Heights', 'Kingsbridge'),
#  ('Williamsbridge', 'Norwood'),
#  ('Williamsbridge', 'Morris Park'),
#  ('Tremont', 'University Heights'),
#  ('Tremont', 'Morris Heights'),
#  ('Tremont', 'East Tremont'),
#  ('Tremont', 'Fordham'),
#  ('Tremont', 'Belmont'),
#  ('Parkchester', 'Van Nest'),
#  ('Parkchester', 'Unionport'),
#  ('Parkchester', 'Westchester Heights'),
#  ('Parkchester', 'Morris Park'),
#  ('Morris Heights', 'Tremont'),
#  ('Morris Heights', 'Concourse'),
#  ('Morris Heights', 'High Bridge'),
#  ('Morris Heights', 'Inwood'),
#  ('Morris Heights', 'Washington Heights'),
#  ('Morris Park', 'Van Nest'),
#  ('Morris Park', 'Parkchester'),
#  ('Morris Park', 'Westchester Heights'),
#  ('Morris Park', 'Pelham Gardens'),
#  ('Morris Park', 'Unionport'),
#  ('Concourse', 'High Bridge'),
#  ('Concourse', 'Morris Heights'),
#  ('Concourse', 'South Bronx'),
#  ('Concourse', 'Melrose'),
#  ('Concourse', 'Mott Haven'),
#  ('Fordham', 'University Heights'),
#  ('Fordham', 'Belmont'),
#  ('Fordham', 'Bedford Park'),
#  ('Fordham', 'East Tremont'),
#  ('Fordham', 'Tremont'),
#  ('Van Nest', 'Parkchester'),
#  ('Van Nest', 'West Farms'),
#  ('Van Nest', 'Morris Park'),
#  ('Van Nest', 'Bronx Park'),
#  ('Norwood', 'Bedford Park'),
#  ('Norwood', 'Williamsbridge'),
#  ('Norwood', 'Belmont'),
#  ('Bedford Park', 'Norwood'),
#  ('Bedford Park', 'Fordham'),
#  ('Bedford Park', 'Belmont'),
#  ('Bedford Park', 'Kingsbridge'),
#  ('Bedford Park', 'Marble Hill'),
#  ('Wakefield', 'Williamsbridge'),
#  ('Wakefield', 'Eastchester'),
#  ('Wakefield', 'Baychester'),
#  ('Wakefield', 'Pelham Gardens'),
#  ('East Tremont', 'Belmont'),
#  ('East Tremont', 'Tremont'),
#  ('East Tremont', 'West Farms'),
#  ('East Tremont', 'Fordham'),
#  ('Melrose', 'Mott Haven'),
#  ('Melrose', 'Port Morris'),
#  ('Melrose', 'Concourse'),
#  ('Melrose', 'Longwood'),
#  ('Melrose', 'South Bronx'),
#  ('Mott Haven', 'Melrose'),
#  ('Mott Haven', 'Concourse'),
#  ('Mott Haven', 'Harlem'),
#  ('West Farms', 'Bronx Park'),
#  ('West Farms', 'Van Nest'),
#  ('West Farms', 'East Tremont'),
#  ('West Farms', 'Belmont'),
#  ('West Farms', 'Parkchester'),
#  ('Eastchester', 'Co-op City'),
#  ('Eastchester', 'Baychester'),
#  ('Eastchester', 'Wakefield'),
#  ('Eastchester', 'Pelham Bay Park'),
#  ('Eastchester', 'Pelham Gardens'),
#  ('Co-op City', 'Pelham Bay Park'),
#  ('Co-op City', 'Baychester'),
#  ('Co-op City', 'Eastchester'),
#  ('Co-op City', 'Pelham Gardens'),
#  ('Co-op City', 'Pelham Bay'),
#  ('Pelham Bay', 'Country Club'),
#  ('Pelham Bay', 'Westchester Heights'),
#  ('Pelham Bay', 'Throggs Neck'),
#  ('Pelham Bay', 'Unionport'),
#  ('Pelham Bay', 'Co-op City'),
#  ('Throggs Neck', 'Pelham Bay'),
#  ('Throggs Neck', 'Castle Hill'),
#  ('Throggs Neck', 'Unionport'),
#  ('Kingsbridge', 'Marble Hill'),
#  ('Kingsbridge', 'Riverdale'),
#  ('Kingsbridge', 'Spuyten Duyvil'),
#  ('Kingsbridge', 'Fieldston'),
#  ('Kingsbridge', 'University Heights'),
#  ('Hunts Point', 'Longwood'),
#  ('Hunts Point', 'Rikers Island'),
#  ('Hunts Point', 'Melrose'),
#  ('City Island', 'Country Club'),
#  ('City Island', 'Pelham Bay'),
#  ('City Island', 'Pelham Bay Park'),
#  ('City Island', 'Co-op City'),
#  ('Pelham Gardens', 'Baychester'),
#  ('Pelham Gardens', 'Morris Park'),
#  ('Pelham Gardens', 'Co-op City'),
#  ('Pelham Gardens', 'Westchester Heights'),
#  ('Unionport', 'Castle Hill'),
#  ('Unionport', 'Westchester Heights'),
#  ('Unionport', 'Parkchester'),
#  ('Unionport', 'Clason Point'),
#  ('Belmont', 'Bronx Park'),
#  ('Belmont', 'East Tremont'),
#  ('Belmont', 'Fordham'),
#  ('Belmont', 'Bedford Park'),
#  ('Belmont', 'West Farms'),
#  ('Port Morris', 'Melrose'),
#  ('Port Morris', 'Randals-Wards Island'),
#  ('Baychester', 'Pelham Gardens'),
#  ('Baychester', 'Co-op City'),
#  ('Baychester', 'Eastchester'),
#  ('Baychester', 'Pelham Bay Park'),
#  ('Marble Hill', 'Kingsbridge'),
#  ('Marble Hill', 'Spuyten Duyvil'),
#  ('Marble Hill', 'University Heights'),
#  ('Marble Hill', 'Riverdale'),
#  ('Marble Hill', 'Inwood'),
#  ('Castle Hill', 'Unionport'),
#  ('Castle Hill', 'Clason Point'),
#  ('Castle Hill', 'Westchester Heights'),
#  ('Castle Hill', 'Parkchester'),
#  ('Fieldston', 'Riverdale'),
#  ('Fieldston', 'Van Cortlandt Park'),
#  ('Fieldston', 'North Riverdale'),
#  ('Fieldston', 'Kingsbridge'),
#  ('Fieldston', 'Spuyten Duyvil'),
#  ('Clason Point', 'Castle Hill'),
#  ('Clason Point', 'Unionport'),
#  ('Clason Point', 'Parkchester'),
#  ('Clason Point', 'Hunts Point'),
#  ('Country Club', 'Pelham Bay'),
#  ('Country Club', 'Pelham Bay Park'),
#  ('Country Club', 'Westchester Heights'),
#  ('Country Club', 'Co-op City'),
#  ('Rikers Island', 'La Guardia Airport'),
#  ('Rikers Island', 'Hunts Point'),
#  ('Rikers Island', 'Astoria Heights'),
#  ('Rikers Island', 'Murray Hill'),
#  ('Rikers Island', 'East Elmhurst'),
#  ('North Riverdale', 'Fieldston'),
#  ('North Riverdale', 'Riverdale'),
#  ('North Riverdale', 'Van Cortlandt Park'),
#  ('North Riverdale', 'Kingsbridge'),
#  ('North Riverdale', 'Spuyten Duyvil'),
#  ('Westchester Heights', 'Unionport'),
#  ('Westchester Heights', 'Parkchester'),
#  ('Westchester Heights', 'Pelham Bay'),
#  ('Westchester Heights', 'Morris Park'),
#  ('Westchester Heights', 'Castle Hill'),
#  ('Woodlawn', 'Van Cortlandt Park'),
#  ('Woodlawn', 'Fieldston'),
#  ('Riverdale', 'Fieldston'),
#  ('Riverdale', 'Spuyten Duyvil'),
#  ('Riverdale', 'Kingsbridge'),
#  ('Riverdale', 'Marble Hill'),
#  ('Riverdale', 'Van Cortlandt Park'),
#  ('Spuyten Duyvil', 'Marble Hill'),
#  ('Spuyten Duyvil', 'Riverdale'),
#  ('Spuyten Duyvil', 'Kingsbridge'),
#  ('Spuyten Duyvil', 'Fieldston'),
#  ('Washington Heights', 'High Bridge'),
#  ('Washington Heights', 'Morris Heights'),
#  ('Washington Heights', 'Concourse'),
#  ('Washington Heights', 'Hamilton Heights'),
#  ('Washington Heights', 'Inwood'),
#  ('Van Cortlandt Park', 'Fieldston'),
#  ('Van Cortlandt Park', 'Riverdale'),
#  ('Van Cortlandt Park', 'Woodlawn'),
#  ('Van Cortlandt Park', 'North Riverdale'),
#  ('Pelham Bay Park', 'Co-op City'),
#  ('Pelham Bay Park', 'Country Club'),
#  ('Pelham Bay Park', 'Pelham Gardens'),
#  ('Pelham Bay Park', 'Baychester'),
#  ('Pelham Bay Park', 'Eastchester'),
#  ('Bronx Park', 'Belmont'),
#  ('Bronx Park', 'West Farms'),
#  ('East New York', 'Brownsville'),
#  ('Brownsville', 'Ocean Hill'),
#  ('Brownsville', 'East New York'),
#  ('Brownsville', 'East Flatbush'),
#  ('Brownsville', 'Canarsie'),
#  ('Bedford Stuyvesant', 'Crown Heights'),
#  ('Bedford Stuyvesant', 'Williamsburg'),
#  ('Bedford Stuyvesant', 'Bushwick'),
#  ('East Harlem', 'Harlem'),
#  ('Crown Heights', 'Bedford Stuyvesant'),
#  ('Crown Heights', 'East Flatbush'),
#  ('Canarsie', 'Brownsville'),
#  ('Canarsie', 'Flatlands'),
#  ('Canarsie', 'East Flatbush'),
#  ('Greenpoint', 'Hunters Point'),
#  ('Greenpoint', 'Blissville'),
#  ('Greenpoint', 'Stuyvesant Town'),
#  ('Greenpoint', 'Sunnyside'),
#  ('Williamsburg', 'Bedford Stuyvesant'),
#  ('Sheepshead Bay', 'Homecrest'),
#  ('Sheepshead Bay', 'Marine Park'),
#  ('Sheepshead Bay', 'Gravesend'),
#  ('Bath Beach', 'Bensonhurst'),
#  ('Bath Beach', 'Gravesend'),
#  ('Bath Beach', 'Coney Island'),
#  ('Bath Beach', 'Borough Park'),
#  ('Flatlands', 'Marine Park'),
#  ('Flatlands', 'East Flatbush'),
#  ('Flatlands', 'Mill Basin'),
#  ('Flatlands', 'Midwood'),
#  ('Bushwick', 'Ridgewood'),
#  ('Bushwick', 'Ocean Hill'),
#  ('Bushwick', 'Bedford Stuyvesant'),
#  ('Bushwick', 'Brownsville'),
#  ('East Flatbush', 'Flatlands'),
#  ('East Flatbush', 'Crown Heights'),
#  ('East Flatbush', 'Brownsville'),
#  ('Greenwood', 'Carroll Gardens'),
#  ('Greenwood', 'Red Hook'),
#  ('Greenwood', 'Windsor Terrace'),
#  ('Greenwood', 'Sunset Park'),
#  ('Greenwood', 'Gowanus'),
#  ('Fort Greene', 'Downtown'),
#  ('Fort Greene', 'Boerum Hill'),
#  ('Fort Greene', 'Clinton Hill'),
#  ('Kensington', 'Prospect Park South'),
#  ('Kensington', 'Windsor Terrace'),
#  ('Kensington', 'Ocean Parkway'),
#  ('Kensington', 'Borough Park'),
#  ('Prospect Heights', 'Park Slope'),
#  ('Prospect Heights', 'Clinton Hill'),
#  ('Prospect Heights', 'Gowanus'),
#  ('Prospect Heights', 'Prospect Park'),
#  ('Prospect Heights', 'Fort Greene'),
#  ('Mill Basin', 'Georgetown'),
#  ('Mill Basin', 'Marine Park'),
#  ('Mill Basin', 'Bergen Beach'),
#  ('Mill Basin', 'Flatlands'),
#  ('Mill Basin', 'Gerritsen Beach'),
#  ('Downtown', 'Boerum Hill'),
#  ('Downtown', 'Fort Greene'),
#  ('Downtown', 'Brooklyn Heights'),
#  ('Coney Island', 'Brighton Beach'),
#  ('Coney Island', 'Bath Beach'),
#  ('Coney Island', 'Gravesend'),
#  ('Coney Island', 'Bensonhurst'),
#  ('Park Slope', 'Gowanus'),
#  ('Park Slope', 'Prospect Heights'),
#  ('Park Slope', 'Boerum Hill'),
#  ('Park Slope', 'Fort Greene'),
#  ('Wingate', 'Prospect Lefferts Gardens'),
#  ('Wingate', 'Prospect Park'),
#  ('Prospect Lefferts Gardens', 'Prospect Park'),
#  ('Prospect Lefferts Gardens', 'Wingate'),
#  ('Prospect Lefferts Gardens', 'Prospect Park South'),
#  ('Ridgewood', 'Bushwick'),
#  ('Ridgewood', 'Maspeth'),
#  ('Ridgewood', 'Glendale'),
#  ('Ridgewood', 'Ocean Hill'),
#  ('Carroll Gardens', 'Cobble Hill'),
#  ('Carroll Gardens', 'Columbia Street Waterfront District'),
#  ('Carroll Gardens', 'Gowanus'),
#  ('Carroll Gardens', 'Red Hook'),
#  ('Carroll Gardens', 'Boerum Hill'),
#  ('Windsor Terrace', 'Prospect Park South'),
#  ('Windsor Terrace', 'Kensington'),
#  ('Windsor Terrace', 'Prospect Park'),
#  ('Windsor Terrace', 'Greenwood'),
#  ('Brighton Beach', 'Manhattan Beach'),
#  ('Brighton Beach', 'Gravesend'),
#  ('Brighton Beach', 'Homecrest'),
#  ('Brighton Beach', 'Coney Island'),
#  ('Brighton Beach', 'Sheepshead Bay'),
#  ('Clinton Hill', 'Fort Greene'),
#  ('Clinton Hill', 'Prospect Heights'),
#  ('Clinton Hill', 'Navy Yard'),
#  ('Clinton Hill', 'Downtown'),
#  ('Bay Ridge', 'Fort Hamilton'),
#  ('Bay Ridge', 'Dyker Heights'),
#  ('Bay Ridge', 'Sunset Park'),
#  ('Bay Ridge', 'Borough Park'),
#  ('Ocean Hill', 'Brownsville'),
#  ('Ocean Hill', 'Bushwick'),
#  ('Ocean Hill', 'Crown Heights'),
#  ('Ocean Hill', 'Ridgewood'),
#  ('Midwood', 'Ocean Parkway'),
#  ('Midwood', 'Homecrest'),
#  ('Midwood', 'Flatlands'),
#  ('Midwood', 'Marine Park'),
#  ('Sunset Park', 'Dyker Heights'),
#  ('Sunset Park', 'Borough Park'),
#  ('Sunset Park', 'Greenwood'),
#  ('Sunset Park', 'Bay Ridge'),
#  ('Sunset Park', 'Red Hook'),
#  ('Bensonhurst', 'Bath Beach'),
#  ('Bensonhurst', 'Ocean Parkway'),
#  ('Bensonhurst', 'Borough Park'),
#  ('Bensonhurst', 'Gravesend'),
#  ('Red Hook', 'Columbia Street Waterfront District'),
#  ('Red Hook', 'Carroll Gardens'),
#  ('Red Hook', 'Gowanus'),
#  ('Red Hook', 'Cobble Hill'),
#  ('Red Hook', 'Greenwood'),
#  ('Bergen Beach', 'Georgetown'),
#  ('Bergen Beach', 'Mill Basin'),
#  ('Bergen Beach', 'Floyd Bennett Field'),
#  ('Dyker Heights', 'New Utrecht'),
#  ('Dyker Heights', 'Sunset Park'),
#  ('Dyker Heights', 'Bay Ridge'),
#  ('Dyker Heights', 'Fort Hamilton'),
#  ('Dyker Heights', 'Borough Park'),
#  ('Borough Park', 'Kensington'),
#  ('Borough Park', 'Sunset Park'),
#  ('Borough Park', 'Bensonhurst'),
#  ('Borough Park', 'Dyker Heights'),
#  ('Borough Park', 'New Utrecht'),
#  ('Gowanus', 'Carroll Gardens'),
#  ('Gowanus', 'Boerum Hill'),
#  ('Gowanus', 'Park Slope'),
#  ('Gowanus', 'Cobble Hill'),
#  ('Gowanus', 'Downtown'),
#  ('Gravesend', 'Homecrest'),
#  ('Gravesend', 'Ocean Parkway'),
#  ('Gravesend', 'Bath Beach'),
#  ('Gravesend', 'Brighton Beach'),
#  ('Gravesend', 'Sheepshead Bay'),
#  ('Marine Park', 'Mill Basin'),
#  ('Marine Park', 'Flatlands'),
#  ('Marine Park', 'Gerritsen Beach'),
#  ('Marine Park', 'Sheepshead Bay'),
#  ('Marine Park', 'Midwood'),
#  ('Brooklyn Heights', 'Cobble Hill'),
#  ('Brooklyn Heights', 'Downtown'),
#  ('Brooklyn Heights', 'DUMBO'),
#  ('Brooklyn Heights', 'Boerum Hill'),
#  ('Brooklyn Heights', 'Carroll Gardens'),
#  ('DUMBO', 'Vinegar Hill'),
#  ('DUMBO', 'Brooklyn Heights'),
#  ('DUMBO', 'Navy Yard'),
#  ('Ocean Parkway', 'Midwood'),
#  ('Ocean Parkway', 'Kensington'),
#  ('Ocean Parkway', 'Bensonhurst'),
#  ('Ocean Parkway', 'Gravesend'),
#  ('Ocean Parkway', 'Prospect Park South'),
#  ('Boerum Hill', 'Downtown'),
#  ('Boerum Hill', 'Cobble Hill'),
#  ('Boerum Hill', 'Gowanus'),
#  ('Boerum Hill', 'Fort Greene'),
#  ('Boerum Hill', 'Brooklyn Heights'),
#  ('Homecrest', 'Sheepshead Bay'),
#  ('Homecrest', 'Gravesend'),
#  ('Homecrest', 'Midwood'),
#  ('Homecrest', 'Brighton Beach'),
#  ('Homecrest', 'Marine Park'),
#  ('Fort Hamilton', 'Bay Ridge'),
#  ('Fort Hamilton', 'Dyker Heights'),
#  ('Fort Hamilton', 'New Utrecht'),
#  ('Fort Hamilton', 'Rosebank'),
#  ('Fort Hamilton', 'Clifton'),
#  ('Prospect Park', 'Prospect Lefferts Gardens'),
#  ('Prospect Park', 'Prospect Park South'),
#  ('Prospect Park', 'Prospect Heights'),
#  ('Prospect Park', 'Windsor Terrace'),
#  ('Prospect Park', 'Wingate'),
#  ('Gerritsen Beach', 'Marine Park'),
#  ('Gerritsen Beach', 'Floyd Bennett Field'),
#  ('Gerritsen Beach', 'Mill Basin'),
#  ('Gerritsen Beach', 'Manhattan Beach'),
#  ('Columbia Street Waterfront District', 'Cobble Hill'),
#  ('Columbia Street Waterfront District', 'Carroll Gardens'),
#  ('Columbia Street Waterfront District', 'Red Hook'),
#  ('Columbia Street Waterfront District', 'Boerum Hill'),
#  ('Columbia Street Waterfront District', 'Brooklyn Heights'),
#  ('New Utrecht', 'Dyker Heights'),
#  ('New Utrecht', 'Borough Park'),
#  ('New Utrecht', 'Fort Hamilton'),
#  ('Ozone Park', 'Howard Beach'),
#  ('Ozone Park', 'Woodhaven'),
#  ('Ozone Park', 'Richmond Hill'),
#  ('Ozone Park', 'South Ozone Park'),
#  ('Floyd Bennett Field', 'Gerritsen Beach'),
#  ('Floyd Bennett Field', 'Bergen Beach'),
#  ('Floyd Bennett Field', 'Mill Basin'),
#  ('Floyd Bennett Field', 'Georgetown'),
#  ('Georgetown', 'Bergen Beach'),
#  ('Georgetown', 'Mill Basin'),
#  ('Georgetown', 'Marine Park'),
#  ('Cobble Hill', 'Carroll Gardens'),
#  ('Cobble Hill', 'Columbia Street Waterfront District'),
#  ('Cobble Hill', 'Brooklyn Heights'),
#  ('Cobble Hill', 'Boerum Hill'),
#  ('Cobble Hill', 'Gowanus'),
#  ('Manhattan Beach', 'Brighton Beach'),
#  ('Manhattan Beach', 'Gerritsen Beach'),
#  ('Manhattan Beach', 'Homecrest'),
#  ('Manhattan Beach', 'Marine Park'),
#  ('Prospect Park South', 'Kensington'),
#  ('Prospect Park South', 'Windsor Terrace'),
#  ('Prospect Park South', 'Prospect Park'),
#  ('Prospect Park South', 'Prospect Lefferts Gardens'),
#  ('Woodhaven', 'Ozone Park'),
#  ('Woodhaven', 'Glendale'),
#  ('Woodhaven', 'Richmond Hill'),
#  ('Woodhaven', 'Forest Hills Gardens'),
#  ('Woodhaven', 'Rego Park'),
#  ('Chelsea', 'Flatiron District'),
#  ('Chelsea', 'West Village'),
#  ('Chelsea', 'Greenwich Village'),
#  ('Chelsea', 'Garment District'),
#  ('Chelsea', 'Clinton'),
#  ('Vinegar Hill', 'DUMBO'),
#  ('Vinegar Hill', 'Navy Yard'),
#  ('Navy Yard', 'Vinegar Hill'),
#  ('Navy Yard', 'DUMBO'),
#  ('Navy Yard', 'Clinton Hill'),
#  ('Upper West Side', 'Midtown'),
#  ('Upper West Side', 'Upper East Side'),
#  ('Harlem', 'East Harlem'),
#  ('Harlem', 'Mott Haven'),
#  ('Midtown', 'Clinton'),
#  ('Midtown', 'Garment District'),
#  ('Manhattanville', 'Morningside Heights'),
#  ('Manhattanville', 'Hamilton Heights'),
#  ('Manhattanville', 'Carnegie Hill'),
#  ('Chinatown', 'Little Italy'),
#  ('Chinatown', 'Tribeca'),
#  ('Chinatown', 'SoHo'),
#  ('Chinatown', 'NoHo'),
#  ('Tribeca', 'Chinatown'),
#  ('Tribeca', 'SoHo'),
#  ('Tribeca', 'Financial District'),
#  ('Tribeca', 'Little Italy'),
#  ('Financial District', 'Tribeca'),
#  ('Financial District', 'Chinatown'),
#  ('Financial District', 'SoHo'),
#  ('Gramercy', 'Flatiron District'),
#  ('Gramercy', 'Tudor City'),
#  ('Gramercy', 'East Village'),
#  ('Gramercy', 'Midtown'),
#  ('Flatiron District', 'Garment District'),
#  ('Flatiron District', 'Gramercy'),
#  ('Flatiron District', 'Chelsea'),
#  ('Flatiron District', 'Greenwich Village'),
#  ('Flatiron District', 'NoHo'),
#  ('Clinton', 'Garment District'),
#  ('Clinton', 'Columbus Circle'),
#  ('Clinton', 'Midtown'),
#  ('Clinton', 'Chelsea'),
#  ('Clinton', 'Flatiron District'),
#  ('Greenwich Village', 'NoHo'),
#  ('Greenwich Village', 'West Village'),
#  ('Greenwich Village', 'Little Italy'),
#  ('Greenwich Village', 'SoHo'),
#  ('Greenwich Village', 'Chelsea'),
#  ('Garment District', 'Flatiron District'),
#  ('Garment District', 'Clinton'),
#  ('Garment District', 'Midtown'),
#  ('Garment District', 'Chelsea'),
#  ('Lower East Side', 'East Village'),
#  ('Central Park', 'Carnegie Hill'),
#  ('Central Park', 'Sutton Place'),
#  ('Central Park', 'Turtle Bay'),
#  ('West Village', 'Greenwich Village'),
#  ('West Village', 'Chelsea'),
#  ('West Village', 'SoHo'),
#  ('West Village', 'NoHo'),
#  ('West Village', 'Tribeca'),
#  ('Hamilton Heights', 'Manhattanville'),
#  ('Hamilton Heights', 'Morningside Heights'),
#  ('Hamilton Heights', 'Washington Heights'),
#  ('East Village', 'NoHo'),
#  ('East Village', 'Lower East Side'),
#  ('East Village', 'Gramercy'),
#  ('East Village', 'Little Italy'),
#  ('SoHo', 'Little Italy'),
#  ('SoHo', 'Chinatown'),
#  ('SoHo', 'NoHo'),
#  ('SoHo', 'Tribeca'),
#  ('SoHo', 'Greenwich Village'),
#  ('Sutton Place', 'Turtle Bay'),
#  ('Sutton Place', 'Tudor City'),
#  ('Sutton Place', 'Roosevelt Island'),
#  ('Morningside Heights', 'Manhattanville'),
#  ('Morningside Heights', 'Hamilton Heights'),
#  ('Morningside Heights', 'Carnegie Hill'),
#  ('Murray Hill', 'East Elmhurst'),
#  ('Murray Hill', 'Jackson Heights'),
#  ('Murray Hill', 'Elmhurst'),
#  ('Inwood', 'University Heights'),
#  ('Inwood', 'Morris Heights'),
#  ('Inwood', 'Marble Hill'),
#  ('Inwood', 'Fordham'),
#  ('Turtle Bay', 'Sutton Place'),
#  ('Turtle Bay', 'Tudor City'),
#  ('Turtle Bay', 'Gramercy'),
#  ('NoHo', 'Little Italy'),
#  ('NoHo', 'Greenwich Village'),
#  ('NoHo', 'SoHo'),
#  ('NoHo', 'East Village'),
#  ('NoHo', 'Chinatown'),
#  ('Columbus Circle', 'Clinton'),
#  ('Columbus Circle', 'Flatiron District'),
#  ('Columbus Circle', 'Sutton Place'),
#  ('Little Italy', 'SoHo'),
#  ('Little Italy', 'NoHo'),
#  ('Little Italy', 'Chinatown'),
#  ('Little Italy', 'Greenwich Village'),
#  ('Stuyvesant Town', 'Tudor City'),
#  ('Stuyvesant Town', 'NoHo'),
#  ('Carnegie Hill', 'Central Park'),
#  ('Carnegie Hill', 'Roosevelt Island'),
#  ('Tudor City', 'Turtle Bay'),
#  ('Tudor City', 'Gramercy'),
#  ('Tudor City', 'Sutton Place'),
#  ('Roosevelt Island', 'Hunters Point'),
#  ('Roosevelt Island', 'Sutton Place'),
#  ('Roosevelt Island', 'Carnegie Hill'),
#  ('Randals-Wards Island', 'Port Morris'),
#  ('Randals-Wards Island', 'Carnegie Hill'),
#  ('Battery Park', 'Chinatown'),
#  ('Battery Park', 'SoHo'),
#  ('Battery Park', 'Little Italy'),
#  ('St. Albans', 'Hollis'),
#  ('St. Albans', 'Rochdale'),
#  ('St. Albans', 'Cambria Heights'),
#  ('St. Albans', 'Laurelton'),
#  ('St. Albans', 'Springfield Gardens'),
#  ('Maspeth', 'Ridgewood'),
#  ('Maspeth', 'Woodside'),
#  ('Maspeth', 'Bay Terrace'),
#  ('Maspeth', 'Middle Village'),
#  ('Maspeth', 'Elmhurst'),
#  ('Bayside', 'Auburndale'),
#  ('Bayside', 'Oakland Gardens'),
#  ('Bayside', 'Douglaston-Little Neck'),
#  ('Bayside', 'Fresh Meadows'),
#  ('Bayside', 'Holliswood'),
#  ('Corona', 'Rego Park'),
#  ('Corona', 'Elmhurst'),
#  ('Corona', 'Jackson Heights'),
#  ('Corona', 'East Elmhurst'),
#  ('Hunters Point', 'Greenpoint'),
#  ('Hunters Point', 'Roosevelt Island'),
#  ('Hunters Point', 'Blissville'),
#  ('Hunters Point', 'Sunnyside'),
#  ('Hunters Point', 'Tudor City'),
#  ('Elmhurst', 'Jackson Heights'),
#  ('Elmhurst', 'East Elmhurst'),
#  ('Elmhurst', 'Murray Hill'),
#  ('Elmhurst', 'Corona'),
#  ('Elmhurst', 'Middle Village'),
#  ('Far Rockaway', 'Arverne'),
#  ('Far Rockaway', 'Rockaway Beach'),
#  ('Far Rockaway', 'Springfield Gardens'),
#  ('Far Rockaway', 'Rosedale'),
#  ('South Ozone Park', 'Ozone Park'),
#  ('South Ozone Park', 'Richmond Hill'),
#  ('South Ozone Park', 'Briarwood'),
#  ('South Ozone Park', 'Jamaica'),
#  ('Rochdale', 'Springfield Gardens'),
#  ('Rochdale', 'St. Albans'),
#  ('Rochdale', 'Laurelton'),
#  ('Rochdale', 'Jamaica'),
#  ('Richmond Hill', 'Kew Gardens'),
#  ('Richmond Hill', 'Ozone Park'),
#  ('Richmond Hill', 'Briarwood'),
#  ('Richmond Hill', 'South Ozone Park'),
#  ('Jackson Heights', 'Murray Hill'),
#  ('Jackson Heights', 'East Elmhurst'),
#  ('Jackson Heights', 'Elmhurst'),
#  ('Jackson Heights', 'Woodside'),
#  ('Fresh Meadows', 'Utopia'),
#  ('Fresh Meadows', 'Jamaica Estates'),
#  ('Fresh Meadows', 'Auburndale'),
#  ('Fresh Meadows', 'Pomonok'),
#  ('Fresh Meadows', 'Hillcrest'),
#  ('Forest Hills', 'Forest Hills Gardens'),
#  ('Forest Hills', 'Rego Park'),
#  ('Forest Hills', 'Kew Gardens'),
#  ('Forest Hills', 'Flushing Meadows Corona Park'),
#  ('Forest Hills', 'Middle Village'),
#  ('Arverne', 'Rockaway Beach'),
#  ('Arverne', 'Broad Channel'),
#  ('Arverne', 'Far Rockaway'),
#  ('Arverne', 'Rockaway Park'),
#  ('Arverne', 'Belle Harbor'),
#  ('East Elmhurst', 'Murray Hill'),
#  ('East Elmhurst', 'Jackson Heights'),
#  ('East Elmhurst', 'Elmhurst'),
#  ('Flushing', 'Kew Gardens Hills'),
#  ('Flushing', 'College Point'),
#  ('Hollis', 'St. Albans'),
#  ('Hollis', 'Holliswood'),
#  ('Hollis', 'Queens Village'),
#  ('Hollis', 'Jamaica Estates'),
#  ('Hollis', 'Oakland Gardens'),
#  ('Pomonok', 'Kew Gardens Hills'),
#  ('Pomonok', 'Hillcrest'),
#  ('Pomonok', 'Utopia'),
#  ('Pomonok', 'Briarwood'),
#  ('Pomonok', 'Fresh Meadows'),
#  ('Sunnyside', 'Blissville'),
#  ('Sunnyside', 'Hunters Point'),
#  ('Sunnyside', 'Greenpoint'),
#  ('Sunnyside', 'Woodside'),
#  ('Oakland Gardens', 'Holliswood'),
#  ('Oakland Gardens', 'Bellerose'),
#  ('Oakland Gardens', 'Bayside'),
#  ('Oakland Gardens', 'Fresh Meadows'),
#  ('Oakland Gardens', 'Douglaston-Little Neck'),
#  ('Jamaica', 'Richmond Hill'),
#  ('Woodside', 'Jackson Heights'),
#  ('Woodside', 'Maspeth'),
#  ('Woodside', 'Astoria Heights'),
#  ('Woodside', 'Elmhurst'),
#  ('Woodside', 'Murray Hill'),
#  ('Glendale', 'Middle Village'),
#  ('Glendale', 'Ridgewood'),
#  ('Glendale', 'Bay Terrace'),
#  ('Glendale', 'Woodhaven'),
#  ('Briarwood', 'Jamaica Hills'),
#  ('Briarwood', 'Kew Gardens'),
#  ('Briarwood', 'Kew Gardens Hills'),
#  ('Briarwood', 'Hillcrest'),
#  ('Briarwood', 'Pomonok'),
#  ('Rego Park', 'Forest Hills'),
#  ('Rego Park', 'Corona'),
#  ('Rego Park', 'Middle Village'),
#  ('Rego Park', 'Elmhurst'),
#  ('Rego Park', 'Forest Hills Gardens'),
#  ('Rockaway Beach', 'Arverne'),
#  ('Rockaway Beach', 'Rockaway Park'),
#  ('Rockaway Beach', 'Broad Channel'),
#  ('Rockaway Beach', 'Belle Harbor'),
#  ('Rockaway Beach', 'Neponsit'),
#  ('Bellerose', 'Queens Village'),
#  ('Bellerose', 'Floral park'),
#  ('Bellerose', 'Oakland Gardens'),
#  ('Bellerose', 'Douglaston-Little Neck'),
#  ('Bellerose', 'Glen Oaks'),
#  ('Whitestone', 'Malba'),
#  ('Whitestone', 'College Point'),
#  ('Whitestone', 'Flushing'),
#  ('Whitestone', 'Auburndale'),
#  ('Whitestone', 'Throggs Neck'),
#  ('Cambria Heights', 'Queens Village'),
#  ('Cambria Heights', 'Laurelton'),
#  ('Cambria Heights', 'St. Albans'),
#  ('Cambria Heights', 'Rosedale'),
#  ('Cambria Heights', 'Bellerose'),
#  ('Rosedale', 'Laurelton'),
#  ('Rosedale', 'Springfield Gardens'),
#  ('Rosedale', 'Cambria Heights'),
#  ('Rosedale', 'Rochdale'),
#  ('Rosedale', 'St. Albans'),
#  ('Broad Channel', 'Rockaway Beach'),
#  ('Broad Channel', 'Arverne'),
#  ('Broad Channel', 'Rockaway Park'),
#  ('Broad Channel', 'Belle Harbor'),
#  ('Laurelton', 'Rochdale'),
#  ('Laurelton', 'Rosedale'),
#  ('Laurelton', 'Cambria Heights'),
#  ('Laurelton', 'St. Albans'),
#  ('Laurelton', 'Springfield Gardens'),
#  ('Springfield Gardens', 'Rochdale'),
#  ('Springfield Gardens', 'St. Albans'),
#  ('Springfield Gardens', 'Laurelton'),
#  ('Springfield Gardens', 'Rosedale'),
#  ('Springfield Gardens', 'John F. Kennedy International Airport'),
#  ('Astoria Heights', 'La Guardia Airport'),
#  ('Astoria Heights', 'Rikers Island'),
#  ('Queens Village', 'Hollis'),
#  ('Queens Village', 'Cambria Heights'),
#  ('Queens Village', 'Bellerose'),
#  ('Queens Village', 'Holliswood'),
#  ('Queens Village', 'Laurelton'),
#  ('Floral park', 'Glen Oaks'),
#  ('Floral park', 'Bellerose'),
#  ('Floral park', 'Oakland Gardens'),
#  ('Floral park', 'Douglaston-Little Neck'),
#  ('Floral park', 'Queens Village'),
#  ('Kew Gardens Hills', 'Pomonok'),
#  ('Kew Gardens Hills', 'Briarwood'),
#  ('Kew Gardens Hills', 'Hillcrest'),
#  ('Kew Gardens Hills', 'Utopia'),
#  ('Kew Gardens Hills', 'Jamaica Hills'),
#  ('Hillcrest', 'Jamaica Hills'),
#  ('Hillcrest', 'Pomonok'),
#  ('Hillcrest', 'Jamaica Estates'),
#  ('Hillcrest', 'Kew Gardens Hills'),
#  ('Hillcrest', 'Briarwood'),
#  ('Neponsit', 'Belle Harbor'),
#  ('Neponsit', 'Jacob Riis Park'),
#  ('Neponsit', 'Roxbury'),
#  ('Neponsit', 'Rockaway Park'),
#  ('Neponsit', 'Floyd Bennett Field'),
#  ('Kew Gardens', 'Richmond Hill'),
#  ('Kew Gardens', 'Forest Hills Gardens'),
#  ('Kew Gardens', 'Briarwood'),
#  ('Kew Gardens', 'Forest Hills'),
#  ('Kew Gardens', 'Kew Gardens Hills'),
#  ('Douglaston-Little Neck', 'Glen Oaks'),
#  ('Douglaston-Little Neck', 'Bellerose'),
#  ('Douglaston-Little Neck', 'Bayside'),
#  ('Douglaston-Little Neck', 'Oakland Gardens'),
#  ('Douglaston-Little Neck', 'Floral park'),
#  ('Rockaway Park', 'Rockaway Beach'),
#  ('Rockaway Park', 'Belle Harbor'),
#  ('Rockaway Park', 'Neponsit'),
#  ('Rockaway Park', 'Broad Channel'),
#  ('Rockaway Park', 'Arverne'),
#  ('College Point', 'Malba'),
#  ('College Point', 'Whitestone'),
#  ('College Point', 'Flushing Meadows Corona Park'),
#  ('College Point', 'Flushing'),
#  ('College Point', 'Clason Point'),
#  ('Jamaica Estates', 'Utopia'),
#  ('Jamaica Estates', 'Fresh Meadows'),
#  ('Jamaica Estates', 'Jamaica Hills'),
#  ('Jamaica Estates', 'Hillcrest'),
#  ('Jamaica Estates', 'Holliswood'),
#  ('Bay Terrace', 'Glendale'),
#  ('Bay Terrace', 'Maspeth'),
#  ('Jamaica Hills', 'Hillcrest'),
#  ('Jamaica Hills', 'Briarwood'),
#  ('Jamaica Hills', 'Jamaica Estates'),
#  ('Jamaica Hills', 'Utopia'),
#  ('Auburndale', 'Fresh Meadows'),
#  ('Auburndale', 'Utopia'),
#  ('Auburndale', 'Bayside'),
#  ('Auburndale', 'Pomonok'),
#  ('Auburndale', 'Jamaica Estates'),
#  ('Howard Beach', 'Ozone Park'),
#  ('Howard Beach', 'Woodhaven'),
#  ('Howard Beach', 'South Ozone Park'),
#  ('Howard Beach', 'John F. Kennedy International Airport'),
#  ('Middle Village', 'Glendale'),
#  ('Middle Village', 'Rego Park'),
#  ('Middle Village', 'Elmhurst'),
#  ('Middle Village', 'Forest Hills'),
#  ('Middle Village', 'Maspeth'),
#  ('Glen Oaks', 'Floral park'),
#  ('Glen Oaks', 'Douglaston-Little Neck'),
#  ('Glen Oaks', 'Bellerose'),
#  ('Glen Oaks', 'Oakland Gardens'),
#  ('Glen Oaks', 'Queens Village'),
#  ('Utopia', 'Fresh Meadows'),
#  ('Utopia', 'Jamaica Estates'),
#  ('Utopia', 'Hillcrest'),
#  ('Utopia', 'Pomonok'),
#  ('Utopia', 'Auburndale'),
#  ('Flushing Meadows Corona Park', 'Forest Hills'),
#  ('Flushing Meadows Corona Park', 'College Point'),
#  ('Malba', 'Whitestone'),
#  ('Malba', 'College Point'),
#  ('Malba', 'Clason Point'),
#  ('Belle Harbor', 'Neponsit'),
#  ('Belle Harbor', 'Rockaway Park'),
#  ('Belle Harbor', 'Jacob Riis Park'),
#  ('Belle Harbor', 'Roxbury'),
#  ('Belle Harbor', 'Rockaway Beach'),
#  ('Holliswood', 'Hollis'),
#  ('Holliswood', 'Jamaica Estates'),
#  ('Holliswood', 'Utopia'),
#  ('Holliswood', 'Queens Village'),
#  ('Holliswood', 'Oakland Gardens'),
#  ('Blissville', 'Sunnyside'),
#  ('Blissville', 'Hunters Point'),
#  ('Blissville', 'Greenpoint'),
#  ('Blissville', 'Roosevelt Island'),
#  ('Forest Hills Gardens', 'Forest Hills'),
#  ('Forest Hills Gardens', 'Kew Gardens'),
#  ('Forest Hills Gardens', 'Briarwood'),
#  ('Forest Hills Gardens', 'Rego Park'),
#  ('John F. Kennedy International Airport', 'Springfield Gardens'),
#  ('John F. Kennedy International Airport', 'Howard Beach'),
#  ('Breezy Point', 'Roxbury'),
#  ('Breezy Point', 'Jacob Riis Park'),
#  ('Breezy Point', 'Floyd Bennett Field'),
#  ('Breezy Point', 'Gerritsen Beach'),
#  ('Breezy Point', 'Manhattan Beach'),
#  ('Jacob Riis Park', 'Roxbury'),
#  ('Jacob Riis Park', 'Neponsit'),
#  ('Jacob Riis Park', 'Breezy Point'),
#  ('Jacob Riis Park', 'Belle Harbor'),
#  ('Jacob Riis Park', 'Floyd Bennett Field'),
#  ('Graniteville', "Mariner's Harbor"),
#  ('Graniteville', 'Elm Park'),
#  ('Graniteville', 'Westerleigh'),
#  ('Graniteville', 'Meiers Corners'),
#  ('Graniteville', 'Bulls Head'),
#  ('La Guardia Airport', 'Astoria Heights'),
#  ('La Guardia Airport', 'Rikers Island'),
#  ('Roxbury', 'Jacob Riis Park'),
#  ('Roxbury', 'Neponsit'),
#  ('Roxbury', 'Breezy Point'),
#  ('Roxbury', 'Floyd Bennett Field'),
#  ('Roxbury', 'Belle Harbor'),
#  ("Mariner's Harbor", 'Elm Park'),
#  ("Mariner's Harbor", 'Graniteville'),
#  ("Mariner's Harbor", 'Port Ivory'),
#  ("Mariner's Harbor", 'Port Richmond'),
#  ("Mariner's Harbor", 'Bulls Head'),
#  ('Park Hill', 'Grasmere - Concord'),
#  ('Park Hill', 'Stapleton'),
#  ('Park Hill', 'Clifton'),
#  ('Park Hill', 'Rosebank'),
#  ('Park Hill', 'Grymes Hill'),
#  ('Port Ivory', "Mariner's Harbor"),
#  ('Port Ivory', 'Elm Park'),
#  ('Port Ivory', 'Graniteville'),
#  ('Port Ivory', 'Bloomfield'),
#  ('Port Ivory', 'Bulls Head'),
#  ('St. George', 'Tompkinsville'),
#  ('St. George', 'New Brighton'),
#  ('St. George', 'Stapleton'),
#  ('St. George', 'Randall Manor'),
#  ('St. George', 'Clifton'),
#  ('Huguenot', 'Arden Heights'),
#  ('Huguenot', "Prince's Bay"),
#  ('Huguenot', 'Annadale'),
#  ('Huguenot', 'Woodrow'),
#  ('Huguenot', 'Pleasant Plains'),
#  ('Charleston', 'Richmond Valley'),
#  ('Charleston', 'Woodrow'),
#  ('Charleston', 'Pleasant Plains'),
#  ('Charleston', 'Butler Manor'),
#  ('Charleston', 'Rossville'),
#  ('Port Richmond', 'Westerleigh'),
#  ('Port Richmond', 'Elm Park'),
#  ('Port Richmond', 'West Brighton'),
#  ('Port Richmond', 'Meiers Corners'),
#  ('Tottenville', 'Butler Manor'),
#  ('Tottenville', 'Richmond Valley'),
#  ('Tottenville', 'Charleston'),
#  ('Tottenville', 'Pleasant Plains'),
#  ('Tottenville', "Prince's Bay"),
#  ('South Beach', 'Arrochar'),
#  ('South Beach', 'Old Town'),
#  ('South Beach', 'Grasmere - Concord'),
#  ('South Beach', 'Dongan Hills'),
#  ('South Beach', 'Fort Wadsworth'),
#  ('West Brighton', 'Clove Lake'),
#  ('West Brighton', 'Randall Manor'),
#  ('West Brighton', 'Port Richmond'),
#  ('West Brighton', 'Castleton Corners'),
#  ('Stapleton', 'Clifton'),
#  ('Stapleton', 'Park Hill'),
#  ('Stapleton', 'Tompkinsville'),
#  ('Stapleton', 'Silver Lake'),
#  ('Stapleton', 'St. George'),
#  ('Arrochar', 'South Beach'),
#  ('Arrochar', 'Fort Wadsworth'),
#  ('Arrochar', 'Grasmere - Concord'),
#  ('Arrochar', 'Rosebank'),
#  ('Arrochar', 'Old Town'),
#  ('Westerleigh', 'Meiers Corners'),
#  ('Westerleigh', 'Port Richmond'),
#  ('Westerleigh', 'Castleton Corners'),
#  ('Westerleigh', 'Graniteville'),
#  ('Heartland Village', 'Bulls Head'),
#  ('Heartland Village', 'La Tourette Park'),
#  ('Heartland Village', 'Chelsea-Travis'),
#  ('Heartland Village', 'Lighthouse Hill'),
#  ('Heartland Village', 'Eltingville'),
#  ('Tompkinsville', 'St. George'),
#  ('Tompkinsville', 'New Brighton'),
#  ('Tompkinsville', 'Stapleton'),
#  ('Tompkinsville', 'Randall Manor'),
#  ('Tompkinsville', 'Park Hill'),
#  ('New Dorp', 'Grant City'),
#  ('New Dorp', 'Oakwood'),
#  ('New Dorp', 'New Dorp Beach'),
#  ('New Dorp', 'Richmond Town'),
#  ('New Dorp', 'Midland Beach'),
#  ('Great Kills', 'Eltingville'),
#  ('Great Kills', 'La Tourette Park'),
#  ('Great Kills', 'Richmond Town'),
#  ('Great Kills', 'Annadale'),
#  ('Great Kills', 'Arden Heights'),
#  ('Dongan Hills', 'Todt Hill'),
#  ('Dongan Hills', 'Old Town'),
#  ('Dongan Hills', 'Grant City'),
#  ('Dongan Hills', 'Midland Beach'),
#  ('Dongan Hills', 'South Beach'),
#  ('Oakwood', 'New Dorp'),
#  ('Oakwood', 'New Dorp Beach'),
#  ('Oakwood', 'Richmond Town'),
#  ('Oakwood', 'Grant City'),
#  ('Oakwood', 'Lighthouse Hill'),
#  ('New Brighton', 'St. George'),
#  ('New Brighton', 'Tompkinsville'),
#  ('New Brighton', 'Randall Manor'),
#  ('New Brighton', 'Silver Lake'),
#  ('New Brighton', 'Stapleton'),
#  ('Midland Beach', 'Grant City'),
#  ('Midland Beach', 'Dongan Hills'),
#  ('Midland Beach', 'New Dorp Beach'),
#  ('Midland Beach', 'Old Town'),
#  ('Midland Beach', 'New Dorp'),
#  ('Grant City', 'New Dorp'),
#  ('Grant City', 'New Dorp Beach'),
#  ('Grant City', 'Midland Beach'),
#  ('Grant City', 'Dongan Hills'),
#  ('Grant City', 'Todt Hill'),
#  ('Woodrow', 'Rossville'),
#  ('Woodrow', 'Pleasant Plains'),
#  ('Woodrow', 'Charleston'),
#  ('Woodrow', "Prince's Bay"),
#  ('Woodrow', 'Huguenot'),
#  ('New Springville', 'Emerson Hill'),
#  ('New Springville', 'Willowbrook'),
#  ('New Springville', 'Meiers Corners'),
#  ('New Springville', 'Lighthouse Hill'),
#  ('New Springville', 'Westerleigh'),
#  ('Willowbrook', 'Meiers Corners'),
#  ('Willowbrook', 'Bulls Head'),
#  ('Willowbrook', 'New Springville'),
#  ('Willowbrook', 'Graniteville'),
#  ('Willowbrook', 'Elm Park'),
#  ('Elm Park', "Mariner's Harbor"),
#  ('Elm Park', 'Port Richmond'),
#  ('Elm Park', 'Graniteville'),
#  ('Elm Park', 'Westerleigh'),
#  ('Elm Park', 'Meiers Corners'),
#  ('Richmond Town', 'Lighthouse Hill'),
#  ('Richmond Town', 'Oakwood'),
#  ('Richmond Town', 'New Dorp'),
#  ('Richmond Town', 'New Dorp Beach'),
#  ('Richmond Town', 'Grant City'),
#  ('Grasmere - Concord', 'Park Hill'),
#  ('Grasmere - Concord', 'Old Town'),
#  ('Grasmere - Concord', 'Arrochar'),
#  ('Grasmere - Concord', 'Fort Wadsworth'),
#  ('Grasmere - Concord', 'South Beach'),
#  ('Bulls Head', 'Willowbrook'),
#  ('Bulls Head', 'Bloomfield'),
#  ('Bulls Head', 'Heartland Village'),
#  ('Bulls Head', 'Graniteville'),
#  ('Bulls Head', "Mariner's Harbor"),
#  ('Todt Hill', 'Dongan Hills'),
#  ('Todt Hill', 'Old Town'),
#  ('Todt Hill', 'Grant City'),
#  ('Todt Hill', 'Grasmere - Concord'),
#  ('Todt Hill', 'Midland Beach'),
#  ('Rossville', 'Woodrow'),
#  ('Rossville', 'Arden Heights'),
#  ('Rossville', 'Fresh Kills'),
#  ('Rossville', 'Pleasant Plains'),
#  ('Rossville', 'Charleston'),
#  ('Eltingville', 'La Tourette Park'),
#  ('Eltingville', 'Great Kills'),
#  ('Eltingville', 'Annadale'),
#  ('Eltingville', 'Arden Heights'),
#  ('Eltingville', 'Greenridge'),
#  ('Grymes Hill', 'Silver Lake'),
#  ('Grymes Hill', 'Park Hill'),
#  ('Grymes Hill', 'Stapleton'),
#  ('Grymes Hill', 'Clifton'),
#  ('Grymes Hill', 'Clove Lake'),
#  ('Chelsea-Travis', 'Bloomfield'),
#  ('Chelsea-Travis', 'Heartland Village'),
#  ('Chelsea-Travis', 'Greenridge'),
#  ('Chelsea-Travis', 'Bulls Head'),
#  ('Chelsea-Travis', 'Fresh Kills'),
#  ('Richmond Valley', 'Butler Manor'),
#  ('Richmond Valley', 'Charleston'),
#  ('Richmond Valley', 'Tottenville'),
#  ('Richmond Valley', 'Pleasant Plains'),
#  ('Richmond Valley', "Prince's Bay"),
#  ('Castleton Corners', 'Westerleigh'),
#  ('Castleton Corners', 'Meiers Corners'),
#  ('Castleton Corners', 'Clove Lake'),
#  ('Castleton Corners', 'Emerson Hill'),
#  ('Emerson Hill', 'Castleton Corners'),
#  ('Emerson Hill', 'New Springville'),
#  ('Emerson Hill', 'Clove Lake'),
#  ('Emerson Hill', 'Willowbrook'),
#  ('Rosebank', 'Clifton'),
#  ('Rosebank', 'Park Hill'),
#  ('Rosebank', 'Fort Wadsworth'),
#  ('Rosebank', 'Arrochar'),
#  ('Rosebank', 'Stapleton'),
#  ...]

# %% [markdown]
# ### Type Crime Graph

# %%
# Creating a new variable for this section using a previously created variable

datapanda_crimetype = datapanda

# %%
# Getting the type of crime by getting the first digit of the PD_CD: a three digit code for crimes
# used by the police, where the first digit indicates the broad category of crime (ex: Harassment...etc)

datapanda_crimetype['PD_CD']=[str(o)[0] for o in datapanda_crimetype['PD_CD']]

# %%
datapanda_crimetype.head()
# Out:
#    Longitude   Latitude Neighborhood PD_CD                         PD_DESC  \
# 0 -73.769745  40.683786   St. Albans     6      HARASSMENT,SUBD 1,CIVILIAN
# 2 -73.953117  40.726965   Greenpoint     4  THEFT OF SERVICES, UNCLASSIFIE
# 3 -73.897849  40.824519     Longwood     5     MARIJUANA, POSSESSION 4 & 5
# 4 -73.867003  40.822552    Soundview     1             OBSTR BREATH/CIRCUL
# 5 -73.891225  40.712362      Maspeth     9     INTOXICATED DRIVING,ALCOHOL
#
#     BORO_NM
# 0    QUEENS
# 2  BROOKLYN
# 3     BRONX
# 4     BRONX
# 5    QUEENS

# %%
# The number of crime per category through our time period

print(datapanda_crimetype['PD_CD'].value_counts())
# Out:
# 3    47320
# 6    46323
# 1    45286
# 2    31685
# 4    25963
# 7    15304
# 5     9644
# 9     5841
# 8     1122
# n      148
# Name: PD_CD, dtype: int64

# %%
#Compute majority of crimes
datapanda_crimetype['PD_CD'].value_counts().idxmax()
# Out:
# '3'

# %%
# Assign to a neighborhood the category type that happens the most in said neighborhood 

def top_value_count(x, n=1):
    return x.value_counts().head(n)

gb = datapanda_crimetype.groupby(['Neighborhood']).PD_CD
df_top_freq = gb.apply(top_value_count).reset_index()

# %%
df_top_freq.head()
# Out:
#     Neighborhood level_1  PD_CD
# 0       Annadale       6     22
# 1  Arden Heights       6     29
# 2       Arrochar       2     71
# 3        Arverne       1     73
# 4        Astoria       6    799

# %%
# We observe that each crime time is represented except category 5

df_top_freq.level_1.unique()
# Out:
# array(['6', '2', '1', '4', '3', '7', '8', '9'], dtype=object)

# %%
# Number of neighborhoods per crime category

df_top_freq.level_1.value_counts()
# Out:
# 6    99
# 3    75
# 1    54
# 2    13
# 4    12
# 9     4
# 7     3
# 8     1
# Name: level_1, dtype: int64

# %%
# Merging our panda dataframe with closeness info, with crime type info for edges selection

dfedges_crimetype = pd.DataFrame(edges, columns=['N1', 'N2'])
dfedges_crimetype = dfedges_crimetype.merge(df_top_freq, left_on='N1', right_on='Neighborhood', how = 'left', suffixes=('', '_N1'), copy='True')

dfedges_crimetype = dfedges_crimetype.merge(df_top_freq, left_on='N2', right_on='Neighborhood', how = 'left', suffixes=('', '_N2'),copy='True')

# %%
dfedges_crimetype.head()
# Out:
#          N1            N2 Neighborhood level_1  PD_CD Neighborhood_N2  \
# 0  Longwood   Hunts Point     Longwood       1  470.0     Hunts Point
# 1  Longwood   South Bronx     Longwood       1  470.0     South Bronx
# 2  Longwood       Melrose     Longwood       1  470.0         Melrose
# 3  Longwood     Soundview     Longwood       1  470.0       Soundview
# 4  Longwood  East Tremont     Longwood       1  470.0    East Tremont
#
#   level_1_N2  PD_CD_N2
# 0          6     151.0
# 1          1    1176.0
# 2          1     549.0
# 3          1     775.0
# 4          6     417.0

# %%
# Creating our edge list with closeness and crime type

edges_crimetype = []
for i in range(dfedges_crimetype.shape[0]):
    if dfedges_crimetype.loc[i, "level_1"] == dfedges_crimetype.loc[i, "level_1_N2"]:
        edges_crimetype.append((dfedges_crimetype.loc[i, "N1"],dfedges_crimetype.loc[i, "N2"]))

# %%
#Graph with crime type edges
G_ct = nx.Graph()
G_ct.add_nodes_from(nodes)
G_ct.add_edges_from(edges_crimetype)
nx.draw(G_ct,node_size=20,font_size=8, node_color = color_map)

# %% [markdown]
# ### Gif Creation

# %%
import random
#Random Deletion
#Generate gcc for random deletion
comp_error_gen = nx.connected_components(G)
gcc_error_set = sorted(comp_error_gen, key=len, reverse=True)[0]
gcc_error_sub = nx.subgraph(G,gcc_error_set)
gcc_error = nx.Graph(gcc_error_sub)
original_gcc_error_nodes = len(gcc_error.nodes())
original_gcc_error_size = nx.Graph.size(gcc_error_sub)


#set boundary of deletion
nodes_for_deletion = int(original_gcc_error_nodes  * 0.20) + 1

# %%
#nx.draw(gcc)
#nx.draw(gcc_error)
#plt.savefig("C://Users//Rebecca//Desktop//nsa//final_project//gcc_error_random_fp.pdf")


#Targeted Deletion
#Generate gcc for Targeted deletion
comp_target_gen = nx.connected_components(G)
gcc_target_set = sorted(comp_target_gen, key=len, reverse=True)[0]
gcc_target_sub = nx.subgraph(G,gcc_target_set)
gcc_target = nx.Graph(gcc_target_sub)
original_gcc_target_nodes = len(gcc_target.nodes())
original_gcc_target_size = nx.Graph.size(gcc_target_sub)

# %%
def save_graph(graph,pos,file_name):
    #initialze Figure
    plt.figure(num=None, figsize=(20, 20), dpi=80)
    plt.axis('off')
    fig = plt.figure(1)
    nx.draw_networkx_nodes(graph,pos,node_size=140,font_size=5,node_color = color_map)
    nx.draw_networkx_edges(graph,pos)
    nx.draw_networkx_labels(graph,pos)

    cut = 1.2
    xmax = cut * max(xx for xx, yy in pos.values())
    ymax = cut * max(yy for xx, yy in pos.values())
    plt.xlim(-1.5*xmax, 1.5*xmax)
    plt.ylim(-1.2*ymax, 1.2*ymax)

    plt.savefig(file_name,bbox_inches="tight")
    pylab.close()
    del fig

def attack(graph, centrality_metric):
    graph = graph.copy()
    steps = 0
    ranks = centrality_metric(graph)
    nodes = sorted(graph.nodes(), key=lambda n: ranks[n])

        #Generate spring layout
    pos = nx.spring_layout(graph)

    for x in range(nodes_for_deletion):
        graph.remove_node(nodes.pop())
        file_name = './sim2/'+str(steps)+'.png'
        save_graph(graph,pos,file_name)
        steps += 1
    else:
        return steps

attack(G,nx.betweenness_centrality)

# %% [markdown]
# ### Density Map

# %%
#Import the necessary Python moduless
import pandas as pd
import geopandas as gpd
import numpy as np
from geopandas.tools import sjoin
import folium
from folium.plugins import MarkerCluster
from folium import IFrame
import shapely
from shapely.geometry import Point
import unicodedata
import pysal as ps

# %%
#Read in CSV file specifying date field and encoding. Sort by crime
all_crime = pd.read_csv(r'C:\Users\Rebecca\Desktop\nsa\final_project\Data-for-graph.csv', encoding = 'utf-8')
all_crime.sort_values('PD_DESC').reset_index(drop=True)
# Out:
#         Longitude   Latitude               Neighborhood  PD_CD  \
# 0      -73.952533  40.801117                     Harlem  803.0
# 1      -73.944661  40.694403         Bedford Stuyvesant  818.0
# 2      -73.945167  40.815930                     Harlem  818.0
# 3      -73.892632  40.866513                    Fordham  818.0
# 4      -73.957502  40.814787        Morningside Heights  818.0
# 5      -73.928841  40.820024                  Concourse  818.0
# 6      -73.908684  40.820240                    Melrose  818.0
# 7      -73.917963  40.843001                High Bridge  818.0
# 8      -73.742623  40.703732             Queens Village  818.0
# 9      -74.115678  40.637223              West Brighton  818.0
# 10     -73.758676  40.721608             Queens Village  818.0
# 11     -73.775909  40.680049                   Rochdale  818.0
# 12     -73.939379  40.792695                East Harlem  818.0
# 13     -73.871003  40.822570                  Soundview  818.0
# 14     -73.984819  40.711471            Lower East Side  818.0
# 15     -73.895947  40.654180              East New York  818.0
# 16     -73.904337  40.669328                Brownsville  818.0
# 17     -74.136668  40.640233              Port Richmond  818.0
# 18     -73.734004  40.737828                  Bellerose  818.0
# 19     -73.907953  40.885849             Spuyten Duyvil  818.0
# 20     -73.786750  40.703960                    Jamaica  818.0
# 21     -73.998532  40.751853                    Chelsea  818.0
# 22     -73.899968  40.854989                    Tremont  143.0
# 23     -73.949786  40.809597                     Harlem  466.0
# 24     -74.007090  40.720255                    Tribeca  466.0
# 25     -73.798255  40.704115                    Jamaica  466.0
# 26     -73.984284  40.764799                    Midtown  466.0
# 27     -73.988943  40.748213           Garment District  466.0
# 28     -73.984120  40.754849           Garment District  466.0
# 29     -73.892459  40.861855                    Fordham  466.0
# ...           ...        ...                        ...    ...
# 228875 -73.939997  40.788721                East Harlem    NaN
# 228876 -73.957745  40.665899              Crown Heights    NaN
# 228877 -73.777806  40.595535               Far Rockaway    NaN
# 228878 -73.951695  40.657014  Prospect Lefferts Gardens    NaN
# 228879 -73.951695  40.657014  Prospect Lefferts Gardens    NaN
# 228880 -73.856950  40.851757                Morris Park    NaN
# 228881 -73.892378  40.856122                    Fordham    NaN
# 228882 -73.804462  40.711342              Jamaica Hills    NaN
# 228883 -73.811020  40.729065          Kew Gardens Hills    NaN
# 228884 -73.943316  40.694932         Bedford Stuyvesant    NaN
# 228885 -73.804247  40.666865           South Ozone Park    NaN
# 228886 -73.893410  40.649687              East New York    NaN
# 228887 -74.075033  40.625610                  Stapleton    NaN
# 228888 -73.811897  40.730274          Kew Gardens Hills    NaN
# 228889 -73.888670  40.844782               East Tremont    NaN
# 228890 -73.920766  40.841224                High Bridge    NaN
# 228891 -73.934344  40.694463         Bedford Stuyvesant    NaN
# 228892 -73.746577  40.708136             Queens Village    NaN
# 228893 -73.810556  40.689284           South Ozone Park    NaN
# 228894 -73.922103  40.847354             Morris Heights    NaN
# 228895 -73.908618  40.813148                    Melrose    NaN
# 228896 -73.772573  40.595821               Far Rockaway    NaN
# 228897 -73.919324  40.665222                Brownsville    NaN
# 228898 -73.872288  40.834473                  Soundview    NaN
# 228899 -73.872288  40.834473                  Soundview    NaN
# 228900 -73.881393  40.841836                 West Farms    NaN
# 228901 -73.918187  40.819597                    Melrose    NaN
# 228902 -73.854749  40.899691                  Wakefield    NaN
# 228903 -73.753094  40.714103             Queens Village    NaN
# 228904 -73.830464  40.686417              Richmond Hill    NaN
#
#                           PD_DESC        BORO_NM
# 0       A.B.C.,FALSE PROOF OF AGE      MANHATTAN
# 1                  ABANDON ANIMAL       BROOKLYN
# 2                  ABANDON ANIMAL      MANHATTAN
# 3                  ABANDON ANIMAL          BRONX
# 4                  ABANDON ANIMAL      MANHATTAN
# 5                  ABANDON ANIMAL          BRONX
# 6                  ABANDON ANIMAL          BRONX
# 7                  ABANDON ANIMAL          BRONX
# 8                  ABANDON ANIMAL         QUEENS
# 9                  ABANDON ANIMAL  STATEN ISLAND
# 10                 ABANDON ANIMAL         QUEENS
# 11                 ABANDON ANIMAL         QUEENS
# 12                 ABANDON ANIMAL      MANHATTAN
# 13                 ABANDON ANIMAL          BRONX
# 14                 ABANDON ANIMAL      MANHATTAN
# 15                 ABANDON ANIMAL       BROOKLYN
# 16                 ABANDON ANIMAL       BROOKLYN
# 17                 ABANDON ANIMAL  STATEN ISLAND
# 18                 ABANDON ANIMAL         QUEENS
# 19                 ABANDON ANIMAL          BRONX
# 20                 ABANDON ANIMAL         QUEENS
# 21                 ABANDON ANIMAL      MANHATTAN
# 22                     ABORTION 1          BRONX
# 23           ACCOSTING,FRAUDULENT      MANHATTAN
# 24           ACCOSTING,FRAUDULENT      MANHATTAN
# 25           ACCOSTING,FRAUDULENT         QUEENS
# 26           ACCOSTING,FRAUDULENT      MANHATTAN
# 27           ACCOSTING,FRAUDULENT      MANHATTAN
# 28           ACCOSTING,FRAUDULENT      MANHATTAN
# 29           ACCOSTING,FRAUDULENT          BRONX
# ...                           ...            ...
# 228875                        NaN            NaN
# 228876                        NaN            NaN
# 228877                        NaN            NaN
# 228878                        NaN            NaN
# 228879                        NaN            NaN
# 228880                        NaN            NaN
# 228881                        NaN            NaN
# 228882                        NaN            NaN
# 228883                        NaN            NaN
# 228884                        NaN            NaN
# 228885                        NaN            NaN
# 228886                        NaN            NaN
# 228887                        NaN            NaN
# 228888                        NaN            NaN
# 228889                        NaN            NaN
# 228890                        NaN            NaN
# 228891                        NaN            NaN
# 228892                        NaN            NaN
# 228893                        NaN            NaN
# 228894                        NaN            NaN
# 228895                        NaN            NaN
# 228896                        NaN            NaN
# 228897                        NaN            NaN
# 228898                        NaN            NaN
# 228899                        NaN            NaN
# 228900                        NaN            NaN
# 228901                        NaN            NaN
# 228902                        NaN            NaN
# 228903                        NaN            NaN
# 228904                        NaN            NaN
#
# [228905 rows x 6 columns]

# %%
#Identify those crimes that are categorized as marijuana-related
is_crime = all_crime.PD_DESC == 'HARASSMENT,SUBD 3,4,5'

# %%
assaults = all_crime[is_crime].reset_index(drop = True)
assaults = assaults[['Longitude', 'Latitude', 'PD_DESC','Neighborhood', 'BORO_NM']]
print ('{}Harassment Crimes'.format(str(len(assaults))))
# Out:
# 25321Harassment Crimes

# %%
#First create a GeoSeries of crime locations by converting coordinates to Shapely geometry objects
#Specify the coordinate system ESPG4326 which represents the standard WGS84 coordinate system
assault_geo = gpd.GeoSeries(assaults.apply(lambda z: Point(z['Longitude'], z['Latitude']), 1),crs={'init': 'epsg:4326'})

#Create a geodataframe from the pandas dataframe and the geoseries of shapely geometry objects
assaults = gpd.GeoDataFrame(assaults.drop(['Longitude', 'Latitude'], 1), geometry=assault_geo)
assaults.head()

# %%
#Read tracts shapefile into GeoDataFrame
tracts = gpd.read_file('/Users/Boubou/Desktop/NGSA Project/nyc_census_tracts.shp')
tracts

# %%
#Generate Counts of Assaults per Census Tract
#Spatially join census tracts to assaults (after projecting) and then group by Tract FIPS while counting the number of crimes
assaults = assaults.to_crs({'init': 'epsg:3310'})

# %%
tract_counts = gpd.tools.sjoin(assaults, tracts).groupby('geometry').size()

# %%
tract_counts

# %%
#Calculate Assault Density, converting square meters to square miles.
tracts['AssaultsPSqMi'] = (tract_counts/(tracts.geometry.area*3.86102e-7)).fillna(0)
tracts = tracts.reset_index()
tracts.head()

# %%
#Create SF basemap specifying map center, zoom level, and using the default OpenStreetMap tiles
crime_map = folium.Map([40.73, -73.93], zoom_start = 12)

def add_choropleth(mapobj, gdf, id_field, value_field, fill_color = 'YlOrRd', fill_opacity = 0.6, 
                    line_opacity = 0.2, num_classes = 5, classifier = 'Fisher_Jenks'):
    #Allow for 3 Pysal map classifiers to display data
    #Generate list of breakpoints using specified classification scheme. List of breakpoint will be input to choropleth function
    if classifier == 'Fisher_Jenks':
        threshold_scale=ps.esda.mapclassify.Fisher_Jenks(gdf[value_field], k = num_classes).bins.tolist()
    if classifier == 'Equal_Interval':
        threshold_scale=ps.esda.mapclassify.Equal_Interval(gdf[value_field], k = num_classes).bins.tolist()
    if classifier == 'Quantiles':
        threshold_scale=ps.esda.mapclassify.Quantiles(gdf[value_field], k = num_classes).bins.tolist()
    
    #Convert the GeoDataFrame to WGS84 coordinate reference system
    gdf_wgs84 = gdf.to_crs({'init': 'epsg:4326'})
    
    #Call Folium choropleth function, specifying the geometry as a the WGS84 dataframe converted to GeoJSON, the data as 
    #the GeoDataFrame, the columns as the user-specified id field and and value field.
    #key_on field refers to the id field within the GeoJSON string
    mapobj.choropleth(geo_str = gdf_wgs84.to_json(), data = gdf,
                columns = [id_field, value_field], key_on = 'feature.properties.{}'.format(id_field),
                fill_color = fill_color, fill_opacity = fill_opacity, line_opacity = line_opacity,  
                threshold_scale = threshold_scale)
    return mapobj

#Update basemap with choropleth
crime_map=add_choropleth(crime_map, tracts,'geometry','AssaultsPSqMi')

# %%
def add_point_clusters(mapobj, gdf, popup_field_list):
    #Create empty lists to contain the point coordinates and the point pop-up information
    coords, popups = [], [] 
    #Loop through each record in the GeoDataFrame
    for i, row in gdf.iterrows():
        #Append lat and long coordinates to "coords" list
        coords.append([row.geometry.y, row.geometry.x])
        #Create a string of HTML code used in the IFrame popup
        #Join together the fields in "popup_field_list" with a linebreak between them
        label = '<br>'.join([row[field] for field in popup_field_list])
        #Append an IFrame that uses the HTML string to the "popups" list 
        popups.append(IFrame(label, width = 300, height = 100))
        
    #Create a Folium feature group for this layer, since we will be displaying multiple layers
    pt_lyr = folium.FeatureGroup(name = 'pt_lyr')
    
    #Add the clustered points of crime locations and popups to this layer
    pt_lyr.add_child(MarkerCluster(locations = coords, popups = popups))
    
    #Add this point layer to the map object
    mapobj.add_child(pt_lyr)
    return mapobj

#Update choropleth with point clusters
crime_map = add_point_clusters(crime_map, assaults, ['PD_DESC'])

# %%
folium.LayerControl().add_to(crime_map) #Add layer control to toggle on/off
crime_map.save('nyc_assaults.html') #save HTML
#crime_map #display map

# %% [markdown]
# ### Gang Networks

# %% [markdown]
# Creating the list of edegs with gang, which we will try to infer by using the previously created graphs

# %%
# Loading gang information per neighborhoods, gathered from: 
# http://interactive.nydailynews.com/2015/12/gangs-of-new-york-city-interactive-map/
# The gang presence in a neighborhood had to be extracted manually from the map provided in this website into a csv

data_gang = np.array(list(csv.reader(open("C://Users//Rebecca//Desktop//nsa//final_project//Project-Network//Project Network//Gang numbers2.csv", "r"), delimiter=",")))

# %%
# Transforming our gang data into a panda dataframe

data_gangdf = pd.DataFrame(data_gang[1:],columns=data_gang[0])

# %%
data_gangdf.head()
# Out:
#     Neighborhood gang
# 0       Annadale    0
# 1  Arden Heights    0
# 2       Arrochar    0
# 3        Arverne    1
# 4        Astoria    1

# %%
# Getting the edge list of neighborhoods close to eachother

dfedges = pd.DataFrame(edges, columns=['N1', 'N2'])

# %%
# Merging the info of neighborhoods close to each other with gang info for edge selection

dfedgesgang = dfedges.merge(data_gangdf, left_on='N1', right_on='Neighborhood', how = 'left', suffixes=('', '_N1'), copy='True')

dfedgesgang = dfedgesgang.merge(data_gangdf, left_on='N2', right_on='Neighborhood', how = 'left', suffixes=('', '_N2'),copy='True')

# %%
dfedgesgang.head()
# Out:
#          N1            N2 Neighborhood gang Neighborhood_N2 gang_N2
# 0  Longwood   Hunts Point     Longwood    1     Hunts Point       0
# 1  Longwood   South Bronx     Longwood    1     South Bronx       0
# 2  Longwood       Melrose     Longwood    1         Melrose       1
# 3  Longwood     Soundview     Longwood    1       Soundview       1
# 4  Longwood  East Tremont     Longwood    1    East Tremont       1

# %%
# Creating edges if two neighborhoods are close and display the presence of a gang

gangedges = []
for i in range(dfedgesgang.shape[0]):
    if dfedgesgang.loc[i, "gang"] =='1':
        if dfedgesgang.loc[i, "gang_N2"] =='1':
            gangedges.append((dfedgesgang.loc[i, "N1"],dfedgesgang.loc[i, "N2"]))

# %%
gangedges
# Out:
# [('Longwood', 'Melrose'),
#  ('Longwood', 'Soundview'),
#  ('Longwood', 'East Tremont'),
#  ('Soundview', 'Unionport'),
#  ('Soundview', 'Castle Hill'),
#  ('Soundview', 'West Farms'),
#  ('University Heights', 'Fordham'),
#  ('University Heights', 'Tremont'),
#  ('University Heights', 'Marble Hill'),
#  ('University Heights', 'Inwood'),
#  ('University Heights', 'Kingsbridge'),
#  ('Williamsbridge', 'Norwood'),
#  ('Williamsbridge', 'Baychester'),
#  ('Williamsbridge', 'Morris Park'),
#  ('Tremont', 'University Heights'),
#  ('Tremont', 'Morris Heights'),
#  ('Tremont', 'East Tremont'),
#  ('Tremont', 'Fordham'),
#  ('Tremont', 'Belmont'),
#  ('Morris Heights', 'Tremont'),
#  ('Morris Heights', 'Inwood'),
#  ('Morris Heights', 'Washington Heights'),
#  ('Morris Park', 'Unionport'),
#  ('Fordham', 'University Heights'),
#  ('Fordham', 'Belmont'),
#  ('Fordham', 'Bedford Park'),
#  ('Fordham', 'East Tremont'),
#  ('Fordham', 'Tremont'),
#  ('Norwood', 'Bedford Park'),
#  ('Norwood', 'Williamsbridge'),
#  ('Norwood', 'Belmont'),
#  ('Bedford Park', 'Norwood'),
#  ('Bedford Park', 'Fordham'),
#  ('Bedford Park', 'Belmont'),
#  ('Bedford Park', 'Kingsbridge'),
#  ('Bedford Park', 'Marble Hill'),
#  ('East Tremont', 'Belmont'),
#  ('East Tremont', 'Tremont'),
#  ('East Tremont', 'West Farms'),
#  ('East Tremont', 'Fordham'),
#  ('Melrose', 'Mott Haven'),
#  ('Melrose', 'Longwood'),
#  ('Mott Haven', 'Melrose'),
#  ('Mott Haven', 'Harlem'),
#  ('West Farms', 'East Tremont'),
#  ('West Farms', 'Belmont'),
#  ('Eastchester', 'Co-op City'),
#  ('Eastchester', 'Baychester'),
#  ('Co-op City', 'Baychester'),
#  ('Co-op City', 'Eastchester'),
#  ('Throggs Neck', 'Castle Hill'),
#  ('Throggs Neck', 'Unionport'),
#  ('Kingsbridge', 'Marble Hill'),
#  ('Kingsbridge', 'University Heights'),
#  ('Unionport', 'Castle Hill'),
#  ('Unionport', 'Soundview'),
#  ('Unionport', 'Clason Point'),
#  ('Belmont', 'East Tremont'),
#  ('Belmont', 'Fordham'),
#  ('Belmont', 'Bedford Park'),
#  ('Belmont', 'West Farms'),
#  ('Baychester', 'Co-op City'),
#  ('Baychester', 'Williamsbridge'),
#  ('Baychester', 'Eastchester'),
#  ('Marble Hill', 'Kingsbridge'),
#  ('Marble Hill', 'University Heights'),
#  ('Marble Hill', 'Inwood'),
#  ('Castle Hill', 'Unionport'),
#  ('Castle Hill', 'Clason Point'),
#  ('Castle Hill', 'Soundview'),
#  ('Clason Point', 'Castle Hill'),
#  ('Clason Point', 'Unionport'),
#  ('Clason Point', 'Soundview'),
#  ('Washington Heights', 'Morris Heights'),
#  ('Washington Heights', 'Inwood'),
#  ('East New York', 'Brownsville'),
#  ('East New York', 'Glendale'),
#  ('Brownsville', 'East New York'),
#  ('Brownsville', 'East Flatbush'),
#  ('Brownsville', 'Canarsie'),
#  ('Bedford Stuyvesant', 'Crown Heights'),
#  ('Bedford Stuyvesant', 'Clinton Hill'),
#  ('Bedford Stuyvesant', 'Williamsburg'),
#  ('Bedford Stuyvesant', 'Bushwick'),
#  ('East Harlem', 'Harlem'),
#  ('East Harlem', 'Morningside Heights'),
#  ('Crown Heights', 'Bedford Stuyvesant'),
#  ('Crown Heights', 'Prospect Lefferts Gardens'),
#  ('Crown Heights', 'East Flatbush'),
#  ('Canarsie', 'Brownsville'),
#  ('Canarsie', 'Flatlands'),
#  ('Canarsie', 'East Flatbush'),
#  ('Flatbush', 'Prospect Lefferts Gardens'),
#  ('Williamsburg', 'Bedford Stuyvesant'),
#  ('Williamsburg', 'Hunters Point'),
#  ('Williamsburg', 'Clinton Hill'),
#  ('Sheepshead Bay', 'Gravesend'),
#  ('Bath Beach', 'Gravesend'),
#  ('Bath Beach', 'Coney Island'),
#  ('Flatlands', 'East Flatbush'),
#  ('Bushwick', 'Ridgewood'),
#  ('Bushwick', 'Bedford Stuyvesant'),
#  ('Bushwick', 'Brownsville'),
#  ('East Flatbush', 'Flatlands'),
#  ('East Flatbush', 'Crown Heights'),
#  ('East Flatbush', 'Prospect Lefferts Gardens'),
#  ('East Flatbush', 'Brownsville'),
#  ('Fort Greene', 'Clinton Hill'),
#  ('Fort Greene', 'Vinegar Hill'),
#  ('Coney Island', 'Bath Beach'),
#  ('Coney Island', 'Gravesend'),
#  ('Prospect Lefferts Gardens', 'Flatbush'),
#  ('Prospect Lefferts Gardens', 'Crown Heights'),
#  ('Ridgewood', 'Bushwick'),
#  ('Ridgewood', 'Glendale'),
#  ('Clinton Hill', 'Fort Greene'),
#  ('Clinton Hill', 'Bedford Stuyvesant'),
#  ('Gravesend', 'Bath Beach'),
#  ('Gravesend', 'Sheepshead Bay'),
#  ('Vinegar Hill', 'Fort Greene'),
#  ('Vinegar Hill', 'Lower East Side'),
#  ('Upper West Side', 'Upper East Side'),
#  ('Harlem', 'Manhattanville'),
#  ('Harlem', 'Morningside Heights'),
#  ('Harlem', 'East Harlem'),
#  ('Harlem', 'Mott Haven'),
#  ('Manhattanville', 'Morningside Heights'),
#  ('Manhattanville', 'Harlem'),
#  ('Manhattanville', 'East Harlem'),
#  ('Chinatown', 'Lower East Side'),
#  ('Lower East Side', 'Chinatown'),
#  ('Lower East Side', 'East Village'),
#  ('East Village', 'Lower East Side'),
#  ('Morningside Heights', 'Manhattanville'),
#  ('Morningside Heights', 'Harlem'),
#  ('Morningside Heights', 'East Harlem'),
#  ('Inwood', 'University Heights'),
#  ('Inwood', 'Morris Heights'),
#  ('Inwood', 'Marble Hill'),
#  ('Inwood', 'Fordham'),
#  ('Astoria', 'Sunnyside'),
#  ('Astoria', 'Astoria Heights'),
#  ('St. Albans', 'Hollis'),
#  ('St. Albans', 'Rochdale'),
#  ('Corona', 'Elmhurst'),
#  ('Corona', 'Jackson Heights'),
#  ('Corona', 'East Elmhurst'),
#  ('Hunters Point', 'Sunnyside'),
#  ('Elmhurst', 'Jackson Heights'),
#  ('Elmhurst', 'East Elmhurst'),
#  ('Elmhurst', 'Corona'),
#  ('Far Rockaway', 'Arverne'),
#  ('South Ozone Park', 'Briarwood'),
#  ('South Ozone Park', 'Jamaica'),
#  ('Rochdale', 'St. Albans'),
#  ('Rochdale', 'Jamaica'),
#  ('Jackson Heights', 'East Elmhurst'),
#  ('Jackson Heights', 'Elmhurst'),
#  ('Arverne', 'Far Rockaway'),
#  ('East Elmhurst', 'Jackson Heights'),
#  ('East Elmhurst', 'Elmhurst'),
#  ('East Elmhurst', 'Astoria Heights'),
#  ('Flushing', 'College Point'),
#  ('Flushing', 'Auburndale'),
#  ('Hollis', 'St. Albans'),
#  ('Hollis', 'Jamaica Estates'),
#  ('Pomonok', 'Hillcrest'),
#  ('Pomonok', 'Briarwood'),
#  ('Sunnyside', 'Hunters Point'),
#  ('Sunnyside', 'Astoria'),
#  ('Jamaica', 'Jamaica Hills'),
#  ('Jamaica', 'Jamaica Estates'),
#  ('Jamaica', 'Hillcrest'),
#  ('Jamaica', 'Briarwood'),
#  ('Glendale', 'Ridgewood'),
#  ('Glendale', 'East New York'),
#  ('Briarwood', 'Jamaica Hills'),
#  ('Briarwood', 'Hillcrest'),
#  ('Briarwood', 'Pomonok'),
#  ('Astoria Heights', 'East Elmhurst'),
#  ('Astoria Heights', 'Jackson Heights'),
#  ('Hillcrest', 'Jamaica Hills'),
#  ('Hillcrest', 'Pomonok'),
#  ('Hillcrest', 'Jamaica Estates'),
#  ('Hillcrest', 'Briarwood'),
#  ('College Point', 'Flushing'),
#  ('College Point', 'Clason Point'),
#  ('Jamaica Estates', 'Jamaica Hills'),
#  ('Jamaica Estates', 'Hillcrest'),
#  ('Jamaica Hills', 'Hillcrest'),
#  ('Jamaica Hills', 'Briarwood'),
#  ('Jamaica Hills', 'Jamaica Estates'),
#  ('Jamaica Hills', 'Jamaica'),
#  ('Auburndale', 'Pomonok'),
#  ('Auburndale', 'Jamaica Estates'),
#  ('Park Hill', 'Clifton'),
#  ('St. George', 'Clifton'),
#  ('Clifton', 'Park Hill')]

# %%
#self edges
selfedges = []
for n in nodes:
    index = data_gangdf[data_gangdf['Neighborhood']== n ].index.values.astype(int)[0]
    if data_gangdf.loc[index, 'gang'] == '1':
        selfedges.append((n,n))

# %%
all_gang_edges = selfedges + gangedges

# %%
#Graph with gangedges
G_g = nx.Graph()
G_g.add_nodes_from(nodes)
G_g.add_edges_from(gangedges)
nx.draw(G_g,node_size=20,font_size=8, node_color = color_map)

# %%
#Graph with gangedges
G_g2 = nx.Graph()
G_g2.add_nodes_from(nodes)
G_g2.add_edges_from(all_gang_edges)
nx.draw(G_g2,node_size=20,font_size=8, node_color = color_map_gang)

# %%
nx.number_connected_components(G)
# Out:
# 598

# %%
len(list(nx.isolates(G)))
# Out:
# 598

# %%
#Preparing data to create a color list informing us on the presence of a gang in a neighborhood

data_gangdf.groupby('Neighborhood').count()
data_gangdf2 = nbcrimenei.merge(data_gangdf, left_on='Neighborhood', right_on='Neighborhood', how = 'left', suffixes=('', '_N1'))
print(len(data_gangdf2))
print(len(nbcrimenei))
# Out:
# 261
# 261

# %%
# Creating a color maping of the gang presense in a neighborhood for visualisation

color_map_gang = []
for node in data_gangdf2["gang"] :
    if node == '1':
        color_map_gang.append('red')
    else:
        color_map_gang.append('blue')

# %%
color_map_gang
# Out:
# ['blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'blue',
#  'red',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'red',
#  'red',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue',
#  'blue']

# %%
len(nbcrimenei)
# Out:
# 261

# %% [markdown]
# ### Features

# %%
#Graph with gangedges
G3 = nx.Graph()
G3.add_nodes_from(nodes)
G3.add_edges_from(gangedges)
nx.draw(G3,node_size=20,font_size=8, node_color = color_map)

# %%
#Shortest path
shortest_path3=[]

counter = 0
for i in nodes:
    for j in nodes:
        source = i
        target = j
    
    #index_source = IDs.index(source)
    #index_target = IDs.index(target)
    
        if (nx.has_path(G3, source, target)== True) :
            shortest_path3.append(((source,target),nx.shortest_path_length(G3,source,target)))
        else : 
            shortest_path3.append(1000)
    
        counter += 1
        if counter % 1000 == True:
            print (counter, "training examples processsed")
# Out:
# 1 training examples processsed
# 1001 training examples processsed
# 2001 training examples processsed
# 3001 training examples processsed
# 4001 training examples processsed
# 5001 training examples processsed
# 6001 training examples processsed
# 7001 training examples processsed
# 8001 training examples processsed
# 9001 training examples processsed
# 10001 training examples processsed
# 11001 training examples processsed
# 12001 training examples processsed
# 13001 training examples processsed
# 14001 training examples processsed
# 15001 training examples processsed
# 16001 training examples processsed
# 17001 training examples processsed
# 18001 training examples processsed
# 19001 training examples processsed
# 20001 training examples processsed
# 21001 training examples processsed
# 22001 training examples processsed
# 23001 training examples processsed
# 24001 training examples processsed
# 25001 training examples processsed
# 26001 training examples processsed
# 27001 training examples processsed
# 28001 training examples processsed
# 29001 training examples processsed
# 30001 training examples processsed
# 31001 training examples processsed
# 32001 training examples processsed
# 33001 training examples processsed
# 34001 training examples processsed
# 35001 training examples processsed
# 36001 training examples processsed
# 37001 training examples processsed
# 38001 training examples processsed
# 39001 training examples processsed
# 40001 training examples processsed
# 41001 training examples processsed
# 42001 training examples processsed
# 43001 training examples processsed
# 44001 training examples processsed
# 45001 training examples processsed
# 46001 training examples processsed
# 47001 training examples processsed
# 48001 training examples processsed
# 49001 training examples processsed
# 50001 training examples processsed
# 51001 training examples processsed
# 52001 training examples processsed
# 53001 training examples processsed
# 54001 training examples processsed
# 55001 training examples processsed
# 56001 training examples processsed
# 57001 training examples processsed
# 58001 training examples processsed
# 59001 training examples processsed
# 60001 training examples processsed
# 61001 training examples processsed
# 62001 training examples processsed
# 63001 training examples processsed
# 64001 training examples processsed
# 65001 training examples processsed
# 66001 training examples processsed
# 67001 training examples processsed
# 68001 training examples processsed

# %%
shortest_path3
# Out:
# [(('Annadale', 'Annadale'), 0),
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  (('Arden Heights', 'Arden Heights'), 0),
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  (('Arrochar', 'Arrochar'), 0),
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  (('Arverne', 'Arverne'), 0),
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  (('Arverne', 'Far Rockaway'), 1),
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  1000,
#  ...]

# %%
deg_centr3=nx.degree_centrality(G3)
betw_centr3=nx.betweenness_centrality(G3)
eigen_centr3=nx.eigenvector_centrality(G3,max_iter=1000)

# %% [markdown]
# XGB

# %%
 deg_centr3
# Out:
# {'Annadale': 0.0,
#  'Arden Heights': 0.0,
#  'Arrochar': 0.0,
#  'Arverne': 0.0038461538461538464,
#  'Astoria': 0.007692307692307693,
#  'Astoria Heights': 0.011538461538461539,
#  'Auburndale': 0.011538461538461539,
#  'Bath Beach': 0.007692307692307693,
#  'Battery Park': 0.0,
#  'Bay Ridge': 0.0,
#  'Bay Terrace': 0.0,
#  'Baychester': 0.011538461538461539,
#  'Bayside': 0.0,
#  'Bedford Park': 0.019230769230769232,
#  'Bedford Stuyvesant': 0.015384615384615385,
#  'Belle Harbor': 0.0,
#  'Bellerose': 0.0,
#  'Belmont': 0.023076923076923078,
#  'Bensonhurst': 0.0,
#  'Bergen Beach': 0.0,
#  'Blissville': 0.0,
#  'Bloomfield': 0.0,
#  'Boerum Hill': 0.0,
#  'Borough Park': 0.0,
#  'Breezy Point': 0.0,
#  'Briarwood': 0.019230769230769232,
#  'Brighton Beach': 0.0,
#  'Broad Channel': 0.0,
#  'Bronx Park': 0.0,
#  'Brooklyn Heights': 0.0,
#  'Brownsville': 0.015384615384615385,
#  'Bulls Head': 0.0,
#  'Bushwick': 0.011538461538461539,
#  'Butler Manor': 0.0,
#  'Cambria Heights': 0.0,
#  'Canarsie': 0.011538461538461539,
#  'Carnegie Hill': 0.0,
#  'Carroll Gardens': 0.0,
#  'Castle Hill': 0.015384615384615385,
#  'Castleton Corners': 0.0,
#  'Central Park': 0.0,
#  'Charleston': 0.0,
#  'Chelsea': 0.0,
#  'Chelsea-Travis': 0.0,
#  'Chinatown': 0.0038461538461538464,
#  'City Island': 0.0,
#  'Clason Point': 0.015384615384615385,
#  'Clifton': 0.007692307692307693,
#  'Clinton': 0.0,
#  'Clinton Hill': 0.011538461538461539,
#  'Clove Lake': 0.0,
#  'Co-op City': 0.007692307692307693,
#  'Cobble Hill': 0.0,
#  'College Point': 0.007692307692307693,
#  'Columbia Street Waterfront District': 0.0,
#  'Columbus Circle': 0.0,
#  'Concourse': 0.0,
#  'Coney Island': 0.007692307692307693,
#  'Corona': 0.011538461538461539,
#  'Country Club': 0.0,
#  'Crown Heights': 0.011538461538461539,
#  'DUMBO': 0.0,
#  'Dongan Hills': 0.0,
#  'Douglaston-Little Neck': 0.0,
#  'Downtown': 0.0,
#  'Dyker Heights': 0.0,
#  'East Elmhurst': 0.015384615384615385,
#  'East Flatbush': 0.019230769230769232,
#  'East Harlem': 0.011538461538461539,
#  'East New York': 0.007692307692307693,
#  'East Tremont': 0.019230769230769232,
#  'East Village': 0.0038461538461538464,
#  'Eastchester': 0.007692307692307693,
#  'Elm Park': 0.0,
#  'Elmhurst': 0.011538461538461539,
#  'Eltingville': 0.0,
#  'Emerson Hill': 0.0,
#  'Far Rockaway': 0.0038461538461538464,
#  'Fieldston': 0.0,
#  'Financial District': 0.0,
#  'Flatbush': 0.0038461538461538464,
#  'Flatiron District': 0.0,
#  'Flatlands': 0.007692307692307693,
#  'Floral park': 0.0,
#  'Floyd Bennett Field': 0.0,
#  'Flushing': 0.007692307692307693,
#  'Flushing Meadows Corona Park': 0.0,
#  'Fordham': 0.023076923076923078,
#  'Forest Hills': 0.0,
#  'Forest Hills Gardens': 0.0,
#  'Fort Greene': 0.007692307692307693,
#  'Fort Hamilton': 0.0,
#  'Fort Wadsworth': 0.0,
#  'Fresh Kills': 0.0,
#  'Fresh Meadows': 0.0,
#  'Garment District': 0.0,
#  'Georgetown': 0.0,
#  'Gerritsen Beach': 0.0,
#  'Glen Oaks': 0.0,
#  'Glendale': 0.007692307692307693,
#  'Gowanus': 0.0,
#  'Gramercy': 0.0,
#  'Graniteville': 0.0,
#  'Grant City': 0.0,
#  'Grasmere - Concord': 0.0,
#  'Gravesend': 0.011538461538461539,
#  'Great Kills': 0.0,
#  'Greenpoint': 0.0,
#  'Greenridge': 0.0,
#  'Greenwich Village': 0.0,
#  'Greenwood': 0.0,
#  'Grymes Hill': 0.0,
#  'Hamilton Heights': 0.0,
#  'Harlem': 0.015384615384615385,
#  'Heartland Village': 0.0,
#  'High Bridge': 0.0,
#  'Hillcrest': 0.019230769230769232,
#  'Hollis': 0.007692307692307693,
#  'Holliswood': 0.0,
#  'Homecrest': 0.0,
#  'Howard Beach': 0.0,
#  'Huguenot': 0.0,
#  'Hunters Point': 0.007692307692307693,
#  'Hunts Point': 0.0,
#  'Inwood': 0.019230769230769232,
#  'Jackson Heights': 0.015384615384615385,
#  'Jacob Riis Park': 0.0,
#  'Jamaica': 0.023076923076923078,
#  'Jamaica Estates': 0.019230769230769232,
#  'Jamaica Hills': 0.015384615384615385,
#  'John F. Kennedy International Airport': 0.0,
#  'Kensington': 0.0,
#  'Kew Gardens': 0.0,
#  'Kew Gardens Hills': 0.0,
#  'Kingsbridge': 0.011538461538461539,
#  'La Guardia Airport': 0.0,
#  'La Tourette Park': 0.0,
#  'Laurelton': 0.0,
#  'Lighthouse Hill': 0.0,
#  'Little Italy': 0.0,
#  'Longwood': 0.011538461538461539,
#  'Lower East Side': 0.011538461538461539,
#  'Malba': 0.0,
#  'Manhattan Beach': 0.0,
#  'Manhattanville': 0.011538461538461539,
#  'Marble Hill': 0.015384615384615385,
#  'Marine Park': 0.0,
#  "Mariner's Harbor": 0.0,
#  'Maspeth': 0.0,
#  'Meiers Corners': 0.0,
#  'Melrose': 0.007692307692307693,
#  'Middle Village': 0.0,
#  'Midland Beach': 0.0,
#  'Midtown': 0.0,
#  'Midwood': 0.0,
#  'Mill Basin': 0.0,
#  'Morningside Heights': 0.011538461538461539,
#  'Morris Heights': 0.011538461538461539,
#  'Morris Park': 0.007692307692307693,
#  'Mott Haven': 0.007692307692307693,
#  'Murray Hill': 0.0,
#  'Navy Yard': 0.0,
#  'Neponsit': 0.0,
#  'New Brighton': 0.0,
#  'New Dorp': 0.0,
#  'New Dorp Beach': 0.0,
#  'New Springville': 0.0,
#  'New Utrecht': 0.0,
#  'NoHo': 0.0,
#  'North Riverdale': 0.0,
#  'Norwood': 0.011538461538461539,
#  'Oakland Gardens': 0.0,
#  'Oakwood': 0.0,
#  'Ocean Hill': 0.0,
#  'Ocean Parkway': 0.0,
#  'Old Town': 0.0,
#  'Ozone Park': 0.0,
#  'Park Hill': 0.0038461538461538464,
#  'Park Slope': 0.0,
#  'Parkchester': 0.0,
#  'Pelham Bay': 0.0,
#  'Pelham Bay Park': 0.0,
#  'Pelham Gardens': 0.0,
#  'Pleasant Plains': 0.0,
#  'Pomonok': 0.011538461538461539,
#  'Port Ivory': 0.0,
#  'Port Morris': 0.0,
#  'Port Richmond': 0.0,
#  "Prince's Bay": 0.0,
#  'Prospect Heights': 0.0,
#  'Prospect Lefferts Gardens': 0.011538461538461539,
#  'Prospect Park': 0.0,
#  'Prospect Park South': 0.0,
#  'Queens Village': 0.0,
#  'Randall Manor': 0.0,
#  'Randals-Wards Island': 0.0,
#  'Red Hook': 0.0,
#  'Rego Park': 0.0,
#  'Richmond Hill': 0.0,
#  'Richmond Town': 0.0,
#  'Richmond Valley': 0.0,
#  'Ridgewood': 0.007692307692307693,
#  'Rikers Island': 0.0,
#  'Riverdale': 0.0,
#  'Rochdale': 0.007692307692307693,
#  'Rockaway Beach': 0.0,
#  'Rockaway Park': 0.0,
#  'Roosevelt Island': 0.0,
#  'Rosebank': 0.0,
#  'Rosedale': 0.0,
#  'Rossville': 0.0,
#  'Roxbury': 0.0,
#  'Sheepshead Bay': 0.0038461538461538464,
#  'Silver Lake': 0.0,
#  'SoHo': 0.0,
#  'Soundview': 0.019230769230769232,
#  'South Beach': 0.0,
#  'South Bronx': 0.0,
#  'South Ozone Park': 0.007692307692307693,
#  'Springfield Gardens': 0.0,
#  'Spuyten Duyvil': 0.0,
#  'St. Albans': 0.007692307692307693,
#  'St. George': 0.0038461538461538464,
#  'Stapleton': 0.0,
#  'Stuyvesant Town': 0.0,
#  'Sunnyside': 0.007692307692307693,
#  'Sunset Park': 0.0,
#  'Sutton Place': 0.0,
#  'Throggs Neck': 0.007692307692307693,
#  'Todt Hill': 0.0,
#  'Tompkinsville': 0.0,
#  'Tottenville': 0.0,
#  'Tremont': 0.019230769230769232,
#  'Tribeca': 0.0,
#  'Tudor City': 0.0,
#  'Turtle Bay': 0.0,
#  'Unionport': 0.019230769230769232,
#  'University Heights': 0.019230769230769232,
#  'Upper East Side': 0.0038461538461538464,
#  'Upper West Side': 0.0038461538461538464,
#  'Utopia': 0.0,
#  'Van Cortlandt Park': 0.0,
#  'Van Nest': 0.0,
#  'Vinegar Hill': 0.007692307692307693,
#  'Wakefield': 0.0,
#  'Washington Heights': 0.007692307692307693,
#  'West Brighton': 0.0,
#  'West Farms': 0.011538461538461539,
#  'West Village': 0.0,
#  'Westchester Heights': 0.0,
#  'Westerleigh': 0.0,
#  'Whitestone': 0.0,
#  'Williamsbridge': 0.011538461538461539,
#  'Williamsburg': 0.011538461538461539,
#  'Willowbrook': 0.0,
#  'Windsor Terrace': 0.0,
#  'Wingate': 0.0,
#  'Woodhaven': 0.0,
#  'Woodlawn': 0.0,
#  'Woodrow': 0.0,
#  'Woodside': 0.0}

# %%
dfedgesgang['deg_centr']=0
for i in range(1310):
    for k, v in deg_centr3.items():
        if dfedgesgang['Neighborhood'][i]==k:
            dfedgesgang['deg_centr'][i]=k

dfedgesgang
# Out:
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#                                 N1                  N2  \
# 0                         Longwood         Hunts Point
# 1                         Longwood         South Bronx
# 2                         Longwood             Melrose
# 3                         Longwood           Soundview
# 4                         Longwood        East Tremont
# 5                        Soundview         Parkchester
# 6                        Soundview            Van Nest
# 7                        Soundview           Unionport
# 8                        Soundview         Castle Hill
# 9                        Soundview          West Farms
# 10                     South Bronx            Longwood
# 11                     South Bronx           Concourse
# 12                     South Bronx             Tremont
# 13                     South Bronx        East Tremont
# 14                     South Bronx             Melrose
# 15                     High Bridge           Concourse
# 16                     High Bridge      Morris Heights
# 17                     High Bridge  Washington Heights
# 18                     High Bridge         South Bronx
# 19                     High Bridge             Melrose
# 20              University Heights             Fordham
# 21              University Heights             Tremont
# 22              University Heights         Marble Hill
# 23              University Heights              Inwood
# 24              University Heights         Kingsbridge
# 25                  Williamsbridge             Norwood
# 26                  Williamsbridge          Baychester
# 27                  Williamsbridge      Pelham Gardens
# 28                  Williamsbridge         Morris Park
# 29                  Williamsbridge            Woodlawn
# ...                            ...                 ...
# 1280               Lighthouse Hill       Richmond Town
# 1281               Lighthouse Hill     New Springville
# 1282               Lighthouse Hill            New Dorp
# 1283               Lighthouse Hill          Grant City
# 1284               Lighthouse Hill             Oakwood
# 1285                       Clifton           Stapleton
# 1286                       Clifton            Rosebank
# 1287                       Clifton           Park Hill
# 1288                       Clifton         Grymes Hill
# 1289                       Clifton       Tompkinsville
# 1290  no neihborhood STATEN ISLAND   Castleton Corners
# 1291  no neihborhood STATEN ISLAND       West Brighton
# 1292  no neihborhood STATEN ISLAND          Clove Lake
# 1293  no neihborhood STATEN ISLAND         Westerleigh
# 1294  no neihborhood STATEN ISLAND       Port Richmond
# 1295              La Tourette Park         Eltingville
# 1296              La Tourette Park          Greenridge
# 1297              La Tourette Park   Heartland Village
# 1298              La Tourette Park         Great Kills
# 1299              La Tourette Park            Annadale
# 1300                Fort Wadsworth            Arrochar
# 1301                Fort Wadsworth            Rosebank
# 1302                Fort Wadsworth  Grasmere - Concord
# 1303                Fort Wadsworth         South Beach
# 1304                Fort Wadsworth             Clifton
# 1305                   Fresh Kills          Greenridge
# 1306                   Fresh Kills       Arden Heights
# 1307                   Fresh Kills           Rossville
# 1308                   Fresh Kills    La Tourette Park
# 1309                   Fresh Kills            Huguenot
#
#                       Neighborhood gang     Neighborhood_N2 gang_N2  \
# 0                         Longwood    1         Hunts Point       0
# 1                         Longwood    1         South Bronx       0
# 2                         Longwood    1             Melrose       1
# 3                         Longwood    1           Soundview       1
# 4                         Longwood    1        East Tremont       1
# 5                        Soundview    1         Parkchester       0
# 6                        Soundview    1            Van Nest       0
# 7                        Soundview    1           Unionport       1
# 8                        Soundview    1         Castle Hill       1
# 9                        Soundview    1          West Farms       1
# 10                     South Bronx    0            Longwood       1
# 11                     South Bronx    0           Concourse       0
# 12                     South Bronx    0             Tremont       1
# 13                     South Bronx    0        East Tremont       1
# 14                     South Bronx    0             Melrose       1
# 15                     High Bridge    0           Concourse       0
# 16                     High Bridge    0      Morris Heights       1
# 17                     High Bridge    0  Washington Heights       1
# 18                     High Bridge    0         South Bronx       0
# 19                     High Bridge    0             Melrose       1
# 20              University Heights    1             Fordham       1
# 21              University Heights    1             Tremont       1
# 22              University Heights    1         Marble Hill       1
# 23              University Heights    1              Inwood       1
# 24              University Heights    1         Kingsbridge       1
# 25                  Williamsbridge    1             Norwood       1
# 26                  Williamsbridge    1          Baychester       1
# 27                  Williamsbridge    1      Pelham Gardens       0
# 28                  Williamsbridge    1         Morris Park       1
# 29                  Williamsbridge    1            Woodlawn       0
# ...                            ...  ...                 ...     ...
# 1280               Lighthouse Hill    0       Richmond Town       0
# 1281               Lighthouse Hill    0     New Springville       0
# 1282               Lighthouse Hill    0            New Dorp       0
# 1283               Lighthouse Hill    0          Grant City       0
# 1284               Lighthouse Hill    0             Oakwood       0
# 1285                       Clifton    1           Stapleton       0
# 1286                       Clifton    1            Rosebank       0
# 1287                       Clifton    1           Park Hill       1
# 1288                       Clifton    1         Grymes Hill       0
# 1289                       Clifton    1       Tompkinsville       0
# 1290  no neihborhood STATEN ISLAND    0   Castleton Corners       0
# 1291  no neihborhood STATEN ISLAND    0       West Brighton       1
# 1292  no neihborhood STATEN ISLAND    0          Clove Lake       0
# 1293  no neihborhood STATEN ISLAND    0         Westerleigh       0
# 1294  no neihborhood STATEN ISLAND    0       Port Richmond       0
# 1295              La Tourette Park    0         Eltingville       0
# 1296              La Tourette Park    0          Greenridge       0
# 1297              La Tourette Park    0   Heartland Village       0
# 1298              La Tourette Park    0         Great Kills       0
# 1299              La Tourette Park    0            Annadale       0
# 1300                Fort Wadsworth    0            Arrochar       0
# 1301                Fort Wadsworth    0            Rosebank       0
# 1302                Fort Wadsworth    0  Grasmere - Concord       0
# 1303                Fort Wadsworth    0         South Beach       0
# 1304                Fort Wadsworth    0             Clifton       1
# 1305                   Fresh Kills    0          Greenridge       0
# 1306                   Fresh Kills    0       Arden Heights       0
# 1307                   Fresh Kills    0           Rossville       0
# 1308                   Fresh Kills    0    La Tourette Park       0
# 1309                   Fresh Kills    0            Huguenot       0
#
#                deg_centr
# 0               Longwood
# 1               Longwood
# 2               Longwood
# 3               Longwood
# 4               Longwood
# 5              Soundview
# 6              Soundview
# 7              Soundview
# 8              Soundview
# 9              Soundview
# 10           South Bronx
# 11           South Bronx
# 12           South Bronx
# 13           South Bronx
# 14           South Bronx
# 15           High Bridge
# 16           High Bridge
# 17           High Bridge
# 18           High Bridge
# 19           High Bridge
# 20    University Heights
# 21    University Heights
# 22    University Heights
# 23    University Heights
# 24    University Heights
# 25        Williamsbridge
# 26        Williamsbridge
# 27        Williamsbridge
# 28        Williamsbridge
# 29        Williamsbridge
# ...                  ...
# 1280     Lighthouse Hill
# 1281     Lighthouse Hill
# 1282     Lighthouse Hill
# 1283     Lighthouse Hill
# 1284     Lighthouse Hill
# 1285             Clifton
# 1286             Clifton
# 1287             Clifton
# 1288             Clifton
# 1289             Clifton
# 1290                   0
# 1291                   0
# 1292                   0
# 1293                   0
# 1294                   0
# 1295    La Tourette Park
# 1296    La Tourette Park
# 1297    La Tourette Park
# 1298    La Tourette Park
# 1299    La Tourette Park
# 1300      Fort Wadsworth
# 1301      Fort Wadsworth
# 1302      Fort Wadsworth
# 1303      Fort Wadsworth
# 1304      Fort Wadsworth
# 1305         Fresh Kills
# 1306         Fresh Kills
# 1307         Fresh Kills
# 1308         Fresh Kills
# 1309         Fresh Kills
#
# [1310 rows x 7 columns]

# %%
#dfedgesgang['deg_centr']=0
for i in range(1310):
    for k, v in deg_centr3.items():
        if dfedgesgang['Neighborhood'][i]==k:
            dfedgesgang['deg_centr'][i]=v

dfedgesgang
# Out:
#                                 N1                  N2  \
# 0                         Longwood         Hunts Point
# 1                         Longwood         South Bronx
# 2                         Longwood             Melrose
# 3                         Longwood           Soundview
# 4                         Longwood        East Tremont
# 5                        Soundview         Parkchester
# 6                        Soundview            Van Nest
# 7                        Soundview           Unionport
# 8                        Soundview         Castle Hill
# 9                        Soundview          West Farms
# 10                     South Bronx            Longwood
# 11                     South Bronx           Concourse
# 12                     South Bronx             Tremont
# 13                     South Bronx        East Tremont
# 14                     South Bronx             Melrose
# 15                     High Bridge           Concourse
# 16                     High Bridge      Morris Heights
# 17                     High Bridge  Washington Heights
# 18                     High Bridge         South Bronx
# 19                     High Bridge             Melrose
# 20              University Heights             Fordham
# 21              University Heights             Tremont
# 22              University Heights         Marble Hill
# 23              University Heights              Inwood
# 24              University Heights         Kingsbridge
# 25                  Williamsbridge             Norwood
# 26                  Williamsbridge          Baychester
# 27                  Williamsbridge      Pelham Gardens
# 28                  Williamsbridge         Morris Park
# 29                  Williamsbridge            Woodlawn
# ...                            ...                 ...
# 1280               Lighthouse Hill       Richmond Town
# 1281               Lighthouse Hill     New Springville
# 1282               Lighthouse Hill            New Dorp
# 1283               Lighthouse Hill          Grant City
# 1284               Lighthouse Hill             Oakwood
# 1285                       Clifton           Stapleton
# 1286                       Clifton            Rosebank
# 1287                       Clifton           Park Hill
# 1288                       Clifton         Grymes Hill
# 1289                       Clifton       Tompkinsville
# 1290  no neihborhood STATEN ISLAND   Castleton Corners
# 1291  no neihborhood STATEN ISLAND       West Brighton
# 1292  no neihborhood STATEN ISLAND          Clove Lake
# 1293  no neihborhood STATEN ISLAND         Westerleigh
# 1294  no neihborhood STATEN ISLAND       Port Richmond
# 1295              La Tourette Park         Eltingville
# 1296              La Tourette Park          Greenridge
# 1297              La Tourette Park   Heartland Village
# 1298              La Tourette Park         Great Kills
# 1299              La Tourette Park            Annadale
# 1300                Fort Wadsworth            Arrochar
# 1301                Fort Wadsworth            Rosebank
# 1302                Fort Wadsworth  Grasmere - Concord
# 1303                Fort Wadsworth         South Beach
# 1304                Fort Wadsworth             Clifton
# 1305                   Fresh Kills          Greenridge
# 1306                   Fresh Kills       Arden Heights
# 1307                   Fresh Kills           Rossville
# 1308                   Fresh Kills    La Tourette Park
# 1309                   Fresh Kills            Huguenot
#
#                       Neighborhood gang     Neighborhood_N2 gang_N2  \
# 0                         Longwood    1         Hunts Point       0
# 1                         Longwood    1         South Bronx       0
# 2                         Longwood    1             Melrose       1
# 3                         Longwood    1           Soundview       1
# 4                         Longwood    1        East Tremont       1
# 5                        Soundview    1         Parkchester       0
# 6                        Soundview    1            Van Nest       0
# 7                        Soundview    1           Unionport       1
# 8                        Soundview    1         Castle Hill       1
# 9                        Soundview    1          West Farms       1
# 10                     South Bronx    0            Longwood       1
# 11                     South Bronx    0           Concourse       0
# 12                     South Bronx    0             Tremont       1
# 13                     South Bronx    0        East Tremont       1
# 14                     South Bronx    0             Melrose       1
# 15                     High Bridge    0           Concourse       0
# 16                     High Bridge    0      Morris Heights       1
# 17                     High Bridge    0  Washington Heights       1
# 18                     High Bridge    0         South Bronx       0
# 19                     High Bridge    0             Melrose       1
# 20              University Heights    1             Fordham       1
# 21              University Heights    1             Tremont       1
# 22              University Heights    1         Marble Hill       1
# 23              University Heights    1              Inwood       1
# 24              University Heights    1         Kingsbridge       1
# 25                  Williamsbridge    1             Norwood       1
# 26                  Williamsbridge    1          Baychester       1
# 27                  Williamsbridge    1      Pelham Gardens       0
# 28                  Williamsbridge    1         Morris Park       1
# 29                  Williamsbridge    1            Woodlawn       0
# ...                            ...  ...                 ...     ...
# 1280               Lighthouse Hill    0       Richmond Town       0
# 1281               Lighthouse Hill    0     New Springville       0
# 1282               Lighthouse Hill    0            New Dorp       0
# 1283               Lighthouse Hill    0          Grant City       0
# 1284               Lighthouse Hill    0             Oakwood       0
# 1285                       Clifton    1           Stapleton       0
# 1286                       Clifton    1            Rosebank       0
# 1287                       Clifton    1           Park Hill       1
# 1288                       Clifton    1         Grymes Hill       0
# 1289                       Clifton    1       Tompkinsville       0
# 1290  no neihborhood STATEN ISLAND    0   Castleton Corners       0
# 1291  no neihborhood STATEN ISLAND    0       West Brighton       1
# 1292  no neihborhood STATEN ISLAND    0          Clove Lake       0
# 1293  no neihborhood STATEN ISLAND    0         Westerleigh       0
# 1294  no neihborhood STATEN ISLAND    0       Port Richmond       0
# 1295              La Tourette Park    0         Eltingville       0
# 1296              La Tourette Park    0          Greenridge       0
# 1297              La Tourette Park    0   Heartland Village       0
# 1298              La Tourette Park    0         Great Kills       0
# 1299              La Tourette Park    0            Annadale       0
# 1300                Fort Wadsworth    0            Arrochar       0
# 1301                Fort Wadsworth    0            Rosebank       0
# 1302                Fort Wadsworth    0  Grasmere - Concord       0
# 1303                Fort Wadsworth    0         South Beach       0
# 1304                Fort Wadsworth    0             Clifton       1
# 1305                   Fresh Kills    0          Greenridge       0
# 1306                   Fresh Kills    0       Arden Heights       0
# 1307                   Fresh Kills    0           Rossville       0
# 1308                   Fresh Kills    0    La Tourette Park       0
# 1309                   Fresh Kills    0            Huguenot       0
#
#        deg_centr
# 0      0.0115385
# 1      0.0115385
# 2      0.0115385
# 3      0.0115385
# 4      0.0115385
# 5      0.0192308
# 6      0.0192308
# 7      0.0192308
# 8      0.0192308
# 9      0.0192308
# 10             0
# 11             0
# 12             0
# 13             0
# 14             0
# 15             0
# 16             0
# 17             0
# 18             0
# 19             0
# 20     0.0192308
# 21     0.0192308
# 22     0.0192308
# 23     0.0192308
# 24     0.0192308
# 25     0.0115385
# 26     0.0115385
# 27     0.0115385
# 28     0.0115385
# 29     0.0115385
# ...          ...
# 1280           0
# 1281           0
# 1282           0
# 1283           0
# 1284           0
# 1285  0.00769231
# 1286  0.00769231
# 1287  0.00769231
# 1288  0.00769231
# 1289  0.00769231
# 1290           0
# 1291           0
# 1292           0
# 1293           0
# 1294           0
# 1295           0
# 1296           0
# 1297           0
# 1298           0
# 1299           0
# 1300           0
# 1301           0
# 1302           0
# 1303           0
# 1304           0
# 1305           0
# 1306           0
# 1307           0
# 1308           0
# 1309           0
#
# [1310 rows x 7 columns]

# %%
dfedgesgang['eigen_centr']=0
for i in range(1310):
    for k, v in eigen_centr3.items():
        if dfedgesgang['Neighborhood'][i]==k:
            dfedgesgang['eigen_centr'][i]=k

dfedgesgang
# Out:
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#                                 N1                  N2  \
# 0                         Longwood         Hunts Point
# 1                         Longwood         South Bronx
# 2                         Longwood             Melrose
# 3                         Longwood           Soundview
# 4                         Longwood        East Tremont
# 5                        Soundview         Parkchester
# 6                        Soundview            Van Nest
# 7                        Soundview           Unionport
# 8                        Soundview         Castle Hill
# 9                        Soundview          West Farms
# 10                     South Bronx            Longwood
# 11                     South Bronx           Concourse
# 12                     South Bronx             Tremont
# 13                     South Bronx        East Tremont
# 14                     South Bronx             Melrose
# 15                     High Bridge           Concourse
# 16                     High Bridge      Morris Heights
# 17                     High Bridge  Washington Heights
# 18                     High Bridge         South Bronx
# 19                     High Bridge             Melrose
# 20              University Heights             Fordham
# 21              University Heights             Tremont
# 22              University Heights         Marble Hill
# 23              University Heights              Inwood
# 24              University Heights         Kingsbridge
# 25                  Williamsbridge             Norwood
# 26                  Williamsbridge          Baychester
# 27                  Williamsbridge      Pelham Gardens
# 28                  Williamsbridge         Morris Park
# 29                  Williamsbridge            Woodlawn
# ...                            ...                 ...
# 1280               Lighthouse Hill       Richmond Town
# 1281               Lighthouse Hill     New Springville
# 1282               Lighthouse Hill            New Dorp
# 1283               Lighthouse Hill          Grant City
# 1284               Lighthouse Hill             Oakwood
# 1285                       Clifton           Stapleton
# 1286                       Clifton            Rosebank
# 1287                       Clifton           Park Hill
# 1288                       Clifton         Grymes Hill
# 1289                       Clifton       Tompkinsville
# 1290  no neihborhood STATEN ISLAND   Castleton Corners
# 1291  no neihborhood STATEN ISLAND       West Brighton
# 1292  no neihborhood STATEN ISLAND          Clove Lake
# 1293  no neihborhood STATEN ISLAND         Westerleigh
# 1294  no neihborhood STATEN ISLAND       Port Richmond
# 1295              La Tourette Park         Eltingville
# 1296              La Tourette Park          Greenridge
# 1297              La Tourette Park   Heartland Village
# 1298              La Tourette Park         Great Kills
# 1299              La Tourette Park            Annadale
# 1300                Fort Wadsworth            Arrochar
# 1301                Fort Wadsworth            Rosebank
# 1302                Fort Wadsworth  Grasmere - Concord
# 1303                Fort Wadsworth         South Beach
# 1304                Fort Wadsworth             Clifton
# 1305                   Fresh Kills          Greenridge
# 1306                   Fresh Kills       Arden Heights
# 1307                   Fresh Kills           Rossville
# 1308                   Fresh Kills    La Tourette Park
# 1309                   Fresh Kills            Huguenot
#
#                       Neighborhood gang     Neighborhood_N2 gang_N2  \
# 0                         Longwood    1         Hunts Point       0
# 1                         Longwood    1         South Bronx       0
# 2                         Longwood    1             Melrose       1
# 3                         Longwood    1           Soundview       1
# 4                         Longwood    1        East Tremont       1
# 5                        Soundview    1         Parkchester       0
# 6                        Soundview    1            Van Nest       0
# 7                        Soundview    1           Unionport       1
# 8                        Soundview    1         Castle Hill       1
# 9                        Soundview    1          West Farms       1
# 10                     South Bronx    0            Longwood       1
# 11                     South Bronx    0           Concourse       0
# 12                     South Bronx    0             Tremont       1
# 13                     South Bronx    0        East Tremont       1
# 14                     South Bronx    0             Melrose       1
# 15                     High Bridge    0           Concourse       0
# 16                     High Bridge    0      Morris Heights       1
# 17                     High Bridge    0  Washington Heights       1
# 18                     High Bridge    0         South Bronx       0
# 19                     High Bridge    0             Melrose       1
# 20              University Heights    1             Fordham       1
# 21              University Heights    1             Tremont       1
# 22              University Heights    1         Marble Hill       1
# 23              University Heights    1              Inwood       1
# 24              University Heights    1         Kingsbridge       1
# 25                  Williamsbridge    1             Norwood       1
# 26                  Williamsbridge    1          Baychester       1
# 27                  Williamsbridge    1      Pelham Gardens       0
# 28                  Williamsbridge    1         Morris Park       1
# 29                  Williamsbridge    1            Woodlawn       0
# ...                            ...  ...                 ...     ...
# 1280               Lighthouse Hill    0       Richmond Town       0
# 1281               Lighthouse Hill    0     New Springville       0
# 1282               Lighthouse Hill    0            New Dorp       0
# 1283               Lighthouse Hill    0          Grant City       0
# 1284               Lighthouse Hill    0             Oakwood       0
# 1285                       Clifton    1           Stapleton       0
# 1286                       Clifton    1            Rosebank       0
# 1287                       Clifton    1           Park Hill       1
# 1288                       Clifton    1         Grymes Hill       0
# 1289                       Clifton    1       Tompkinsville       0
# 1290  no neihborhood STATEN ISLAND    0   Castleton Corners       0
# 1291  no neihborhood STATEN ISLAND    0       West Brighton       1
# 1292  no neihborhood STATEN ISLAND    0          Clove Lake       0
# 1293  no neihborhood STATEN ISLAND    0         Westerleigh       0
# 1294  no neihborhood STATEN ISLAND    0       Port Richmond       0
# 1295              La Tourette Park    0         Eltingville       0
# 1296              La Tourette Park    0          Greenridge       0
# 1297              La Tourette Park    0   Heartland Village       0
# 1298              La Tourette Park    0         Great Kills       0
# 1299              La Tourette Park    0            Annadale       0
# 1300                Fort Wadsworth    0            Arrochar       0
# 1301                Fort Wadsworth    0            Rosebank       0
# 1302                Fort Wadsworth    0  Grasmere - Concord       0
# 1303                Fort Wadsworth    0         South Beach       0
# 1304                Fort Wadsworth    0             Clifton       1
# 1305                   Fresh Kills    0          Greenridge       0
# 1306                   Fresh Kills    0       Arden Heights       0
# 1307                   Fresh Kills    0           Rossville       0
# 1308                   Fresh Kills    0    La Tourette Park       0
# 1309                   Fresh Kills    0            Huguenot       0
#
#        deg_centr         eigen_centr
# 0      0.0115385            Longwood
# 1      0.0115385            Longwood
# 2      0.0115385            Longwood
# 3      0.0115385            Longwood
# 4      0.0115385            Longwood
# 5      0.0192308           Soundview
# 6      0.0192308           Soundview
# 7      0.0192308           Soundview
# 8      0.0192308           Soundview
# 9      0.0192308           Soundview
# 10             0         South Bronx
# 11             0         South Bronx
# 12             0         South Bronx
# 13             0         South Bronx
# 14             0         South Bronx
# 15             0         High Bridge
# 16             0         High Bridge
# 17             0         High Bridge
# 18             0         High Bridge
# 19             0         High Bridge
# 20     0.0192308  University Heights
# 21     0.0192308  University Heights
# 22     0.0192308  University Heights
# 23     0.0192308  University Heights
# 24     0.0192308  University Heights
# 25     0.0115385      Williamsbridge
# 26     0.0115385      Williamsbridge
# 27     0.0115385      Williamsbridge
# 28     0.0115385      Williamsbridge
# 29     0.0115385      Williamsbridge
# ...          ...                 ...
# 1280           0     Lighthouse Hill
# 1281           0     Lighthouse Hill
# 1282           0     Lighthouse Hill
# 1283           0     Lighthouse Hill
# 1284           0     Lighthouse Hill
# 1285  0.00769231             Clifton
# 1286  0.00769231             Clifton
# 1287  0.00769231             Clifton
# 1288  0.00769231             Clifton
# 1289  0.00769231             Clifton
# 1290           0                   0
# 1291           0                   0
# 1292           0                   0
# 1293           0                   0
# 1294           0                   0
# 1295           0    La Tourette Park
# 1296           0    La Tourette Park
# 1297           0    La Tourette Park
# 1298           0    La Tourette Park
# 1299           0    La Tourette Park
# 1300           0      Fort Wadsworth
# 1301           0      Fort Wadsworth
# 1302           0      Fort Wadsworth
# 1303           0      Fort Wadsworth
# 1304           0      Fort Wadsworth
# 1305           0         Fresh Kills
# 1306           0         Fresh Kills
# 1307           0         Fresh Kills
# 1308           0         Fresh Kills
# 1309           0         Fresh Kills
#
# [1310 rows x 8 columns]

# %%
#dfedgesgang['eigen_centr']=0
for i in range(1310):
    for k, v in eigen_centr3.items():
        if dfedgesgang['Neighborhood'][i]==k:
            dfedgesgang['eigen_centr'][i]=v

dfedgesgang
# Out:
#                                 N1                  N2  \
# 0                         Longwood         Hunts Point
# 1                         Longwood         South Bronx
# 2                         Longwood             Melrose
# 3                         Longwood           Soundview
# 4                         Longwood        East Tremont
# 5                        Soundview         Parkchester
# 6                        Soundview            Van Nest
# 7                        Soundview           Unionport
# 8                        Soundview         Castle Hill
# 9                        Soundview          West Farms
# 10                     South Bronx            Longwood
# 11                     South Bronx           Concourse
# 12                     South Bronx             Tremont
# 13                     South Bronx        East Tremont
# 14                     South Bronx             Melrose
# 15                     High Bridge           Concourse
# 16                     High Bridge      Morris Heights
# 17                     High Bridge  Washington Heights
# 18                     High Bridge         South Bronx
# 19                     High Bridge             Melrose
# 20              University Heights             Fordham
# 21              University Heights             Tremont
# 22              University Heights         Marble Hill
# 23              University Heights              Inwood
# 24              University Heights         Kingsbridge
# 25                  Williamsbridge             Norwood
# 26                  Williamsbridge          Baychester
# 27                  Williamsbridge      Pelham Gardens
# 28                  Williamsbridge         Morris Park
# 29                  Williamsbridge            Woodlawn
# ...                            ...                 ...
# 1280               Lighthouse Hill       Richmond Town
# 1281               Lighthouse Hill     New Springville
# 1282               Lighthouse Hill            New Dorp
# 1283               Lighthouse Hill          Grant City
# 1284               Lighthouse Hill             Oakwood
# 1285                       Clifton           Stapleton
# 1286                       Clifton            Rosebank
# 1287                       Clifton           Park Hill
# 1288                       Clifton         Grymes Hill
# 1289                       Clifton       Tompkinsville
# 1290  no neihborhood STATEN ISLAND   Castleton Corners
# 1291  no neihborhood STATEN ISLAND       West Brighton
# 1292  no neihborhood STATEN ISLAND          Clove Lake
# 1293  no neihborhood STATEN ISLAND         Westerleigh
# 1294  no neihborhood STATEN ISLAND       Port Richmond
# 1295              La Tourette Park         Eltingville
# 1296              La Tourette Park          Greenridge
# 1297              La Tourette Park   Heartland Village
# 1298              La Tourette Park         Great Kills
# 1299              La Tourette Park            Annadale
# 1300                Fort Wadsworth            Arrochar
# 1301                Fort Wadsworth            Rosebank
# 1302                Fort Wadsworth  Grasmere - Concord
# 1303                Fort Wadsworth         South Beach
# 1304                Fort Wadsworth             Clifton
# 1305                   Fresh Kills          Greenridge
# 1306                   Fresh Kills       Arden Heights
# 1307                   Fresh Kills           Rossville
# 1308                   Fresh Kills    La Tourette Park
# 1309                   Fresh Kills            Huguenot
#
#                       Neighborhood gang     Neighborhood_N2 gang_N2  \
# 0                         Longwood    1         Hunts Point       0
# 1                         Longwood    1         South Bronx       0
# 2                         Longwood    1             Melrose       1
# 3                         Longwood    1           Soundview       1
# 4                         Longwood    1        East Tremont       1
# 5                        Soundview    1         Parkchester       0
# 6                        Soundview    1            Van Nest       0
# 7                        Soundview    1           Unionport       1
# 8                        Soundview    1         Castle Hill       1
# 9                        Soundview    1          West Farms       1
# 10                     South Bronx    0            Longwood       1
# 11                     South Bronx    0           Concourse       0
# 12                     South Bronx    0             Tremont       1
# 13                     South Bronx    0        East Tremont       1
# 14                     South Bronx    0             Melrose       1
# 15                     High Bridge    0           Concourse       0
# 16                     High Bridge    0      Morris Heights       1
# 17                     High Bridge    0  Washington Heights       1
# 18                     High Bridge    0         South Bronx       0
# 19                     High Bridge    0             Melrose       1
# 20              University Heights    1             Fordham       1
# 21              University Heights    1             Tremont       1
# 22              University Heights    1         Marble Hill       1
# 23              University Heights    1              Inwood       1
# 24              University Heights    1         Kingsbridge       1
# 25                  Williamsbridge    1             Norwood       1
# 26                  Williamsbridge    1          Baychester       1
# 27                  Williamsbridge    1      Pelham Gardens       0
# 28                  Williamsbridge    1         Morris Park       1
# 29                  Williamsbridge    1            Woodlawn       0
# ...                            ...  ...                 ...     ...
# 1280               Lighthouse Hill    0       Richmond Town       0
# 1281               Lighthouse Hill    0     New Springville       0
# 1282               Lighthouse Hill    0            New Dorp       0
# 1283               Lighthouse Hill    0          Grant City       0
# 1284               Lighthouse Hill    0             Oakwood       0
# 1285                       Clifton    1           Stapleton       0
# 1286                       Clifton    1            Rosebank       0
# 1287                       Clifton    1           Park Hill       1
# 1288                       Clifton    1         Grymes Hill       0
# 1289                       Clifton    1       Tompkinsville       0
# 1290  no neihborhood STATEN ISLAND    0   Castleton Corners       0
# 1291  no neihborhood STATEN ISLAND    0       West Brighton       1
# 1292  no neihborhood STATEN ISLAND    0          Clove Lake       0
# 1293  no neihborhood STATEN ISLAND    0         Westerleigh       0
# 1294  no neihborhood STATEN ISLAND    0       Port Richmond       0
# 1295              La Tourette Park    0         Eltingville       0
# 1296              La Tourette Park    0          Greenridge       0
# 1297              La Tourette Park    0   Heartland Village       0
# 1298              La Tourette Park    0         Great Kills       0
# 1299              La Tourette Park    0            Annadale       0
# 1300                Fort Wadsworth    0            Arrochar       0
# 1301                Fort Wadsworth    0            Rosebank       0
# 1302                Fort Wadsworth    0  Grasmere - Concord       0
# 1303                Fort Wadsworth    0         South Beach       0
# 1304                Fort Wadsworth    0             Clifton       1
# 1305                   Fresh Kills    0          Greenridge       0
# 1306                   Fresh Kills    0       Arden Heights       0
# 1307                   Fresh Kills    0           Rossville       0
# 1308                   Fresh Kills    0    La Tourette Park       0
# 1309                   Fresh Kills    0            Huguenot       0
#
#        deg_centr  eigen_centr
# 0      0.0115385    0.0903264
# 1      0.0115385    0.0903264
# 2      0.0115385    0.0903264
# 3      0.0115385    0.0903264
# 4      0.0115385    0.0903264
# 5      0.0192308    0.0837211
# 6      0.0192308    0.0837211
# 7      0.0192308    0.0837211
# 8      0.0192308    0.0837211
# 9      0.0192308    0.0837211
# 10             0  1.62434e-79
# 11             0  1.62434e-79
# 12             0  1.62434e-79
# 13             0  1.62434e-79
# 14             0  1.62434e-79
# 15             0  1.62434e-79
# 16             0  1.62434e-79
# 17             0  1.62434e-79
# 18             0  1.62434e-79
# 19             0  1.62434e-79
# 20     0.0192308     0.321216
# 21     0.0192308     0.321216
# 22     0.0192308     0.321216
# 23     0.0192308     0.321216
# 24     0.0192308     0.321216
# 25     0.0115385    0.0408403
# 26     0.0115385    0.0408403
# 27     0.0115385    0.0408403
# 28     0.0115385    0.0408403
# 29     0.0115385    0.0408403
# ...          ...          ...
# 1280           0  1.62434e-79
# 1281           0  1.62434e-79
# 1282           0  1.62434e-79
# 1283           0  1.62434e-79
# 1284           0  1.62434e-79
# 1285  0.00769231  3.04699e-39
# 1286  0.00769231  3.04699e-39
# 1287  0.00769231  3.04699e-39
# 1288  0.00769231  3.04699e-39
# 1289  0.00769231  3.04699e-39
# 1290           0            0
# 1291           0            0
# 1292           0            0
# 1293           0            0
# 1294           0            0
# 1295           0  1.62434e-79
# 1296           0  1.62434e-79
# 1297           0  1.62434e-79
# 1298           0  1.62434e-79
# 1299           0  1.62434e-79
# 1300           0  1.62434e-79
# 1301           0  1.62434e-79
# 1302           0  1.62434e-79
# 1303           0  1.62434e-79
# 1304           0  1.62434e-79
# 1305           0  1.62434e-79
# 1306           0  1.62434e-79
# 1307           0  1.62434e-79
# 1308           0  1.62434e-79
# 1309           0  1.62434e-79
#
# [1310 rows x 8 columns]

# %%
dfedgesgang['betweenness']=0
for i in range(1310):
    for k, v in betw_centr3.items():
        if dfedgesgang['Neighborhood'][i]==k:
            dfedgesgang['betweenness'][i]=k

dfedgesgang
# Out:
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#                                 N1                  N2  \
# 0                         Longwood         Hunts Point
# 1                         Longwood         South Bronx
# 2                         Longwood             Melrose
# 3                         Longwood           Soundview
# 4                         Longwood        East Tremont
# 5                        Soundview         Parkchester
# 6                        Soundview            Van Nest
# 7                        Soundview           Unionport
# 8                        Soundview         Castle Hill
# 9                        Soundview          West Farms
# 10                     South Bronx            Longwood
# 11                     South Bronx           Concourse
# 12                     South Bronx             Tremont
# 13                     South Bronx        East Tremont
# 14                     South Bronx             Melrose
# 15                     High Bridge           Concourse
# 16                     High Bridge      Morris Heights
# 17                     High Bridge  Washington Heights
# 18                     High Bridge         South Bronx
# 19                     High Bridge             Melrose
# 20              University Heights             Fordham
# 21              University Heights             Tremont
# 22              University Heights         Marble Hill
# 23              University Heights              Inwood
# 24              University Heights         Kingsbridge
# 25                  Williamsbridge             Norwood
# 26                  Williamsbridge          Baychester
# 27                  Williamsbridge      Pelham Gardens
# 28                  Williamsbridge         Morris Park
# 29                  Williamsbridge            Woodlawn
# ...                            ...                 ...
# 1280               Lighthouse Hill       Richmond Town
# 1281               Lighthouse Hill     New Springville
# 1282               Lighthouse Hill            New Dorp
# 1283               Lighthouse Hill          Grant City
# 1284               Lighthouse Hill             Oakwood
# 1285                       Clifton           Stapleton
# 1286                       Clifton            Rosebank
# 1287                       Clifton           Park Hill
# 1288                       Clifton         Grymes Hill
# 1289                       Clifton       Tompkinsville
# 1290  no neihborhood STATEN ISLAND   Castleton Corners
# 1291  no neihborhood STATEN ISLAND       West Brighton
# 1292  no neihborhood STATEN ISLAND          Clove Lake
# 1293  no neihborhood STATEN ISLAND         Westerleigh
# 1294  no neihborhood STATEN ISLAND       Port Richmond
# 1295              La Tourette Park         Eltingville
# 1296              La Tourette Park          Greenridge
# 1297              La Tourette Park   Heartland Village
# 1298              La Tourette Park         Great Kills
# 1299              La Tourette Park            Annadale
# 1300                Fort Wadsworth            Arrochar
# 1301                Fort Wadsworth            Rosebank
# 1302                Fort Wadsworth  Grasmere - Concord
# 1303                Fort Wadsworth         South Beach
# 1304                Fort Wadsworth             Clifton
# 1305                   Fresh Kills          Greenridge
# 1306                   Fresh Kills       Arden Heights
# 1307                   Fresh Kills           Rossville
# 1308                   Fresh Kills    La Tourette Park
# 1309                   Fresh Kills            Huguenot
#
#                       Neighborhood gang     Neighborhood_N2 gang_N2  \
# 0                         Longwood    1         Hunts Point       0
# 1                         Longwood    1         South Bronx       0
# 2                         Longwood    1             Melrose       1
# 3                         Longwood    1           Soundview       1
# 4                         Longwood    1        East Tremont       1
# 5                        Soundview    1         Parkchester       0
# 6                        Soundview    1            Van Nest       0
# 7                        Soundview    1           Unionport       1
# 8                        Soundview    1         Castle Hill       1
# 9                        Soundview    1          West Farms       1
# 10                     South Bronx    0            Longwood       1
# 11                     South Bronx    0           Concourse       0
# 12                     South Bronx    0             Tremont       1
# 13                     South Bronx    0        East Tremont       1
# 14                     South Bronx    0             Melrose       1
# 15                     High Bridge    0           Concourse       0
# 16                     High Bridge    0      Morris Heights       1
# 17                     High Bridge    0  Washington Heights       1
# 18                     High Bridge    0         South Bronx       0
# 19                     High Bridge    0             Melrose       1
# 20              University Heights    1             Fordham       1
# 21              University Heights    1             Tremont       1
# 22              University Heights    1         Marble Hill       1
# 23              University Heights    1              Inwood       1
# 24              University Heights    1         Kingsbridge       1
# 25                  Williamsbridge    1             Norwood       1
# 26                  Williamsbridge    1          Baychester       1
# 27                  Williamsbridge    1      Pelham Gardens       0
# 28                  Williamsbridge    1         Morris Park       1
# 29                  Williamsbridge    1            Woodlawn       0
# ...                            ...  ...                 ...     ...
# 1280               Lighthouse Hill    0       Richmond Town       0
# 1281               Lighthouse Hill    0     New Springville       0
# 1282               Lighthouse Hill    0            New Dorp       0
# 1283               Lighthouse Hill    0          Grant City       0
# 1284               Lighthouse Hill    0             Oakwood       0
# 1285                       Clifton    1           Stapleton       0
# 1286                       Clifton    1            Rosebank       0
# 1287                       Clifton    1           Park Hill       1
# 1288                       Clifton    1         Grymes Hill       0
# 1289                       Clifton    1       Tompkinsville       0
# 1290  no neihborhood STATEN ISLAND    0   Castleton Corners       0
# 1291  no neihborhood STATEN ISLAND    0       West Brighton       1
# 1292  no neihborhood STATEN ISLAND    0          Clove Lake       0
# 1293  no neihborhood STATEN ISLAND    0         Westerleigh       0
# 1294  no neihborhood STATEN ISLAND    0       Port Richmond       0
# 1295              La Tourette Park    0         Eltingville       0
# 1296              La Tourette Park    0          Greenridge       0
# 1297              La Tourette Park    0   Heartland Village       0
# 1298              La Tourette Park    0         Great Kills       0
# 1299              La Tourette Park    0            Annadale       0
# 1300                Fort Wadsworth    0            Arrochar       0
# 1301                Fort Wadsworth    0            Rosebank       0
# 1302                Fort Wadsworth    0  Grasmere - Concord       0
# 1303                Fort Wadsworth    0         South Beach       0
# 1304                Fort Wadsworth    0             Clifton       1
# 1305                   Fresh Kills    0          Greenridge       0
# 1306                   Fresh Kills    0       Arden Heights       0
# 1307                   Fresh Kills    0           Rossville       0
# 1308                   Fresh Kills    0    La Tourette Park       0
# 1309                   Fresh Kills    0            Huguenot       0
#
#        deg_centr  eigen_centr         betweenness
# 0      0.0115385    0.0903264            Longwood
# 1      0.0115385    0.0903264            Longwood
# 2      0.0115385    0.0903264            Longwood
# 3      0.0115385    0.0903264            Longwood
# 4      0.0115385    0.0903264            Longwood
# 5      0.0192308    0.0837211           Soundview
# 6      0.0192308    0.0837211           Soundview
# 7      0.0192308    0.0837211           Soundview
# 8      0.0192308    0.0837211           Soundview
# 9      0.0192308    0.0837211           Soundview
# 10             0  1.62434e-79         South Bronx
# 11             0  1.62434e-79         South Bronx
# 12             0  1.62434e-79         South Bronx
# 13             0  1.62434e-79         South Bronx
# 14             0  1.62434e-79         South Bronx
# 15             0  1.62434e-79         High Bridge
# 16             0  1.62434e-79         High Bridge
# 17             0  1.62434e-79         High Bridge
# 18             0  1.62434e-79         High Bridge
# 19             0  1.62434e-79         High Bridge
# 20     0.0192308     0.321216  University Heights
# 21     0.0192308     0.321216  University Heights
# 22     0.0192308     0.321216  University Heights
# 23     0.0192308     0.321216  University Heights
# 24     0.0192308     0.321216  University Heights
# 25     0.0115385    0.0408403      Williamsbridge
# 26     0.0115385    0.0408403      Williamsbridge
# 27     0.0115385    0.0408403      Williamsbridge
# 28     0.0115385    0.0408403      Williamsbridge
# 29     0.0115385    0.0408403      Williamsbridge
# ...          ...          ...                 ...
# 1280           0  1.62434e-79     Lighthouse Hill
# 1281           0  1.62434e-79     Lighthouse Hill
# 1282           0  1.62434e-79     Lighthouse Hill
# 1283           0  1.62434e-79     Lighthouse Hill
# 1284           0  1.62434e-79     Lighthouse Hill
# 1285  0.00769231  3.04699e-39             Clifton
# 1286  0.00769231  3.04699e-39             Clifton
# 1287  0.00769231  3.04699e-39             Clifton
# 1288  0.00769231  3.04699e-39             Clifton
# 1289  0.00769231  3.04699e-39             Clifton
# 1290           0            0                   0
# 1291           0            0                   0
# 1292           0            0                   0
# 1293           0            0                   0
# 1294           0            0                   0
# 1295           0  1.62434e-79    La Tourette Park
# 1296           0  1.62434e-79    La Tourette Park
# 1297           0  1.62434e-79    La Tourette Park
# 1298           0  1.62434e-79    La Tourette Park
# 1299           0  1.62434e-79    La Tourette Park
# 1300           0  1.62434e-79      Fort Wadsworth
# 1301           0  1.62434e-79      Fort Wadsworth
# 1302           0  1.62434e-79      Fort Wadsworth
# 1303           0  1.62434e-79      Fort Wadsworth
# 1304           0  1.62434e-79      Fort Wadsworth
# 1305           0  1.62434e-79         Fresh Kills
# 1306           0  1.62434e-79         Fresh Kills
# 1307           0  1.62434e-79         Fresh Kills
# 1308           0  1.62434e-79         Fresh Kills
# 1309           0  1.62434e-79         Fresh Kills
#
# [1310 rows x 9 columns]

# %%
#dfedgesgang['betweenness']=0
for i in range(1310):
    for k, v in betw_centr3.items():
        if dfedgesgang['Neighborhood'][i]==k:
            dfedgesgang['betweenness'][i]=v

dfedgesgang
# Out:
#                                 N1                  N2  \
# 0                         Longwood         Hunts Point
# 1                         Longwood         South Bronx
# 2                         Longwood             Melrose
# 3                         Longwood           Soundview
# 4                         Longwood        East Tremont
# 5                        Soundview         Parkchester
# 6                        Soundview            Van Nest
# 7                        Soundview           Unionport
# 8                        Soundview         Castle Hill
# 9                        Soundview          West Farms
# 10                     South Bronx            Longwood
# 11                     South Bronx           Concourse
# 12                     South Bronx             Tremont
# 13                     South Bronx        East Tremont
# 14                     South Bronx             Melrose
# 15                     High Bridge           Concourse
# 16                     High Bridge      Morris Heights
# 17                     High Bridge  Washington Heights
# 18                     High Bridge         South Bronx
# 19                     High Bridge             Melrose
# 20              University Heights             Fordham
# 21              University Heights             Tremont
# 22              University Heights         Marble Hill
# 23              University Heights              Inwood
# 24              University Heights         Kingsbridge
# 25                  Williamsbridge             Norwood
# 26                  Williamsbridge          Baychester
# 27                  Williamsbridge      Pelham Gardens
# 28                  Williamsbridge         Morris Park
# 29                  Williamsbridge            Woodlawn
# ...                            ...                 ...
# 1280               Lighthouse Hill       Richmond Town
# 1281               Lighthouse Hill     New Springville
# 1282               Lighthouse Hill            New Dorp
# 1283               Lighthouse Hill          Grant City
# 1284               Lighthouse Hill             Oakwood
# 1285                       Clifton           Stapleton
# 1286                       Clifton            Rosebank
# 1287                       Clifton           Park Hill
# 1288                       Clifton         Grymes Hill
# 1289                       Clifton       Tompkinsville
# 1290  no neihborhood STATEN ISLAND   Castleton Corners
# 1291  no neihborhood STATEN ISLAND       West Brighton
# 1292  no neihborhood STATEN ISLAND          Clove Lake
# 1293  no neihborhood STATEN ISLAND         Westerleigh
# 1294  no neihborhood STATEN ISLAND       Port Richmond
# 1295              La Tourette Park         Eltingville
# 1296              La Tourette Park          Greenridge
# 1297              La Tourette Park   Heartland Village
# 1298              La Tourette Park         Great Kills
# 1299              La Tourette Park            Annadale
# 1300                Fort Wadsworth            Arrochar
# 1301                Fort Wadsworth            Rosebank
# 1302                Fort Wadsworth  Grasmere - Concord
# 1303                Fort Wadsworth         South Beach
# 1304                Fort Wadsworth             Clifton
# 1305                   Fresh Kills          Greenridge
# 1306                   Fresh Kills       Arden Heights
# 1307                   Fresh Kills           Rossville
# 1308                   Fresh Kills    La Tourette Park
# 1309                   Fresh Kills            Huguenot
#
#                       Neighborhood gang     Neighborhood_N2 gang_N2  \
# 0                         Longwood    1         Hunts Point       0
# 1                         Longwood    1         South Bronx       0
# 2                         Longwood    1             Melrose       1
# 3                         Longwood    1           Soundview       1
# 4                         Longwood    1        East Tremont       1
# 5                        Soundview    1         Parkchester       0
# 6                        Soundview    1            Van Nest       0
# 7                        Soundview    1           Unionport       1
# 8                        Soundview    1         Castle Hill       1
# 9                        Soundview    1          West Farms       1
# 10                     South Bronx    0            Longwood       1
# 11                     South Bronx    0           Concourse       0
# 12                     South Bronx    0             Tremont       1
# 13                     South Bronx    0        East Tremont       1
# 14                     South Bronx    0             Melrose       1
# 15                     High Bridge    0           Concourse       0
# 16                     High Bridge    0      Morris Heights       1
# 17                     High Bridge    0  Washington Heights       1
# 18                     High Bridge    0         South Bronx       0
# 19                     High Bridge    0             Melrose       1
# 20              University Heights    1             Fordham       1
# 21              University Heights    1             Tremont       1
# 22              University Heights    1         Marble Hill       1
# 23              University Heights    1              Inwood       1
# 24              University Heights    1         Kingsbridge       1
# 25                  Williamsbridge    1             Norwood       1
# 26                  Williamsbridge    1          Baychester       1
# 27                  Williamsbridge    1      Pelham Gardens       0
# 28                  Williamsbridge    1         Morris Park       1
# 29                  Williamsbridge    1            Woodlawn       0
# ...                            ...  ...                 ...     ...
# 1280               Lighthouse Hill    0       Richmond Town       0
# 1281               Lighthouse Hill    0     New Springville       0
# 1282               Lighthouse Hill    0            New Dorp       0
# 1283               Lighthouse Hill    0          Grant City       0
# 1284               Lighthouse Hill    0             Oakwood       0
# 1285                       Clifton    1           Stapleton       0
# 1286                       Clifton    1            Rosebank       0
# 1287                       Clifton    1           Park Hill       1
# 1288                       Clifton    1         Grymes Hill       0
# 1289                       Clifton    1       Tompkinsville       0
# 1290  no neihborhood STATEN ISLAND    0   Castleton Corners       0
# 1291  no neihborhood STATEN ISLAND    0       West Brighton       1
# 1292  no neihborhood STATEN ISLAND    0          Clove Lake       0
# 1293  no neihborhood STATEN ISLAND    0         Westerleigh       0
# 1294  no neihborhood STATEN ISLAND    0       Port Richmond       0
# 1295              La Tourette Park    0         Eltingville       0
# 1296              La Tourette Park    0          Greenridge       0
# 1297              La Tourette Park    0   Heartland Village       0
# 1298              La Tourette Park    0         Great Kills       0
# 1299              La Tourette Park    0            Annadale       0
# 1300                Fort Wadsworth    0            Arrochar       0
# 1301                Fort Wadsworth    0            Rosebank       0
# 1302                Fort Wadsworth    0  Grasmere - Concord       0
# 1303                Fort Wadsworth    0         South Beach       0
# 1304                Fort Wadsworth    0             Clifton       1
# 1305                   Fresh Kills    0          Greenridge       0
# 1306                   Fresh Kills    0       Arden Heights       0
# 1307                   Fresh Kills    0           Rossville       0
# 1308                   Fresh Kills    0    La Tourette Park       0
# 1309                   Fresh Kills    0            Huguenot       0
#
#        deg_centr  eigen_centr betweenness
# 0      0.0115385    0.0903264  0.00776161
# 1      0.0115385    0.0903264  0.00776161
# 2      0.0115385    0.0903264  0.00776161
# 3      0.0115385    0.0903264  0.00776161
# 4      0.0115385    0.0903264  0.00776161
# 5      0.0192308    0.0837211   0.0105188
# 6      0.0192308    0.0837211   0.0105188
# 7      0.0192308    0.0837211   0.0105188
# 8      0.0192308    0.0837211   0.0105188
# 9      0.0192308    0.0837211   0.0105188
# 10             0  1.62434e-79           0
# 11             0  1.62434e-79           0
# 12             0  1.62434e-79           0
# 13             0  1.62434e-79           0
# 14             0  1.62434e-79           0
# 15             0  1.62434e-79           0
# 16             0  1.62434e-79           0
# 17             0  1.62434e-79           0
# 18             0  1.62434e-79           0
# 19             0  1.62434e-79           0
# 20     0.0192308     0.321216  0.00035739
# 21     0.0192308     0.321216  0.00035739
# 22     0.0192308     0.321216  0.00035739
# 23     0.0192308     0.321216  0.00035739
# 24     0.0192308     0.321216  0.00035739
# 25     0.0115385    0.0408403   0.0041679
# 26     0.0115385    0.0408403   0.0041679
# 27     0.0115385    0.0408403   0.0041679
# 28     0.0115385    0.0408403   0.0041679
# 29     0.0115385    0.0408403   0.0041679
# ...          ...          ...         ...
# 1280           0  1.62434e-79           0
# 1281           0  1.62434e-79           0
# 1282           0  1.62434e-79           0
# 1283           0  1.62434e-79           0
# 1284           0  1.62434e-79           0
# 1285  0.00769231  3.04699e-39    2.97e-05
# 1286  0.00769231  3.04699e-39    2.97e-05
# 1287  0.00769231  3.04699e-39    2.97e-05
# 1288  0.00769231  3.04699e-39    2.97e-05
# 1289  0.00769231  3.04699e-39    2.97e-05
# 1290           0            0           0
# 1291           0            0           0
# 1292           0            0           0
# 1293           0            0           0
# 1294           0            0           0
# 1295           0  1.62434e-79           0
# 1296           0  1.62434e-79           0
# 1297           0  1.62434e-79           0
# 1298           0  1.62434e-79           0
# 1299           0  1.62434e-79           0
# 1300           0  1.62434e-79           0
# 1301           0  1.62434e-79           0
# 1302           0  1.62434e-79           0
# 1303           0  1.62434e-79           0
# 1304           0  1.62434e-79           0
# 1305           0  1.62434e-79           0
# 1306           0  1.62434e-79           0
# 1307           0  1.62434e-79           0
# 1308           0  1.62434e-79           0
# 1309           0  1.62434e-79           0
#
# [1310 rows x 9 columns]

# %%
dfedgesgang= dfedgesgang[dfedgesgang.Neighborhood !='no neihborhood STATEN ISLAND']
dfedgesgang= dfedgesgang[dfedgesgang.Neighborhood !='no neihborhood MANHATTAN']
dfedgesgang= dfedgesgang[dfedgesgang.Neighborhood !='no neihborhood BRONX']
dfedgesgang= dfedgesgang[dfedgesgang.Neighborhood !='no neihborhood QUEENS']
dfedgesgang= dfedgesgang[dfedgesgang.Neighborhood !='no neihborhood BROOKLYN']

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split, GridSearchCV 

training_features = np.array([dfedgesgang['deg_centr'],dfedgesgang['eigen_centr'],dfedgesgang['betweenness']]).T

labels_array=dfedgesgang['gang']
labels_array=np.array(labels_array)
labels_array

# scale
training_features = preprocessing.scale(training_features)


X_train, X_valid, y_train, y_valid = train_test_split(training_features,labels_array , test_size=0.33, random_state=42)
# Out:
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)

# %%
from sklearn import preprocessing
import xgboost as xgb
from sklearn.model_selection import train_test_split, GridSearchCV 

training_features = np.array([dfedgesgang['deg_centr'],dfedgesgang['eigen_centr'],dfedgesgang['betweenness']]).T

labels_array=dfedgesgang['gang']
labels_array=np.array(labels_array)
labels_array

# scale
training_features = preprocessing.scale(training_features)


X_train, X_valid, y_train, y_valid = train_test_split(training_features,labels_array , test_size=0.33, random_state=42)


 
params = {} 
params["objective"] = "binary:hinge"
params["eta"] = 0.009
params["min_child_weight"] = 5
params["subsample"] = 0.85
params["colsample_bytree"] = 0.8
params["scale_pos_weight"] = 1.0
params["silent"] = 1
params["max_depth"] = 7 
plst = list(params.items()) 
xgtrain = xgb.DMatrix(X_train, label=y_train) 


num_rounds = 400
model = xgb.train(plst, xgtrain, num_rounds)

# %%
from numpy import ndarray
from sklearn.metrics import accuracy_score
# make predictions for test data

xgtest = xgb.DMatrix(X_valid) 

y_pred = model.predict(xgtest) 

predictions= list(map(int, y_pred))
#predictions = [round(value) for value in y_pred]

y_valid= list(map(int, y_valid))

# evaluate predictions
accuracy = accuracy_score(y_valid, predictions)
print("Accuracy: %f%%" % (accuracy * 100.0))


#print(len(preds1))
#preds1 = list(map(int, preds1))

# %%
def gini_xgb(preds, dtrain):
    labels = dtrain.get_label()
    gini_score = gini_normalized(labels, preds)
    return [('gini', gini_score)]

def gini(actual, pred, cmpcol = 0, sortcol = 1):
    assert( len(actual) == len(pred) )
    all = np.asarray(np.c_[ actual, pred, np.arange(len(actual)) ], dtype=np.float)
    all = all[ np.lexsort((all[:,2], -1*all[:,1])) ]
    totalLosses = all[:,0].sum()
    giniSum = all[:,0].cumsum().sum() / totalLosses
    
    giniSum -= (len(actual) + 1) / 2.
    return giniSum / len(actual)

def gini_normalized(a, p):
    return gini(a, p) / gini(a, a)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

kfold = KFold(n_splits=10, random_state=7,shuffle=True)

#results = cross_val_score(xgb, training_features,labels_array, cv=kfold)
#print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))



#train=dfedgesgang[['deg_centr','eigen_centr','betweenness','gang']]
#train=np.array(train)
#train = preprocessing.scale(train)


for train_index, test_index in kfold.split(training_features):
    
    train_X, valid_X, train_y, valid_y = train_test_split(training_features,labels_array , test_size=0.25, random_state=42)

   

    xgb_params = {'eta': 0.02, 'max_depth': 4, 'subsample': 0.9, 'colsample_bytree': 0.9, 'objective': 'binary:logistic', 'eval_metric': 'auc', 'seed': 99, 'silent': True}

    d_train = xgb.DMatrix(train_X, train_y)
    d_valid = xgb.DMatrix(valid_X, valid_y)
   
    
    watchlist = [(d_train, 'train'), (d_valid, 'valid')]
    model = xgb.train(xgb_params, d_train, 5000,  watchlist, feval=gini_xgb, maximize=True, verbose_eval=50, early_stopping_rounds=100)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier

# %%
param_grid = {'n_estimators': [1000]}
classifier=RandomForestClassifier(n_jobs=-1, random_state=0)
rng = np.random.RandomState(1)
ABC = AdaBoostClassifier(base_estimator = classifier,n_estimators=300, random_state=rng)
# run grid search
grid_search= GridSearchCV(ABC, param_grid=param_grid, n_jobs=-1, scoring = 'accuracy',verbose=1)

# Fit the grid search to the data
model=grid_search.fit(X_train, y_train)
# Out:
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:  7.8min finished
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# C:\Users\Jithendra Sai V\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
predictions_ADB = model.predict(X_valid) #list(model.predict(X_valid))

# %%
predictions_ADBs=[int(x) for x in predictions_ADB]
y_valid=[int(x) for x in y_valid]

# %%
from sklearn.metrics import accuracy_score
# evaluate predictions
accuracy = accuracy_score(y_valid, predictions_ADBs)
print("Accuracy: %f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 98.143852%

# %%
from sklearn.svm import SVC

# %%
# Support Vector Machine
SVC = SVC(C = 1, kernel = 'rbf', gamma = 'auto').fit(X_train, y_train)
predictions_SVC = [int(x) for x in list(SVC.predict(X_valid))]
accuracy_SVC = accuracy_score(y_valid, predictions_SVC)
print("Accuracy SVC: %f%%" % (accuracy_SVC * 100.0))
# Out:
# Accuracy SVC: 98.143852%

# %%
with open("observe_output.csv", 'w') as F:
    for X, y_r, y_a, y_s in zip(X_valid, y_valid, predictions_ADBs, predictions_SVC):
        line = str(X[0]) + "," + str(X[1]) + "," + str(X[2]) + "," + str(y_r) + "," + str(y_a) + "," + str(y_s) + "\n"
        F.write(line)

# %% [markdown]
# MODULARITY GRAPH

# %%
G = nx.Graph()
G.add_nodes_from(nodes)
G.add_edges_from(edges)

# %%
import community
import matplotlib.pyplot as plt
import networkx as nx

nx.transitivity(G)

# Find modularity
part = community.best_partition(G)
mod = community.modularity(part,G)

# Plot, color nodes using community structure
values = [part.get(node) for node in G.nodes()]
nx.draw_spring(G, cmap=plt.get_cmap('jet'), node_color = values, node_size=30, with_labels=False)
plt.show()
